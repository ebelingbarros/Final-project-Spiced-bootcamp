# %% [markdown]
# # NLP with oil and renewable energies project

# %% [markdown]
# #### Get libraries

# %%
import requests
import re
from bs4 import BeautifulSoup
from collections import Counter
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB  
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss
import numpy as np
from PIL import Image
from sklearn.linear_model import LogisticRegression
import argparse
from matplotlib import pyplot as plt
import wordcloud
import requests, json
import os
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import seaborn as sns
import spacy
import spacy
nlp = spacy.load("en_core_web_sm")
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %% [markdown]
# ### Creating dfs

# %%
corpus_oil_price=pd.read_csv('data/corpus_oil_price.csv', index_col=0)
corpus_alternative_energies=pd.read_csv('data/corpus_alternative_energies.csv', index_col=0)
corpus_crude_oil=pd.read_csv('data/corpus_crude_oil.csv', index_col=0)
corpus_oil_price
# Out:
#                                                   title  \
# 0                         $70 Oil Won't Keep OPEC Happy
# 1     Why This Oil Price Slump May Not Be Bad News F...
# 2              The Double Irony Of Biden's Plea To OPEC
# 3                  The Oil Price Rally Is Far From Over
# 4         Biden Threatens OPEC With Undisclosed "Tools"
# ...                                                 ...
# 2183           A Disobliging Update on the Price of Oil
# 2184                What Happens When the Wells Run Dry
# 2185  Petro Unfriendly California Changing it's Stan...
# 2186  New Techniques Oil Companies are Using in Dril...
# 2187  Biofuel of the Future - Turning our Garbage in...
#
#                  date_published  \
# 0     2021-11-29T19:00:00-06:00
# 1     2021-12-02T19:00:00-06:00
# 2     2021-11-10T13:00:00-06:00
# 3     2021-11-09T19:00:00-06:00
# 4     2021-11-08T10:00:00-06:00
# ...                         ...
# 2183  2010-01-09T16:21:21-06:00
# 2184  2010-01-08T16:55:39-06:00
# 2185  2009-12-30T14:18:05-06:00
# 2186  2009-11-25T16:35:34-06:00
# 2187  2009-11-23T14:06:51-06:00
#
#                                                 content  baseline_sentiment  \
# 0     One day&mdash;that was all it took oil prices ...                  -1
# 1     Crude oil prices are plunging under the weight...                  -1
# 2     As I wrote in February of this year in&nbsp;Th...                  -1
# 3     How much higher could oil prices go This is th...                   1
# 4     "There are other tools in the arsenal that we ...                  -1
# ...                                                 ...                 ...
# 2183  There still seems to be a deplorable uncertain...                  -1
# 2184  One nagging question that the industrial world...                   1
# 2185  The financial crisis changed the way people th...                  -1
# 2186  As the politics and philosophical arguments ab...                   1
# 2187  Two overwhelming environmental calamities, sim...                   1
#
#       vader_sentiment
# 0              0.9448
# 1              0.9957
# 2              0.8805
# 3              0.1027
# 4             -0.6269
# ...               ...
# 2183           0.9947
# 2184          -0.7541
# 2185           0.0982
# 2186           0.9985
# 2187           0.9986
#
# [2188 rows x 5 columns]

# %%
corpus_oil_price['content'] = corpus_oil_price['content'].str.replace('"','')
corpus_oil_price['content'] = corpus_oil_price['content'].str.replace('&','')
corpus_oil_price['content'] = corpus_oil_price['content'].str.replace(';','')
corpus_oil_price
# Out:
#                                                   title  \
# 0                         $70 Oil Won't Keep OPEC Happy
# 1     Why This Oil Price Slump May Not Be Bad News F...
# 2              The Double Irony Of Biden's Plea To OPEC
# 3                  The Oil Price Rally Is Far From Over
# 4         Biden Threatens OPEC With Undisclosed "Tools"
# ...                                                 ...
# 2183           A Disobliging Update on the Price of Oil
# 2184                What Happens When the Wells Run Dry
# 2185  Petro Unfriendly California Changing it's Stan...
# 2186  New Techniques Oil Companies are Using in Dril...
# 2187  Biofuel of the Future - Turning our Garbage in...
#
#                  date_published  \
# 0     2021-11-29T19:00:00-06:00
# 1     2021-12-02T19:00:00-06:00
# 2     2021-11-10T13:00:00-06:00
# 3     2021-11-09T19:00:00-06:00
# 4     2021-11-08T10:00:00-06:00
# ...                         ...
# 2183  2010-01-09T16:21:21-06:00
# 2184  2010-01-08T16:55:39-06:00
# 2185  2009-12-30T14:18:05-06:00
# 2186  2009-11-25T16:35:34-06:00
# 2187  2009-11-23T14:06:51-06:00
#
#                                                 content  baseline_sentiment  \
# 0     One daymdashthat was all it took oil prices to...                  -1
# 1     Crude oil prices are plunging under the weight...                  -1
# 2     As I wrote in February of this year innbspThe ...                  -1
# 3     How much higher could oil prices go This is th...                   1
# 4     There are other tools in the arsenal that we h...                  -1
# ...                                                 ...                 ...
# 2183  There still seems to be a deplorable uncertain...                  -1
# 2184  One nagging question that the industrial world...                   1
# 2185  The financial crisis changed the way people th...                  -1
# 2186  As the politics and philosophical arguments ab...                   1
# 2187  Two overwhelming environmental calamities, sim...                   1
#
#       vader_sentiment
# 0              0.9448
# 1              0.9957
# 2              0.8805
# 3              0.1027
# 4             -0.6269
# ...               ...
# 2183           0.9947
# 2184          -0.7541
# 2185           0.0982
# 2186           0.9985
# 2187           0.9986
#
# [2188 rows x 5 columns]

# %%
col_one_list = corpus_oil_price['content'].tolist()

# %%
common_words_list = []
for a in col_one_list:
    complete_doc = nlp(a)
    # Remove stop words and punctuation symbols
    words = [token.text for token in complete_doc
         if not token.is_stop and not token.is_punct]
    word_freq = Counter(words)
    # 5 commonly occurring words with their frequencies
    common_words = word_freq.most_common(21)
    # Unique words
    common_words_list.append(common_words)
common_words_list
# Out:
# [[('oil', 16),
#   (' ', 14),
#   ('OPEC', 8),
#   ('$', 6),
#   ('release', 6),
#   ('new', 6),
#   ('bpd', 6),
#   ('million', 5),
#   ('barrels', 5),
#   ('rdquo', 5),
#   ('prices', 4),
#   ('latest', 4),
#   ('variant', 4),
#   ('output', 4),
#   ('SPR', 4),
#   ('global', 4),
#   ('market', 4),
#   ('U.S.', 3),
#   ('halt', 3),
#   ('supply', 3),
#   ('demand', 3)],
#  [(' ', 9),
#   ('production', 9),
#   ('shale', 8),
#   ('oil', 7),
#   ('prices', 5),
#   ('approach', 5),
#   ('industry', 5),
#   ('drillers', 4),
#   ('way', 4),
#   ('plunging', 3),
#   ('latest', 3),
#   ('variant', 3),
#   ('selloff', 3),
#   ('U.S.', 3),
#   ('stocks', 3),
#   ('patch', 3),
#   ('discipline', 3),
#   ('cash', 3),
#   ('disciplined', 3),
#   ('said', 3),
#   ('depletion', 3)],
#  [('oil', 16),
#   (' ', 12),
#   ('Biden', 9),
#   ('prices', 9),
#   ('Administration', 8),
#   ('production', 8),
#   ('mdash', 6),
#   ('U.S.', 6),
#   ('   ', 5),
#   ('year', 4),
#   ('fossil', 4),
#   ('people', 4),
#   ('pump', 4),
#   ('President', 3),
#   ('higher', 3),
#   ('policies', 3),
#   ('supplies', 3),
#   ('meeting', 3),
#   ('demand', 3),
#   ('week', 3),
#   ('OPEC', 3)],
#  [('oil', 21),
#   (' ', 16),
#   ('prices', 11),
#   ('demand', 9),
#   ('$', 9),
#   ('higher', 8),
#   ('barrel', 8),
#   ('year', 6),
#   ('said', 6),
#   ('supply', 5),
#   ('bullish', 5),
#   ('remains', 5),
#   ('U.S.', 4),
#   ('rdquo', 4),
#   ('90', 4),
#   ('month', 4),
#   ('OPEC', 4),
#   ('price', 4),
#   ('view', 3),
#   ('note', 3),
#   ('Brent', 3)],
#  [(' ', 8),
#   ('OPEC', 6),
#   ('oil', 5),
#   ('pump', 4),
#   ('tools', 3),
#   ('President', 3),
#   ('Biden', 3),
#   ('said', 3),
#   ('crude', 3),
#   ('Washington', 3),
#   ('global', 3),
#   ('recovery', 3),
#   ('arsenal', 2),
#   ('countries', 2),
#   ('supply', 2),
#   ('response', 2),
#   ('calls', 2),
#   ('prices', 2),
#   ('respond', 2),
#   ('quoted', 2),
#   ('administration', 2)],
#  [('OPEC', 8),
#   ('Morse', 8),
#   ('production', 8),
#   (' ', 7),
#   ('oil', 5),
#   ('prices', 5),
#   ('said', 5),
#   ('U.S.', 5),
#   ('capacity', 3),
#   ('year', 3),
#   ('continue', 2),
#   ('role', 2),
#   ('members', 2),
#   ('administration', 2),
#   ('embarrassing', 2),
#   ('moment', 2),
#   ('levels', 2),
#   ('Crude', 1),
#   ('rising', 1),
#   ('quarter', 1),
#   ('global', 1)],
#  [(' ', 22),
#   ('oil', 11),
#   ('million', 10),
#   ('prices', 8),
#   ('U.S.', 6),
#   ('Fed', 6),
#   ('$', 6),
#   ('inflation', 6),
#   ('supply', 5),
#   ('crude', 5),
#   ('barrels', 5),
#   ('year', 5),
#   ('week', 4),
#   ('bullish', 4),
#   ('high', 4),
#   ('economic', 4),
#   ('demand', 3),
#   ('Brent', 3),
#   ('month', 3),
#   ('build', 3),
#   ('funds', 3)],
#  [(' ', 9),
#   ('crude', 6),
#   ('oil', 5),
#   ('barrels', 5),
#   ('prices', 4),
#   ('market', 4),
#   ('Fed', 4),
#   ('inventory', 4),
#   ('API', 4),
#   ('million', 4),
#   ('week', 4),
#   ('Wednesday', 3),
#   ('U.S.', 3),
#   ('year', 3),
#   ('fell', 2),
#   ('tapering', 2),
#   ('asset', 2),
#   ('inflation', 2),
#   ('EIA', 2),
#   ('report', 2),
#   ('announcement', 2)],
#  [(' ', 24),
#   ('prices', 13),
#   ('oil', 12),
#   ('energy', 9),
#   ('inflation', 7),
#   ('rdquo', 7),
#   ('supply', 6),
#   ('year', 5),
#   ('demand', 5),
#   ('high', 4),
#   ('major', 4),
#   ('analysts', 4),
#   ('banks', 4),
#   ('economic', 4),
#   ('higher', 4),
#   ('asset', 4),
#   ('$', 4),
#   ('recession', 3),
#   ('investment', 3),
#   ('rise', 3),
#   ('market', 3)],
#  [('oil', 27),
#   (' ', 14),
#   ('production', 13),
#   ('$', 11),
#   ('OPEC', 11),
#   ('price', 9),
#   ('100', 8),
#   ('prices', 8),
#   ('U.S.', 7),
#   ('WTI', 4),
#   ('years', 4),
#   ('demand', 4),
#   ('market', 4),
#   ('barrel', 3),
#   ('2014', 3),
#   ('significant', 3),
#   ('reason', 3),
#   ('2008', 3),
#   ('million', 3),
#   ('BPD', 3),
#   ('markets', 3)],
#  [(' ', 7),
#   ('oil', 5),
#   ('China', 4),
#   ('reserve', 4),
#   ('price', 3),
#   ('Chinese', 3),
#   ('supply', 3),
#   ('prices', 3),
#   ('crude', 3),
#   ('news', 3),
#   ('gasoline', 2),
#   ('fuel', 2),
#   ('National', 2),
#   ('Food', 2),
#   ('Strategic', 2),
#   ('Reserve', 2),
#   ('Administration', 2),
#   ('reserves', 2),
#   ('quoted', 2),
#   ('releases', 2),
#   ('Energy', 2)],
#  [(' ', 21),
#   ('gas', 15),
#   ('prices', 13),
#   ('natural', 10),
#   ('inventories', 7),
#   ('oil', 7),
#   ('demand', 6),
#   ('w', 6),
#   ('energy', 6),
#   ('$', 5),
#   ('years', 5),
#   ('crude', 5),
#   ('storage', 5),
#   ('crisis', 5),
#   ('latest', 4),
#   ('average', 4),
#   ('Cushing', 4),
#   ('says', 4),
#   ('increase', 4),
#   ('year', 4),
#   ('seasonal', 3)],
#  [(' ', 8),
#   ('oil', 7),
#   ('$', 6),
#   ('prices', 5),
#   ('weather', 5),
#   ('cold', 4),
#   ('gas', 4),
#   ('said', 4),
#   ('year', 4),
#   ('90', 4),
#   ('barrel', 3),
#   ('Ollenberg', 3),
#   ('end', 3),
#   ('demand', 3),
#   ('hit', 2),
#   ('100', 2),
#   ('winter', 2),
#   ('turns', 2),
#   ('analyst', 2),
#   ('adding', 2),
#   ('natural', 2)],
#  [('China', 8),
#   (' ', 8),
#   ('Monday', 4),
#   ('oil', 4),
#   ('COVID', 3),
#   ('flare', 3),
#   ('market', 3),
#   ('quickly', 3),
#   ('Chinese', 3),
#   ('said', 3),
#   ('demand', 3),
#   ('$', 3),
#   ('residents', 2),
#   ('county', 2),
#   ('lockdown', 2),
#   ('contain', 2),
#   ('new', 2),
#   ('bullish', 2),
#   ('sentiment', 2),
#   ('fresh', 2),
#   ('outbreak', 2)],
#  [(' ', 10),
#   ('oil', 7),
#   ('$', 6),
#   ('Thursday', 6),
#   ('barrels', 6),
#   ('Crude', 5),
#   ('prices', 5),
#   ('year', 5),
#   ('million', 5),
#   ('Wednesday', 4),
#   ('crude', 4),
#   ('inventories', 4),
#   ('Brent', 3),
#   ('early', 3),
#   ('week', 3),
#   ('barrel', 2),
#   ('highest', 2),
#   ('level', 2),
#   ('taking', 2),
#   ('bullish', 2),
#   ('EIA', 2)],
#  [('nbsp', 21),
#   ('oil', 17),
#   ('$', 12),
#   (' ', 10),
#   ('prices', 8),
#   ('said', 7),
#   ('barrel', 6),
#   ('minister', 6),
#   ('100', 5),
#   ('global', 5),
#   ('OPEC', 5),
#   ('Oil', 3),
#   ('group', 3),
#   ('Iraqi', 3),
#   ('demand', 3),
#   ('winter', 3),
#   ('hit', 2),
#   ('2022', 2),
#   ('amid', 2),
#   ('Jabbar', 2),
#   ('Ismaael', 2)],
#  [(' ', 10),
#   ('prices', 6),
#   ('coal', 5),
#   ('$', 5),
#   ('early', 4),
#   ('Wednesday', 4),
#   ('intervention', 4),
#   ('price', 4),
#   ('Oil', 3),
#   ('China', 3),
#   ('Crude', 3),
#   ('Chinese', 3),
#   ('week', 3),
#   ('estimated', 3),
#   ('dropped', 2),
#   ('said', 2),
#   ('considering', 2),
#   ('market', 2),
#   ('reduce', 2),
#   ('record', 2),
#   ('inventory', 2)],
#  [('barrel', 16),
#   (' ', 15),
#   ('2021', 12),
#   ('Saudi', 12),
#   ('November', 9),
#   ('month', 9),
#   ('Basrah', 8),
#   ('ndash', 7),
#   ('cut', 7),
#   ('Aramco', 7),
#   ('prices', 7),
#   ('cargoes', 7),
#   ('Asian', 7),
#   ('production', 6),
#   ('market', 6),
#   ('Graph', 6),
#   ('USD', 6),
#   ('Source', 6),
#   ('Arab', 6),
#   ('Dubai', 6),
#   ('Europe', 6)],
#  [(' ', 12),
#   ('Tuesday', 7),
#   ('said', 7),
#   ('$', 6),
#   ('rdquo', 6),
#   ('prices', 5),
#   ('Monday', 5),
#   ('Oil', 4),
#   ('Crude', 3),
#   ('September', 3),
#   ('demand', 3),
#   ('oil', 3),
#   ('market', 3),
#   ('analysts', 2),
#   ('multi', 2),
#   ('year', 2),
#   ('highs', 2),
#   ('global', 2),
#   ('crunch', 2),
#   ('WTI', 2),
#   ('highest', 2)],
#  [('oil', 13),
#   ('prices', 11),
#   (' ', 10),
#   ('$', 8),
#   ('100', 6),
#   ('barrel', 5),
#   ('going', 4),
#   ('Catsimatidis', 4),
#   ('said', 4),
#   ('demand', 4),
#   ('winter', 3),
#   ('recent', 2),
#   ('weeks', 2),
#   ('looks', 2),
#   ('like', 2),
#   ('food', 2),
#   ('business', 2),
#   ('told', 2),
#   ('FOX', 2),
#   ('Business', 2),
#   ('rdquo', 2)],
#  [(' ', 9),
#   ('Monday', 7),
#   ('$', 7),
#   ('oil', 5),
#   ('gas', 4),
#   ('Brent', 4),
#   ('early', 3),
#   ('energy', 3),
#   ('Europe', 3),
#   ('natural', 3),
#   ('WTI', 3),
#   ('Crude', 3),
#   ('briefly', 3),
#   ('barrel', 3),
#   ('rdquo', 3),
#   ('said', 3),
#   ('Oil', 2),
#   ('prices', 2),
#   ('gains', 2),
#   ('crisis', 2),
#   ('Asia', 2)],
#  [('oil', 11),
#   (' ', 8),
#   ('prices', 6),
#   ('demand', 6),
#   ('bpd', 6),
#   ('said', 5),
#   ('Crude', 4),
#   ('$', 4),
#   ('energy', 4),
#   ('gas', 4),
#   ('IEA', 4),
#   ('Friday', 3),
#   ('WTI', 3),
#   ('weekly', 3),
#   ('switch', 3),
#   ('market', 3),
#   ('Thursday', 3),
#   ('global', 3),
#   ('rdquo', 3),
#   ('year', 3),
#   ('expected', 3)],
#  [(' ', 8),
#   ('variant', 5),
#   ('early', 4),
#   ('Tuesday', 4),
#   ('Omicron', 4),
#   ('oil', 4),
#   ('Monday', 4),
#   ('rdquo', 4),
#   ('Oil', 3),
#   ('prices', 3),
#   ('market', 3),
#   ('demand', 2),
#   ('nbsp', 2),
#   ('Crude', 2),
#   ('$', 2),
#   ('Saudi', 2),
#   ('Arabia', 2),
#   ('optimism', 2),
#   ('official', 2),
#   ('crude', 2),
#   ('selling', 2)],
#  [('oil', 11),
#   ('prices', 9),
#   (' ', 9),
#   ('$', 5),
#   ('100', 5),
#   ('demand', 5),
#   ('said', 5),
#   ('barrel', 4),
#   ('Putin', 4),
#   ('gas', 4),
#   ('Russian', 3),
#   ('OPEC', 3),
#   ('group', 3),
#   ('despite', 3),
#   ('natural', 3),
#   ('winter', 3),
#   ('global', 2),
#   ('hit', 2),
#   ('want', 2),
#   ('market', 2),
#   ('shock', 2)],
#  [(' ', 12),
#   ('oil', 7),
#   ('$', 5),
#   ('prices', 4),
#   ('Bloomberg', 3),
#   ('year', 3),
#   ('timespread', 2),
#   ('futures', 2),
#   ('United', 2),
#   ('States', 2),
#   ('crude', 2),
#   ('According', 2),
#   ('delivery', 2),
#   ('start', 2),
#   ('pump', 2),
#   ('Cushing', 2),
#   ('end', 2),
#   ('market', 2),
#   ('told', 2),
#   ('Oilprice.com', 2),
#   ('Prices', 2)],
#  [(' ', 11),
#   ('$', 7),
#   ('coal', 7),
#   ('gas', 6),
#   ('oil', 6),
#   ('Monday', 5),
#   ('Oil', 4),
#   ('benchmark', 4),
#   ('week', 4),
#   ('prices', 3),
#   ('Europe', 3),
#   ('Crude', 3),
#   ('time', 3),
#   ('power', 3),
#   ('high', 3),
#   ('Gas', 3),
#   ('extended', 2),
#   ('rally', 2),
#   ('U.S.', 2),
#   ('topping', 2),
#   ('trading', 2)],
#  [(' ', 12),
#   ('prices', 7),
#   ('supply', 6),
#   ('oil', 6),
#   ('gas', 5),
#   ('winter', 5),
#   ('Friday', 4),
#   ('$', 4),
#   ('Oil', 3),
#   ('natural', 3),
#   ('Crude', 3),
#   ('demand', 3),
#   ('OPEC', 3),
#   ('crude', 3),
#   ('Energy', 3),
#   ('early', 2),
#   ('headed', 2),
#   ('week', 2),
#   ('U.S.', 2),
#   ('benchmark', 2),
#   ('WTI', 2)],
#  [(' ', 17),
#   ('oil', 11),
#   ('bbl', 10),
#   ('OPEC', 10),
#   ('prices', 8),
#   ('$', 7),
#   ('USD', 7),
#   ('price', 6),
#   ('market', 6),
#   ('Stanchart', 5),
#   ('economy', 4),
#   ('gas', 3),
#   ('rally', 3),
#   ('Global', 3),
#   ('higher', 3),
#   ('bearish', 3),
#   ('80', 3),
#   ('2022', 3),
#   ('Energy', 3),
#   ('markets', 3),
#   ('Wall', 2)],
#  [(' ', 9),
#   ('prices', 7),
#   ('oil', 5),
#   ('U.S.', 5),
#   ('Energy', 4),
#   ('administration', 4),
#   ('gas', 3),
#   ('year', 3),
#   ('OPEC', 3),
#   ('release', 2),
#   ('crude', 2),
#   ('emergency', 2),
#   ('reserve', 2),
#   ('pump', 2),
#   ('ban', 2),
#   ('Granholm', 2),
#   ('said', 2),
#   ('tools', 2),
#   ('gasoline', 2),
#   ('AAA', 2),
#   ('earlier', 2)],
#  [(' ', 11),
#   ('oil', 8),
#   ('bpd', 6),
#   ('prices', 6),
#   ('million', 6),
#   ('Aramco', 4),
#   ('$', 4),
#   ('cut', 3),
#   ('crude', 3),
#   ('price', 3),
#   ('barrel', 3),
#   ('said', 3),
#   ('gas', 3),
#   ('demand', 3),
#   ('capacity', 3),
#   ('13', 3),
#   ('selling', 2),
#   ('buyers', 2),
#   ('rise', 2),
#   ('OPEC', 2),
#   ('total', 2)],
#  [(' ', 27),
#   ('oil', 20),
#   ('prices', 15),
#   ('inflation', 15),
#   ('$', 14),
#   ('U.S.', 7),
#   ('high', 7),
#   ('year', 6),
#   ('gas', 6),
#   ('government', 5),
#   ('price', 5),
#   ('Oil', 5),
#   ('Biden', 5),
#   ('4', 4),
#   ('economy', 4),
#   ('consumer', 4),
#   ('spending', 4),
#   ('dollar', 4),
#   ('pandemic', 3),
#   ('economic', 3),
#   ('experts', 3)],
#  [(' ', 9),
#   ('oil', 7),
#   ('prices', 6),
#   ('Tuesday', 5),
#   ('gas', 5),
#   ('level', 4),
#   ('$', 4),
#   ('year', 4),
#   ('said', 4),
#   ('price', 3),
#   ('highest', 3),
#   ('high', 3),
#   ('rdquo', 3),
#   ('Asia', 3),
#   ('benchmark', 2),
#   ('U.S.', 2),
#   ('morning', 2),
#   ('seven', 2),
#   ('OPEC', 2),
#   ('supply', 2),
#   ('757', 2)],
#  [('prices', 12),
#   ('oil', 11),
#   (' ', 9),
#   ('$', 4),
#   ('energy', 4),
#   ('gas', 3),
#   ('winter', 3),
#   ('100', 3),
#   ('barrel', 3),
#   ('crisis', 3),
#   ('Bank', 3),
#   ('America', 3),
#   ('says', 3),
#   ('high', 3),
#   ('inflationary', 3),
#   ('BofA', 3),
#   ('demand', 3),
#   ('rdquo', 3),
#   ('natural', 2),
#   ('reopening', 2),
#   ('international', 2)],
#  [(' ', 24),
#   ('oil', 16),
#   ('bbl', 13),
#   ('USD', 13),
#   ('w', 10),
#   ('million', 8),
#   ('production', 7),
#   ('Brent', 6),
#   ('80', 6),
#   ('crude', 6),
#   ('barrels', 6),
#   ('September', 6),
#   ('market', 6),
#   ('OPEC', 6),
#   ('time', 5),
#   ('inventories', 5),
#   ('week', 5),
#   ('prices', 5),
#   ('rig', 5),
#   ('U.S.', 4),
#   ('Stanchart', 4)],
#  [('prices', 10),
#   ('oil', 9),
#   (' ', 9),
#   ('$', 7),
#   ('year', 6),
#   ('barrel', 5),
#   ('Europe', 5),
#   ('options', 4),
#   ('end', 4),
#   ('energy', 4),
#   ('200', 3),
#   ('Asia', 3),
#   ('Brent', 3),
#   ('record', 3),
#   ('months', 3),
#   ('month', 3),
#   ('traders', 2),
#   ('betting', 2),
#   ('winter', 2),
#   ('2022', 2),
#   ('data', 2)],
#  [('gas', 9),
#   (' ', 8),
#   ('oil', 7),
#   ('$', 6),
#   ('prices', 5),
#   ('natural', 5),
#   ('demand', 5),
#   ('market', 4),
#   ('Tuesday', 3),
#   ('Crude', 3),
#   ('time', 3),
#   ('crude', 3),
#   ('benchmark', 3),
#   ('highest', 3),
#   ('level', 3),
#   ('Europe', 3),
#   ('Asia', 3),
#   ('early', 2),
#   ('Brent', 2),
#   ('barrel', 2),
#   ('years', 2)],
#  [('oil', 11),
#   ('$', 10),
#   ('barrel', 8),
#   (' ', 8),
#   ('supply', 7),
#   ('Goldman', 7),
#   ('demand', 6),
#   ('prices', 5),
#   ('global', 5),
#   ('price', 4),
#   ('forecast', 4),
#   ('Brent', 4),
#   ('winter', 4),
#   ('recovery', 3),
#   ('Sachs', 3),
#   ('90', 3),
#   ('80', 3),
#   ('expected', 3),
#   ('end', 3),
#   ('year', 3),
#   ('week', 3)],
#  [(' ', 8),
#   ('oil', 7),
#   ('$', 6),
#   ('prices', 5),
#   ('supply', 5),
#   ('demand', 5),
#   ('winter', 4),
#   ('expected', 4),
#   ('Oil', 3),
#   ('Monday', 3),
#   ('Brent', 3),
#   ('Crude', 3),
#   ('barrel', 3),
#   ('global', 3),
#   ('energy', 3),
#   ('said', 3),
#   ('OPEC', 3),
#   ('early', 2),
#   ('80', 2),
#   ('WTI', 2),
#   ('U.S.', 2)],
#  [(' ', 24),
#   ('oil', 13),
#   ('$', 11),
#   ('bbl', 9),
#   ('crude', 8),
#   ('says', 7),
#   ('McGlone', 6),
#   ('Stanchart', 6),
#   ('prices', 5),
#   ('high', 5),
#   ('commodities', 5),
#   ('stones', 5),
#   ('growing', 4),
#   ('U.S.', 4),
#   ('mean', 4),
#   ('market', 4),
#   ('price', 4),
#   ('skimming', 4),
#   ('major', 3),
#   ('Brent', 3),
#   ('2018', 3)],
#  [(' ', 9),
#   ('oil', 6),
#   ('$', 5),
#   ('prices', 4),
#   ('gas', 4),
#   ('market', 4),
#   ('gains', 3),
#   ('U.S.', 3),
#   ('crude', 3),
#   ('boost', 3),
#   ('demand', 3),
#   ('barrel', 3),
#   ('Brent', 3),
#   ('high', 3),
#   ('production', 3),
#   ('rdquo', 3),
#   ('Friday', 2),
#   ('week', 2),
#   ('inventories', 2),
#   ('dropped', 2),
#   ('year', 2)],
#  [('demand', 11),
#   (' ', 9),
#   ('said', 7),
#   ('oil', 6),
#   ('gas', 5),
#   ('rdquo', 4),
#   ('$', 3),
#   ('year', 3),
#   ('crude', 3),
#   ('Crude', 2),
#   ('barrel', 2),
#   ('end', 2),
#   ('Vitol', 2),
#   ('chief', 2),
#   ('executive', 2),
#   ('Hardy', 2),
#   ('told', 2),
#   ('Bloomberg', 2),
#   ('According', 2),
#   ('supply', 2),
#   ('additional', 2)],
#  [('oil', 12),
#   (' ', 11),
#   ('demand', 5),
#   ('$', 5),
#   ('100', 5),
#   ('said', 5),
#   ('prices', 4),
#   ('Trafigura', 4),
#   ('rdquo', 4),
#   ('Rahim', 4),
#   ('Argus', 4),
#   ('year', 4),
#   ('chief', 3),
#   ('conditions', 3),
#   ('U.S.', 3),
#   ('told', 3),
#   ('end', 2),
#   ('worldrsquos', 2),
#   ('largest', 2),
#   ('traders', 2),
#   ('market', 2)],
#  [(' ', 8),
#   ('oil', 8),
#   ('$', 5),
#   ('winter', 5),
#   ('natural', 5),
#   ('gas', 5),
#   ('weather', 4),
#   ('prices', 4),
#   ('crude', 4),
#   ('barrel', 3),
#   ('colder', 3),
#   ('power', 3),
#   ('Europe', 3),
#   ('demand', 3),
#   ('trading', 3),
#   ('Brent', 2),
#   ('Goldman', 2),
#   ('said', 2),
#   ('Wednesday', 2),
#   ('effect', 2),
#   ('United', 2)],
#  [(' ', 7),
#   ('oil', 5),
#   ('$', 5),
#   ('OPEC', 5),
#   ('crude', 4),
#   ('barrel', 4),
#   ('analysts', 4),
#   ('bank', 3),
#   ('said', 3),
#   ('note', 3),
#   ('surplus', 3),
#   ('Morgan', 3),
#   ('2022', 3),
#   ('quarter', 3),
#   ('market', 3),
#   ('Deutsche', 2),
#   ('prices', 2),
#   ('year', 2),
#   ('pause', 2),
#   ('JP', 2),
#   ('forecast', 2)],
#  [(' ', 8),
#   ('prices', 7),
#   ('gas', 6),
#   ('oil', 5),
#   ('WD-143', 5),
#   ('platform', 5),
#   ('Tuesday', 4),
#   ('market', 4),
#   ('facilities', 4),
#   ('natural', 3),
#   ('potential', 3),
#   ('said', 3),
#   ('production', 3),
#   ('Oil', 2),
#   ('early', 2),
#   ('global', 2),
#   ('crunch', 2),
#   ('higher', 2),
#   ('demand', 2),
#   ('winter', 2),
#   ('season', 2)],
#  [(' ', 7),
#   ('oil', 7),
#   ('U.S.', 6),
#   ('week', 5),
#   ('$', 5),
#   ('prices', 4),
#   ('Monday', 4),
#   ('market', 4),
#   ('early', 3),
#   ('dollar', 3),
#   ('meeting', 3),
#   ('announce', 3),
#   ('tapering', 3),
#   ('production', 3),
#   ('Crude', 2),
#   ('day', 2),
#   ('broader', 2),
#   ('start', 2),
#   ('asset', 2),
#   ('Wednesday', 2),
#   ('risk', 2)],
#  [('prices', 9),
#   ('oil', 9),
#   ('gas', 8),
#   ('winter', 6),
#   ('colder', 5),
#   ('$', 5),
#   ('barrel', 5),
#   (' ', 5),
#   ('natural', 4),
#   ('Goldman', 3),
#   ('usual', 3),
#   ('global', 3),
#   ('market', 3),
#   ('months', 3),
#   ('year', 2),
#   ('potential', 2),
#   ('quarter', 2),
#   ('Sachs', 2),
#   ('price', 2),
#   ('combined', 2),
#   ('upside', 2)],
#  [(' ', 24),
#   ('oil', 13),
#   ('gas', 11),
#   ('price', 8),
#   ('plastics', 8),
#   ('prices', 7),
#   ('year', 7),
#   ('natural', 7),
#   ('energy', 6),
#   ('$', 5),
#   ('high', 5),
#   ('production', 5),
#   ('plastic', 5),
#   ('plants', 4),
#   ('higher', 4),
#   ('Natural', 4),
#   ('crisis', 4),
#   ('According', 3),
#   ('feeling', 3),
#   ('forced', 3),
#   ('major', 3)],
#  [(' ', 8),
#   ('prices', 7),
#   ('oil', 7),
#   ('weekly', 4),
#   ('Friday', 4),
#   ('week', 4),
#   ('demand', 4),
#   ('natural', 3),
#   ('gas', 3),
#   ('energy', 3),
#   ('seven', 3),
#   ('Wednesday', 3),
#   ('said', 3),
#   ('crude', 3),
#   ('rdquo', 3),
#   ('Oil', 2),
#   ('fourth', 2),
#   ('consecutive', 2),
#   ('gain', 2),
#   ('early', 2),
#   ('surging', 2)],
#  [('Wirth', 6),
#   (' ', 6),
#   ('oil', 3),
#   ('companies', 3),
#   ('interview', 3),
#   ('rdquo', 3),
#   ('said', 3),
#   ('create', 3),
#   ('wind', 3),
#   ('solar', 3),
#   ('gas', 2),
#   ('told', 2),
#   ('Bloomberg', 2),
#   ('investors', 2),
#   ('term', 2),
#   ('future', 2),
#   ('returns', 2),
#   ('equity', 2),
#   ('markets', 2),
#   ('Irsquom', 2),
#   ('investor', 2)],
#  [('shale', 18),
#   (' ', 12),
#   ('production', 11),
#   ('oil', 10),
#   ('companies', 10),
#   ('U.S.', 9),
#   ('investors', 6),
#   ('drilling', 5),
#   ('new', 5),
#   ('industry', 4),
#   ('wells', 4),
#   ('spending', 4),
#   ('cash', 4),
#   ('Energy', 4),
#   ('months', 3),
#   ('drillers', 3),
#   ('recovery', 3),
#   ('demand', 3),
#   ('lot', 3),
#   ('inventory', 3),
#   ('citing', 3)],
#  [('demand', 8),
#   ('oil', 7),
#   ('Tuesday', 6),
#   (' ', 6),
#   ('prices', 4),
#   ('IEA', 4),
#   ('day', 4),
#   ('Texas', 4),
#   ('Oil', 3),
#   ('early', 3),
#   ('said', 3),
#   ('rebound', 3),
#   ('storm', 3),
#   ('Gulf', 3),
#   ('Crude', 3),
#   ('$', 3),
#   ('bpd', 3),
#   ('highest', 2),
#   ('level', 2),
#   ('weeks', 2),
#   ('expects', 2)],
#  [(' ', 9),
#   ('oil', 7),
#   ('months', 6),
#   ('prices', 5),
#   ('$', 5),
#   ('100', 5),
#   ('winter', 4),
#   ('energy', 4),
#   ('barrel', 3),
#   ('markets', 3),
#   ('Bank', 3),
#   ('America', 3),
#   ('demand', 3),
#   ('said', 3),
#   ('BofA', 3),
#   ('June', 3),
#   ('analysts', 3),
#   ('Oil', 2),
#   ('hit', 2),
#   ('colder', 2),
#   ('important', 2)],
#  [(' ', 9),
#   ('oil', 7),
#   ('Friday', 5),
#   ('Chinese', 4),
#   ('Thursday', 4),
#   ('demand', 4),
#   ('crude', 4),
#   ('prices', 3),
#   ('U.S.', 3),
#   ('$', 3),
#   ('markets', 3),
#   ('rdquo', 3),
#   ('production', 3),
#   ('release', 3),
#   ('Oil', 2),
#   ('bullish', 2),
#   ('sentiment', 2),
#   ('strategic', 2),
#   ('Crude', 2),
#   ('trade', 2),
#   ('President', 2)],
#  [(' ', 38),
#   ('oil', 26),
#   ('$', 19),
#   ('bbl', 13),
#   ('day', 9),
#   ('shale', 8),
#   ('gas', 8),
#   ('previous', 7),
#   ('market', 7),
#   ('companies', 7),
#   ('Stanchart', 6),
#   ('high', 6),
#   ('production', 5),
#   ('price', 5),
#   ('days', 5),
#   ('trading', 5),
#   ('2022', 5),
#   ('ESG', 5),
#   ('investments', 5),
#   ('BlackRock', 5),
#   ('prices', 4)],
#  [('oil', 12),
#   ('$', 10),
#   ('barrel', 9),
#   (' ', 8),
#   ('prices', 6),
#   ('Brent', 5),
#   ('energy', 4),
#   ('said', 4),
#   ('ndash', 4),
#   ('Crude', 3),
#   ('end', 3),
#   ('Energy', 3),
#   ('new', 3),
#   ('200', 3),
#   ('higher', 3),
#   ('OPEC', 3),
#   ('production', 3),
#   ('shale', 3),
#   ('quarter', 3),
#   ('levels', 3),
#   ('rdquo', 3)],
#  [('China', 8),
#   ('prices', 6),
#   ('oil', 5),
#   ('high', 4),
#   ('raw', 4),
#   (' ', 4),
#   ('August', 4),
#   ('price', 3),
#   ('material', 3),
#   ('year', 3),
#   ('recent', 3),
#   ('months', 3),
#   ('   ', 3),
#   ('release', 3),
#   ('bbl', 3),
#   ('producer', 2),
#   ('inflation', 2),
#   ('Beijing', 2),
#   ('step', 2),
#   ('national', 2),
#   ('crude', 2)],
#  [(' ', 9),
#   ('oil', 8),
#   ('production', 5),
#   ('U.S.', 5),
#   ('percent', 4),
#   ('Wednesday', 3),
#   ('total', 3),
#   ('Gulf', 3),
#   ('shut', 3),
#   ('Hurricane', 3),
#   ('Ida', 3),
#   ('$', 3),
#   ('Es', 3),
#   ('Sider', 3),
#   ('Oil', 2),
#   ('prices', 2),
#   ('early', 2),
#   ('crude', 2),
#   ('Mexico', 2),
#   ('Louisiana', 2),
#   ('price', 2)],
#  [(' ', 10),
#   ('Russia', 7),
#   ('$', 6),
#   ('oil', 5),
#   ('barrel', 5),
#   ('Alekperov', 5),
#   ('OPEC', 4),
#   ('Lukoil', 4),
#   ('projects', 4),
#   ('percent', 4),
#   ('Brent', 3),
#   ('said', 3),
#   ('investments', 3),
#   ('outside', 3),
#   ('alliance', 2),
#   ('prices', 2),
#   ('65', 2),
#   ('75', 2),
#   ('price', 2),
#   ('told', 2),
#   ('Russian', 2)],
#  [('oil', 10),
#   (' ', 9),
#   ('prices', 6),
#   ('crude', 6),
#   ('U.S.', 5),
#   ('month', 4),
#   ('Tuesday', 3),
#   ('dollar', 3),
#   ('demand', 3),
#   ('market', 3),
#   ('Brent', 3),
#   ('imports', 3),
#   ('August', 3),
#   ('million', 3),
#   ('bpd', 3),
#   ('Gulf', 3),
#   ('production', 3),
#   ('Oil', 2),
#   ('morning', 2),
#   ('weighed', 2),
#   ('benchmark', 2)],
#  [(' ', 9),
#   ('Fed', 6),
#   ('oil', 6),
#   ('prices', 5),
#   ('tapering', 4),
#   ('August', 4),
#   ('$', 3),
#   ('jobs', 3),
#   ('WTI', 2),
#   ('weaker', 2),
#   ('expected', 2),
#   ('report', 2),
#   ('likely', 2),
#   ('losing', 2),
#   ('streak', 2),
#   ('data', 2),
#   ('push', 2),
#   ('taper', 2),
#   ('news', 2),
#   ('year', 2),
#   ('breaking', 1)],
#  [(' ', 7),
#   ('demand', 6),
#   ('prices', 5),
#   ('$', 5),
#   ('Thursday', 4),
#   ('oil', 4),
#   ('Crude', 3),
#   ('70', 3),
#   ('U.S.', 3),
#   ('inventory', 3),
#   ('crude', 3),
#   ('reported', 3),
#   ('draw', 3),
#   ('record', 3),
#   ('million', 3),
#   ('barrels', 3),
#   ('week', 3),
#   ('rdquo', 3),
#   ('Oil', 2),
#   ('early', 2),
#   ('WTI', 2)],
#  [(' ', 10),
#   ('oil', 8),
#   ('demand', 5),
#   ('Reuters', 5),
#   ('$', 5),
#   ('2021', 4),
#   ('year', 4),
#   ('set', 4),
#   ('prices', 3),
#   ('told', 3),
#   ('poll', 3),
#   ('forecast', 3),
#   ('Crude', 3),
#   ('month', 3),
#   ('Delta', 3),
#   ('variant', 3),
#   ('surge', 2),
#   ('COVID', 2),
#   ('globally', 2),
#   ('slow', 2),
#   ('recovery', 2)],
#  [(' ', 11),
#   ('oil', 6),
#   ('month', 5),
#   ('Oil', 4),
#   ('production', 4),
#   ('bpd', 4),
#   ('prices', 3),
#   ('likely', 3),
#   ('percent', 3),
#   ('Covid-19', 3),
#   ('refining', 3),
#   ('Gulf', 3),
#   ('OPEC', 3),
#   ('end', 2),
#   ('started', 2),
#   ('$', 2),
#   ('barrel', 2),
#   ('U.S.', 2),
#   ('markets', 2),
#   ('sources', 2),
#   ('fourth', 2)],
#  [('oil', 6),
#   (' ', 6),
#   ('new', 3),
#   ('$', 3),
#   ('weeks', 2),
#   ('news', 2),
#   ('SPR', 2),
#   ('release', 2),
#   ('variant', 2),
#   ('According', 2),
#   ('Bloomberg', 2),
#   ('percent', 2),
#   ('Omicron', 2),
#   ('OPEC', 2),
#   ('January', 2),
#   ('demand', 2),
#   ('U.S.', 2),
#   ('end', 2),
#   ('United', 2),
#   ('detected', 2),
#   ('suggest', 2)],
#  [(' ', 7),
#   ('oil', 5),
#   ('crude', 3),
#   ('bullish', 3),
#   ('major', 3),
#   ('rally', 3),
#   ('times', 3),
#   ('strategist', 3),
#   ('told', 3),
#   ('cross', 3),
#   ('chart', 3),
#   ('Maley', 3),
#   ('energy', 3),
#   ('market', 3),
#   ('Delta', 3),
#   ('percent', 2),
#   ('pattern', 2),
#   ('asset', 2),
#   ('century', 2),
#   ('CNBC', 2),
#   ('called', 2)],
#  [(' ', 9),
#   ('Pemex', 8),
#   ('fire', 8),
#   ('production', 7),
#   ('bpd', 4),
#   ('oil', 4),
#   ('gas', 4),
#   ('lost', 3),
#   ('platform', 3),
#   ('outage', 3),
#   ('Reuters', 3),
#   ('Romero', 3),
#   ('caused', 3),
#   ('said', 3),
#   ('Mexico', 2),
#   ('restored', 2),
#   ('erupted', 2),
#   ('offshore', 2),
#   ('reported', 2),
#   ('result', 2),
#   ('Ku', 2)],
#  [('oil', 15),
#   (' ', 13),
#   ('demand', 7),
#   ('week', 7),
#   ('news', 5),
#   ('Covid-19', 4),
#   ('prices', 4),
#   ('Reuters', 4),
#   ('million', 4),
#   ('barrels', 4),
#   ('infections', 3),
#   ('world', 3),
#   ('growing', 3),
#   ('vaccine', 3),
#   ('China', 3),
#   ('U.S.', 3),
#   ('traders', 3),
#   ('selling', 3),
#   ('analyst', 3),
#   ('remains', 3),
#   ('travel', 3)],
#  [(' ', 8),
#   ('oil', 7),
#   ('$', 6),
#   ('prices', 5),
#   ('crude', 4),
#   ('platform', 4),
#   ('early', 3),
#   ('Tuesday', 3),
#   ('demand', 3),
#   ('outage', 3),
#   ('Brent', 3),
#   ('market', 3),
#   ('approval', 3),
#   ('vaccine', 3),
#   ('Oil', 2),
#   ('extended', 2),
#   ('Mondayrsquos', 2),
#   ('5', 2),
#   ('major', 2),
#   ('supply', 2),
#   ('Crude', 2)],
#  [('oil', 8),
#   (' ', 8),
#   ('demand', 7),
#   ('market', 4),
#   ('prices', 3),
#   ('signal', 3),
#   ('stimulus', 3),
#   ('Crude', 3),
#   ('end', 3),
#   ('dollar', 3),
#   ('rdquo', 3),
#   ('Friday', 2),
#   ('growing', 2),
#   ('concerns', 2),
#   ('global', 2),
#   ('Fed', 2),
#   ('$', 2),
#   ('week', 2),
#   ('surging', 2),
#   ('cases', 2),
#   ('major', 2)],
#  [(' ', 22),
#   ('oil', 12),
#   ('bbl', 12),
#   ('$', 11),
#   ('high', 8),
#   ('day', 7),
#   ('Stanchart', 6),
#   ('skimming', 5),
#   ('stones', 5),
#   ('cycle', 5),
#   ('Brent', 5),
#   ('dollar', 5),
#   ('days', 5),
#   ('previous', 5),
#   ('U.S.', 4),
#   ('price', 4),
#   ('sub', 4),
#   ('trading', 4),
#   ('Biden', 3),
#   ('prices', 3),
#   ('fact', 3)],
#  [('oil', 6),
#   (' ', 5),
#   ('prices', 4),
#   ('$', 3),
#   ('month', 3),
#   ('concern', 3),
#   ('start', 2),
#   ('winding', 2),
#   ('bond', 2),
#   ('buying', 2),
#   ('economy', 2),
#   ('Fed', 2),
#   ('report', 2),
#   ('coronavirus', 2),
#   ('120', 2),
#   ('billion', 2),
#   ('monthly', 2),
#   ('According', 2),
#   ('latest', 2),
#   ('crude', 2),
#   ('West', 1)],
#  [(' ', 17),
#   ('oil', 12),
#   ('prices', 12),
#   ('output', 6),
#   ('demand', 5),
#   ('crude', 5),
#   ('year', 5),
#   ('July', 4),
#   ('OPEC', 4),
#   ('U.S.', 4),
#   ('week', 4),
#   ('pre', 3),
#   ('pandemic', 3),
#   ('month', 3),
#   ('rates', 3),
#   ('months', 3),
#   ('rig', 3),
#   ('count', 3),
#   ('confidence', 3),
#   ('global', 3),
#   ('price', 2)],
#  [(' ', 7),
#   ('U.S.', 5),
#   ('oil', 4),
#   ('Tuesday', 4),
#   ('demand', 4),
#   ('week', 4),
#   ('prices', 3),
#   ('$', 3),
#   ('Monday', 3),
#   ('said', 3),
#   ('barrels', 3),
#   ('million', 3),
#   ('gasoline', 3),
#   ('day', 2),
#   ('Crude', 2),
#   ('concerns', 2),
#   ('crude', 2),
#   ('rdquo', 2),
#   ('Vanda', 2),
#   ('Insights', 2),
#   ('shale', 2)],
#  [('US$', 19),
#   ('price', 17),
#   ('oil', 13),
#   ('barrel', 10),
#   ('U.S.', 10),
#   ('gasoline', 10),
#   ('prices', 8),
#   ('crude', 7),
#   ('OPEC', 7),
#   ('Brent', 6),
#   (' ', 6),
#   ('gallon', 6),
#   ('election', 6),
#   ('President', 5),
#   ('cap', 5),
#   ('years', 5),
#   ('reasons', 4),
#   ('economy', 4),
#   ('75', 3),
#   ('80', 3),
#   ('2014', 3)],
#  [(' ', 9),
#   ('demand', 6),
#   ('China', 5),
#   ('data', 4),
#   ('Monday', 3),
#   ('U.S.', 3),
#   ('consumer', 3),
#   ('oil', 3),
#   ('fuel', 3),
#   ('economic', 3),
#   ('July', 3),
#   ('Chinese', 3),
#   ('said', 3),
#   ('Consumers', 3),
#   ('prices', 2),
#   ('percent', 2),
#   ('weak', 2),
#   ('economy', 2),
#   ('confidence', 2),
#   ('Crude', 2),
#   ('$', 2)],
#  [(' ', 8),
#   ('oil', 6),
#   ('prices', 5),
#   ('demand', 5),
#   ('key', 4),
#   ('port', 4),
#   ('said', 4),
#   ('second', 3),
#   ('Friday', 3),
#   ('China', 3),
#   ('Asia', 3),
#   ('rdquo', 3),
#   ('crude', 3),
#   ('Oil', 2),
#   ('hit', 2),
#   ('terminal', 2),
#   ('busiest', 2),
#   ('world', 2),
#   ('Crude', 2),
#   ('$', 2),
#   ('Thursday', 2)],
#  [('oil', 9),
#   (' ', 7),
#   ('demand', 6),
#   ('$', 6),
#   ('prices', 5),
#   ('market', 5),
#   ('Monday', 4),
#   ('Tuesday', 4),
#   ('crude', 3),
#   ('price', 3),
#   ('Brent', 3),
#   ('OPEC', 3),
#   ('low', 2),
#   ('weakness', 2),
#   ('importer', 2),
#   ('Crude', 2),
#   ('day', 2),
#   ('COVID', 2),
#   ('July', 2),
#   ('following', 2),
#   ('Oil', 2)],
#  [('$', 16),
#   ('billion', 16),
#   (' ', 9),
#   ('year', 6),
#   ('Aramco', 5),
#   ('percent', 4),
#   ('second', 4),
#   ('quarter', 4),
#   ('increase', 3),
#   ('net', 3),
#   ('half', 3),
#   ('earlier', 3),
#   ('dividend', 3),
#   ('pipeline', 3),
#   ('business', 3),
#   ('Saudi', 2),
#   ('reported', 2),
#   ('profits', 2),
#   ('company', 2),
#   ('cash', 2),
#   ('flow', 2)],
#  [('oil', 10),
#   (' ', 6),
#   ('Saudi', 5),
#   ('prices', 5),
#   ('latest', 3),
#   ('year', 3),
#   ('Chinarsquos', 3),
#   ('raised', 2),
#   ('selling', 2),
#   ('crude', 2),
#   ('$', 2),
#   ('month', 2),
#   ('Bloomberg', 2),
#   ('largest', 2),
#   ('OPEC', 2),
#   ('biggest', 2),
#   ('demand', 2),
#   ('resurgence', 2),
#   ('likely', 2),
#   ('competitive', 2),
#   ('alternatives', 2)],
#  [(' ', 7),
#   ('cases', 5),
#   ('oil', 5),
#   ('China', 5),
#   ('travel', 4),
#   ('demand', 4),
#   ('Asia', 4),
#   ('new', 4),
#   ('worst', 3),
#   ('fuel', 3),
#   ('prices', 2),
#   ('early', 2),
#   ('Friday', 2),
#   ('March', 2),
#   ('COVID', 2),
#   ('Crude', 2),
#   ('$', 2),
#   ('week', 2),
#   ('Delta', 2),
#   ('variant', 2),
#   ('rest', 2)],
#  [('oil', 9),
#   (' ', 8),
#   ('prices', 6),
#   ('Thursday', 4),
#   ('demand', 4),
#   ('NYSE', 4),
#   ('crude', 3),
#   ('Oil', 2),
#   ('morning', 2),
#   ('energy', 2),
#   ('stocks', 2),
#   ('higher', 2),
#   ('concerns', 2),
#   ('rising', 2),
#   ('COVID', 2),
#   ('cases', 2),
#   ('early', 2),
#   ('continued', 2),
#   ('new', 2),
#   ('EDT', 2),
#   ('Crude', 2)],
#  [(' ', 29),
#   ('Exxon', 14),
#   ('shale', 12),
#   ('$', 11),
#   ('oil', 10),
#   ('production', 10),
#   ('U.S.', 8),
#   ('Y', 8),
#   ('earnings', 7),
#   ('company', 7),
#   ('gas', 6),
#   ('years', 6),
#   ('says', 5),
#   ('debt', 5),
#   ('prices', 5),
#   ('year', 4),
#   ('day', 4),
#   ('Permian', 4),
#   ('cash', 4),
#   ('record', 4),
#   ('1', 4)],
#  [('$', 10),
#   (' ', 9),
#   ('oil', 8),
#   ('Saudi', 8),
#   ('Asia', 8),
#   ('barrel', 8),
#   ('price', 7),
#   ('September', 6),
#   ('Aramco', 6),
#   ('crude', 5),
#   ('grades', 5),
#   ('raised', 4),
#   ('prices', 4),
#   ('Middle', 4),
#   ('Arab', 4),
#   ('expected', 3),
#   ('premium', 3),
#   ('going', 3),
#   ('pricing', 3),
#   ('OSPs', 3),
#   ('Light', 3)],
#  [(' ', 9),
#   ('Tuesday', 6),
#   ('variant', 6),
#   ('Delta', 5),
#   ('China', 4),
#   ('rdquo', 4),
#   ('Crude', 3),
#   ('$', 3),
#   ('early', 3),
#   ('cases', 3),
#   ('spread', 3),
#   ('said', 3),
#   ('U.S.', 2),
#   ('WTI', 2),
#   ('day', 2),
#   ('sell', 2),
#   ('economies', 2),
#   ('prices', 2),
#   ('3', 2),
#   ('Chinese', 2),
#   ('according', 2)],
#  [(' ', 6),
#   ('oil', 5),
#   ('markets', 4),
#   ('demand', 4),
#   ('Iran', 4),
#   ('U.S.', 4),
#   ('expectations', 3),
#   ('attack', 3),
#   ('prices', 3),
#   ('additional', 2),
#   ('strong', 2),
#   ('concerns', 2),
#   ('believe', 2),
#   ('Eberhart', 2),
#   ('Canary', 2),
#   ('nuclear', 2),
#   ('week', 2),
#   ('killed', 2),
#   ('said', 2),
#   ('Secretary', 2),
#   ('Blinken', 2)],
#  [(' ', 10),
#   ('oil', 9),
#   ('$', 4),
#   ('Delta', 4),
#   ('variant', 4),
#   ('Monday', 3),
#   ('number', 3),
#   ('demand', 3),
#   ('vaccinated', 3),
#   ('prices', 2),
#   ('started', 2),
#   ('trading', 2),
#   ('Mondayrsquos', 2),
#   ('barrel', 2),
#   ('coronavirus', 2),
#   ('importer', 2),
#   ('spread', 2),
#   ('outbreak', 2),
#   ('increase', 2),
#   ('people', 2),
#   ('surrounding', 2)],
#  [(' ', 10),
#   ('oil', 5),
#   ('Monday', 4),
#   ('gains', 4),
#   ('OPEC', 4),
#   ('early', 3),
#   ('August', 3),
#   ('higher', 3),
#   ('Friday', 3),
#   ('rdquo', 3),
#   ('said', 3),
#   ('market', 3),
#   ('China', 3),
#   ('bpd', 3),
#   ('attack', 3),
#   ('Oil', 2),
#   ('prices', 2),
#   ('start', 2),
#   ('fourth', 2),
#   ('month', 2),
#   ('July', 2)],
#  [('$', 7),
#   ('prices', 7),
#   (' ', 7),
#   ('Brent', 5),
#   ('oil', 5),
#   ('Reuters', 5),
#   ('analysts', 4),
#   ('barrel', 4),
#   ('year', 4),
#   ('poll', 4),
#   ('believe', 3),
#   ('Crude', 3),
#   ('economists', 2),
#   ('rest', 2),
#   ('80', 2),
#   ('COVID', 2),
#   ('variants', 2),
#   ('Friday', 2),
#   ('expected', 2),
#   ('higher', 2),
#   ('price', 2)],
#  [(' ', 10),
#   ('Monday', 8),
#   ('early', 6),
#   ('market', 6),
#   ('variant', 5),
#   ('prices', 4),
#   ('percent', 4),
#   ('Delta', 4),
#   ('rdquo', 4),
#   ('key', 4),
#   ('week', 3),
#   ('said', 3),
#   ('oil', 3),
#   ('demand', 3),
#   ('trading', 2),
#   ('slightly', 2),
#   ('fallen', 2),
#   ('1', 2),
#   ('Asia', 2),
#   ('factor', 2),
#   ('tight', 2)],
#  [('oil', 18),
#   (' ', 13),
#   ('market', 11),
#   ('volatility', 7),
#   ('prices', 7),
#   ('price', 5),
#   ('OPEC', 5),
#   ('demand', 5),
#   ('$', 4),
#   ('traders', 4),
#   ('participants', 4),
#   ('U.S.', 3),
#   ('options', 3),
#   ('coming', 3),
#   ('data', 3),
#   ('recovery', 3),
#   ('Monday', 3),
#   ('Delta', 3),
#   ('variant', 3),
#   ('generally', 3),
#   ('period', 2)],
#  [('week', 11),
#   ('million', 8),
#   (' ', 8),
#   ('barrels', 7),
#   ('inventory', 5),
#   ('oil', 4),
#   ('build', 4),
#   ('July', 4),
#   ('compared', 4),
#   ('previous', 4),
#   ('prices', 3),
#   ('crude', 3),
#   ('16', 3),
#   ('reported', 3),
#   ('$', 3),
#   ('gasoline', 3),
#   ('bpd', 3),
#   ('draw', 2),
#   ('barrel', 2),
#   ('day', 2),
#   ('demand', 2)],
#  [(' ', 11),
#   ('$', 8),
#   ('crude', 6),
#   ('oil', 6),
#   ('Wednesday', 5),
#   ('API', 5),
#   ('week', 5),
#   ('prices', 4),
#   ('report', 4),
#   ('inventory', 4),
#   ('million', 4),
#   ('early', 4),
#   ('Asia', 3),
#   ('Tuesday', 3),
#   ('build', 3),
#   ('inventories', 3),
#   ('barrels', 3),
#   ('July', 3),
#   ('draw', 3),
#   ('barrel', 3),
#   ('EIA', 3)],
#  [(' ', 17),
#   ('oil', 12),
#   ('prices', 9),
#   ('OPEC', 9),
#   ('week', 7),
#   ('market', 7),
#   ('managers', 6),
#   ('supply', 6),
#   ('July', 5),
#   ('long', 5),
#   ('contracts', 4),
#   ('petroleum', 4),
#   ('short', 4),
#   ('positions', 4),
#   ('taking', 4),
#   ('profits', 3),
#   ('hit', 3),
#   ('highs', 3),
#   ('buying', 3),
#   ('money', 3),
#   ('continued', 3)],
#  [('oil', 7),
#   (' ', 7),
#   ('market', 5),
#   ('demand', 4),
#   ('prices', 3),
#   ('Tuesday', 3),
#   ('new', 3),
#   ('$', 3),
#   ('Delta', 3),
#   ('variant', 3),
#   ('nearly', 2),
#   ('Monday', 2),
#   ('saw', 2),
#   ('WTI', 2),
#   ('sharply', 2),
#   ('price', 2),
#   ('time', 2),
#   ('additional', 2),
#   ('production', 2),
#   ('quotas', 2),
#   ('400,000', 2)],
#  [('$', 7),
#   (' ', 6),
#   ('OPEC', 5),
#   ('barrel', 5),
#   ('oil', 5),
#   ('Goldman', 4),
#   ('80', 4),
#   ('group', 4),
#   ('production', 4),
#   ('agreement', 3),
#   ('reached', 3),
#   ('forecast', 3),
#   ('Brent', 3),
#   ('summer', 3),
#   ('said', 3),
#   ('bpd', 3),
#   ('Sachs', 3),
#   ('despite', 3),
#   ('market', 3),
#   ('deal', 3),
#   ('Sunday', 2)],
#  [('OPEC', 9),
#   (' ', 8),
#   ('$', 6),
#   ('market', 6),
#   ('oil', 6),
#   ('supply', 5),
#   ('Crude', 4),
#   ('barrel', 4),
#   ('prices', 3),
#   ('percent', 3),
#   ('Monday', 3),
#   ('demand', 3),
#   ('Brent', 3),
#   ('deal', 3),
#   ('production', 3),
#   ('early', 2),
#   ('WTI', 2),
#   ('bpd', 2),
#   ('alliance', 2),
#   ('rising', 2),
#   ('global', 2)],
#  [(' ', 8),
#   ('oil', 6),
#   ('prices', 5),
#   ('million', 4),
#   ('week', 3),
#   ('OPEC', 3),
#   ('Energy', 3),
#   ('barrels', 3),
#   ('production', 3),
#   ('supply', 2),
#   ('inventory', 2),
#   ('United', 2),
#   ('Saudi', 2),
#   ('allow', 2),
#   ('reached', 2),
#   ('deal', 2),
#   ('Emirati', 2),
#   ('coverage', 2),
#   ('time', 2),
#   ('Voice', 2),
#   ('agreement', 2)],
#  [('week', 7),
#   ('million', 7),
#   (' ', 6),
#   ('OPEC', 5),
#   ('UAE', 4),
#   ('barrels', 4),
#   ('bpd', 4),
#   ('Oil', 3),
#   ('prices', 3),
#   ('Thursday', 3),
#   ('reported', 3),
#   ('Wednesday', 3),
#   ('baseline', 3),
#   ('production', 3),
#   ('oil', 3),
#   ('market', 2),
#   ('crude', 2),
#   ('supply', 2),
#   ('compromise', 2),
#   ('Saudi', 2),
#   ('Arabia', 2)],
#  [('oil', 7),
#   ('production', 7),
#   (' ', 7),
#   ('OPEC', 5),
#   ('million', 5),
#   ('bpd', 5),
#   ('deal', 4),
#   ('year', 4),
#   ('agreement', 4),
#   ('UAE', 4),
#   ('baseline', 4),
#   ('reached', 3),
#   ('Emirati', 3),
#   ('Goldman', 2),
#   ('$', 2),
#   ('80', 2),
#   ('Brent', 2),
#   ('Saudi', 2),
#   ('Emirates', 2),
#   ('end', 2),
#   ('future', 2)],
#  [('oil', 10),
#   (' ', 8),
#   ('prices', 5),
#   ('market', 5),
#   ('compromise', 4),
#   ('percent', 4),
#   ('demand', 4),
#   ('crude', 4),
#   ('million', 4),
#   ('imports', 3),
#   ('barrels', 3),
#   ('year', 3),
#   ('Tuesday', 3),
#   ('half', 3),
#   ('Oil', 2),
#   ('Wednesday', 2),
#   ('reported', 2),
#   ('Saudi', 2),
#   ('UAE', 2),
#   ('production', 2),
#   ('uncertainty', 2)],
#  [('oil', 19),
#   (' ', 17),
#   ('prices', 12),
#   ('economic', 10),
#   ('economies', 8),
#   ('developed', 7),
#   ('growth', 7),
#   ('higher', 6),
#   ('$', 5),
#   ('analysts', 5),
#   ('term', 5),
#   ('burden', 5),
#   ('rising', 4),
#   ('share', 4),
#   ('GDP', 4),
#   ('long', 4),
#   ('percent', 4),
#   ('average', 4),
#   ('demand', 4),
#   ('barrel', 3),
#   ('earlier', 3)],
#  [('year', 16),
#   ('half', 13),
#   ('inventory', 12),
#   ('spreads', 11),
#   (' ', 9),
#   ('levels', 8),
#   ('oil', 8),
#   ('spread', 7),
#   ('draws', 7),
#   ('calendar', 6),
#   ('expiration', 6),
#   ('inventories', 6),
#   ('second', 6),
#   ('month', 5),
#   ('pattern', 4),
#   ('Dec', 4),
#   ('backwardation', 4),
#   ('2020', 4),
#   ('2021', 4),
#   ('crude', 4),
#   ('higher', 4)],
#  [('$', 11),
#   (' ', 8),
#   ('prices', 6),
#   ('average', 6),
#   ('oil', 6),
#   ('b', 6),
#   ('Brent', 5),
#   ('price', 5),
#   ('forecast', 5),
#   ('July', 5),
#   ('spot', 4),
#   ('year', 4),
#   ('EIA', 4),
#   ('demand', 4),
#   ('supply', 4),
#   ('WTI', 4),
#   ('U.S.', 3),
#   ('said', 3),
#   ('2022', 3),
#   ('June', 3),
#   ('forecasts', 3)],
#  [('oil', 20),
#   ('prices', 9),
#   (' ', 9),
#   ('OPEC', 5),
#   ('high', 4),
#   ('long', 4),
#   ('consumers', 4),
#   ('economic', 4),
#   ('U.S.', 4),
#   ('price', 3),
#   ('pandemic', 3),
#   ('sector', 3),
#   ('devastation', 3),
#   ('gas', 3),
#   ('2020', 3),
#   ('talks', 3),
#   ('$', 3),
#   ('barrel', 3),
#   ('United', 3),
#   ('rdquo', 3),
#   ('March', 2)],
#  [('oil', 12),
#   (' ', 10),
#   ('crude', 7),
#   ('variant', 6),
#   ('prices', 6),
#   ('week', 5),
#   ('demand', 5),
#   ('$', 5),
#   ('Brent', 5),
#   ('latest', 4),
#   ('bullish', 3),
#   ('million', 3),
#   ('barrels', 3),
#   ('November', 3),
#   ('according', 3),
#   ('Omicron', 3),
#   ('new', 3),
#   ('barrel', 3),
#   ('confidence', 3),
#   ('OPEC', 3),
#   ('news', 2)],
#  [(' ', 7),
#   ('market', 5),
#   ('Thursday', 4),
#   ('OPEC', 4),
#   ('COVID', 3),
#   ('$', 3),
#   ('period', 3),
#   ('cases', 3),
#   ('fell', 2),
#   ('uncertainty', 2),
#   ('weekly', 2),
#   ('inventory', 2),
#   ('Crude', 2),
#   ('percent', 2),
#   ('Brent', 2),
#   ('API', 2),
#   ('crude', 2),
#   ('oil', 2),
#   ('week', 2),
#   ('UAE', 2),
#   ('increased', 2)],
#  [(' ', 8),
#   ('oil', 7),
#   ('hedging', 7),
#   ('producers', 6),
#   ('$', 6),
#   ('shale', 5),
#   ('prices', 5),
#   ('U.S.', 4),
#   ('right', 3),
#   ('report', 3),
#   ('production', 3),
#   ('wants', 3),
#   ('Reuters', 3),
#   ('losses', 2),
#   ('citing', 2),
#   ('IHS', 2),
#   ('Markit', 2),
#   ('barrel', 2),
#   ('selling', 2),
#   ('half', 2),
#   ('year', 2)],
#  [(' ', 23),
#   ('production', 16),
#   ('mm', 14),
#   ('OPEC', 13),
#   ('BOPD', 13),
#   ('year', 8),
#   ('Russia', 7),
#   ('output', 7),
#   ('producers', 6),
#   ('oil', 5),
#   ('prices', 5),
#   ('capacity', 5),
#   ('new', 5),
#   ('shale', 5),
#   ('2021', 4),
#   ('demand', 4),
#   ('article', 4),
#   ('UAE', 4),
#   ('noted', 4),
#   ('increases', 4),
#   ('increase', 4)],
#  [(' ', 9),
#   ('oil', 8),
#   ('U.S.', 5),
#   ('prices', 4),
#   ('Wednesday', 4),
#   ('OPEC', 4),
#   ('supply', 4),
#   ('crude', 4),
#   ('market', 3),
#   ('dollar', 3),
#   ('rdquo', 3),
#   ('said', 3),
#   ('assess', 2),
#   ('demand', 2),
#   ('Crude', 2),
#   ('percent', 2),
#   ('$', 2),
#   ('trade', 2),
#   ('stronger', 2),
#   ('morning', 2),
#   ('term', 2)],
#  [(' ', 23),
#   ('OPEC', 17),
#   ('oil', 14),
#   ('$', 8),
#   ('supply', 7),
#   ('market', 7),
#   ('rdquo', 6),
#   ('production', 5),
#   ('prices', 5),
#   ('group', 4),
#   ('Saudi', 4),
#   ('demand', 4),
#   ('analysts', 4),
#   ('UAE', 4),
#   ('price', 4),
#   ('alliance', 4),
#   ('month', 4),
#   ('time', 4),
#   ('said', 4),
#   ('August', 4),
#   ('90', 4)],
#  [('OPEC', 8),
#   (' ', 7),
#   ('oil', 6),
#   ('prices', 4),
#   ('WTI', 3),
#   ('Crude', 3),
#   ('said', 3),
#   ('supply', 3),
#   ('rising', 3),
#   ('price', 2),
#   ('level', 2),
#   ('Monday', 2),
#   ('called', 2),
#   ('management', 2),
#   ('months', 2),
#   ('meeting', 2),
#   ('market', 2),
#   ('deal', 2),
#   ('global', 2),
#   ('collapse', 2),
#   ('year', 2)],
#  [(' ', 8),
#   ('oil', 7),
#   ('OPEC', 6),
#   ('price', 5),
#   ('production', 4),
#   ('Saudi', 3),
#   ('August', 3),
#   ('prices', 3),
#   ('war', 3),
#   ('barrel', 3),
#   ('year', 3),
#   ('agreement', 3),
#   ('million', 3),
#   ('Aramco', 2),
#   ('crude', 2),
#   ('market', 2),
#   ('Biden', 2),
#   ('administration', 2),
#   ('settle', 2),
#   ('differences', 2),
#   ('Bloomberg', 2)],
#  [(' ', 9),
#   ('UAE', 8),
#   ('production', 5),
#   ('OPEC', 4),
#   ('Saudi', 3),
#   ('million', 3),
#   ('year', 3),
#   ('exclude', 3),
#   ('goods', 3),
#   ('talks', 2),
#   ('Arabia', 2),
#   ('opposed', 2),
#   ('ldquounfairrdquo', 2),
#   ('Saudis', 2),
#   ('tariff', 2),
#   ('amendments', 2),
#   ('designed', 2),
#   ('Chief', 2),
#   ('meeting', 2),
#   ('indications', 2),
#   ('bpd', 2)],
#  [(' ', 7),
#   ('group', 5),
#   ('Monday', 4),
#   ('OPEC', 4),
#   ('UAE', 4),
#   ('prices', 3),
#   ('trading', 3),
#   ('early', 3),
#   ('market', 3),
#   ('day', 3),
#   ('production', 3),
#   ('baseline', 3),
#   ('slightly', 2),
#   ('begin', 2),
#   ('oil', 2),
#   ('a.m.', 2),
#   ('EDT', 2),
#   ('Crude', 2),
#   ('percent', 2),
#   ('$', 2),
#   ('meeting', 2)],
#  [('UAE', 12),
#   (' ', 12),
#   ('production', 8),
#   ('OPEC', 5),
#   ('agreement', 5),
#   ('oil', 4),
#   ('Al', 4),
#   ('exclude', 4),
#   ('Saudi', 3),
#   ('challenge', 3),
#   ('million', 3),
#   ('deal', 3),
#   ('year', 3),
#   ('extension', 3),
#   ('GCC', 3),
#   ('goods', 3),
#   ('proposal', 2),
#   ('extend', 2),
#   ('end', 2),
#   ('Monday', 2),
#   ('morning', 2)],
#  [('oil', 28),
#   ('prices', 12),
#   ('markets', 8),
#   ('production', 8),
#   (' ', 8),
#   ('China', 6),
#   ('U.S.', 6),
#   ('sentiment', 5),
#   ('$', 5),
#   ('100', 4),
#   ('bearish', 4),
#   ('Chinese', 4),
#   ('shift', 4),
#   ('Oil', 4),
#   ('geopolitical', 4),
#   ('increase', 4),
#   ('rigs', 4),
#   ('2021', 3),
#   ('global', 3),
#   ('plenty', 3),
#   ('factors', 3)],
#  [(' ', 9),
#   ('market', 5),
#   ('prices', 4),
#   ('OPEC', 4),
#   ('said', 4),
#   ('production', 4),
#   ('barrels', 3),
#   ('$', 3),
#   ('add', 3),
#   ('bpd', 3),
#   ('oil', 2),
#   ('lower', 2),
#   ('today', 2),
#   ('return', 2),
#   ('Brent', 2),
#   ('crude', 2),
#   ('barrel', 2),
#   ('agreement', 2),
#   ('expected', 2),
#   ('come', 2),
#   ('mean', 2)],
#  [(' ', 12),
#   ('OPEC', 5),
#   ('$', 4),
#   ('increase', 3),
#   ('Reuters', 3),
#   ('JMMC', 3),
#   ('Russia', 2),
#   ('output', 2),
#   ('2', 2),
#   ('million', 2),
#   ('barrels', 2),
#   ('day', 2),
#   ('August', 2),
#   ('December', 2),
#   ('said', 2),
#   ('EDT', 2),
#   ('Bakr', 2),
#   ('Chief', 2),
#   ('proposal', 2),
#   ('oil', 2),
#   ('sentiments', 2)],
#  [('OPEC', 11),
#   ('bpd', 8),
#   (' ', 7),
#   ('million', 5),
#   ('August', 5),
#   ('2', 4),
#   ('meeting', 4),
#   ('end', 4),
#   ('agreement', 4),
#   ('ndash', 4),
#   ('increase', 3),
#   ('supply', 3),
#   ('market', 3),
#   ('$', 3),
#   ('Thursday', 2),
#   ('Russia', 2),
#   ('gradual', 2),
#   ('December', 2),
#   ('EDT', 2),
#   ('Crude', 2),
#   ('output', 2)],
#  [('oil', 13),
#   (' ', 11),
#   ('prices', 9),
#   ('supply', 7),
#   ('$', 6),
#   ('Hamm', 6),
#   ('said', 6),
#   ('100', 5),
#   ('rdquo', 4),
#   ('executive', 4),
#   ('market', 4),
#   ('barrel', 3),
#   ('demand', 3),
#   ('week', 3),
#   ('today', 3),
#   ('chairman', 2),
#   ('Continental', 2),
#   ('told', 2),
#   ('FOX', 2),
#   ('Business', 2),
#   ('coming', 2)],
#  [('oil', 14),
#   (' ', 13),
#   ('crude', 10),
#   ('demand', 9),
#   ('market', 6),
#   ('Brent', 5),
#   ('WTI', 5),
#   ('Crude', 5),
#   ('U.S.', 5),
#   ('week', 5),
#   ('June', 5),
#   ('futures', 4),
#   ('$', 4),
#   ('OPEC', 4),
#   ('driving', 3),
#   ('prices', 3),
#   ('physical', 3),
#   ('Asia', 3),
#   ('regional', 3),
#   ('benchmark', 3),
#   ('grades', 3)],
#  [(' ', 7),
#   ('market', 6),
#   ('Wednesday', 4),
#   ('oil', 4),
#   ('demand', 4),
#   ('WTI', 3),
#   ('percent', 3),
#   ('week', 3),
#   ('said', 3),
#   ('prices', 2),
#   ('rose', 2),
#   ('economic', 2),
#   ('United', 2),
#   ('States', 2),
#   ('inventory', 2),
#   ('U.S.', 2),
#   ('EIA', 2),
#   ('Crude', 2),
#   ('$', 2),
#   ('Brent', 2),
#   ('support', 2)],
#  [(' ', 8),
#   ('oil', 7),
#   ('$', 7),
#   ('prices', 4),
#   ('Iran', 3),
#   ('nuclear', 3),
#   ('WTI', 3),
#   ('barrel', 3),
#   ('crude', 3),
#   ('market', 2),
#   ('hardliner', 2),
#   ('risen', 2),
#   ('roughly', 2),
#   ('Brent', 2),
#   ('pricing', 2),
#   ('100', 2),
#   ('new', 2),
#   ('president', 2),
#   ('hopes', 2),
#   ('sanctions', 2),
#   ('Market', 2)],
#  [('oil', 17),
#   (' ', 15),
#   ('prices', 9),
#   ('$', 8),
#   ('demand', 8),
#   ('supply', 7),
#   ('barrel', 6),
#   ('production', 5),
#   ('pandemic', 5),
#   ('year', 5),
#   ('energy', 5),
#   ('usual', 4),
#   ('gas', 4),
#   ('35', 3),
#   ('investment', 3),
#   ('new', 3),
#   ('100', 3),
#   ('time', 3),
#   ('International', 3),
#   ('question', 3),
#   ('peak', 3)],
#  [('oil', 11),
#   (' ', 8),
#   ('prices', 6),
#   ('$', 6),
#   ('barrel', 5),
#   ('BofA', 5),
#   ('demand', 4),
#   ('supply', 4),
#   ('said', 4),
#   ('Global', 3),
#   ('rdquo', 3),
#   ('average', 3),
#   ('Brent', 3),
#   ('year', 3),
#   ('strong', 2),
#   ('recovery', 2),
#   ('outpace', 2),
#   ('months', 2),
#   ('lead', 2),
#   ('100', 2),
#   ('2022', 2)],
#  [('oil', 22),
#   (' ', 17),
#   ('supply', 10),
#   ('prices', 10),
#   ('year', 9),
#   ('demand', 9),
#   ('$', 8),
#   ('OPEC', 7),
#   ('100', 6),
#   ('rdquo', 6),
#   ('global', 5),
#   ('market', 5),
#   ('time', 4),
#   ('expected', 4),
#   ('crude', 3),
#   ('bullish', 3),
#   ('said', 3),
#   ('levels', 3),
#   ('Oil', 3),
#   ('high', 3),
#   ('higher', 3)],
#  [(' ', 12),
#   ('week', 11),
#   ('oil', 6),
#   ('U.S.', 6),
#   ('WTI', 5),
#   ('Brent', 5),
#   ('percent', 5),
#   ('Crude', 4),
#   ('million', 4),
#   ('bpd', 4),
#   ('$', 4),
#   ('demand', 3),
#   ('production', 3),
#   ('recent', 3),
#   ('gasoline', 3),
#   ('June', 3),
#   ('compared', 3),
#   ('said', 3),
#   ('barrel', 3),
#   ('crude', 3),
#   ('spread', 3)],
#  [(' ', 9),
#   ('oil', 7),
#   ('prices', 5),
#   ('$', 5),
#   ('dollar', 4),
#   ('week', 3),
#   ('Thursday', 2),
#   ('afternoon', 2),
#   ('WTI', 2),
#   ('Wednesday', 2),
#   ('said', 2),
#   ('inflation', 2),
#   ('expected', 2),
#   ('earlier', 2),
#   ('U.S.', 2),
#   ('demand', 2),
#   ('crude', 2),
#   ('inventories', 2),
#   ('loss', 2),
#   ('price', 2),
#   ('million', 2)],
#  [('oil', 20),
#   (' ', 17),
#   ('energy', 14),
#   ('world', 8),
#   ('emissions', 5),
#   ('Oil', 5),
#   ('transition', 5),
#   ('renewable', 5),
#   ('fossil', 4),
#   ('fuels', 4),
#   ('demand', 4),
#   ('investors', 4),
#   ('investing', 3),
#   ('new', 3),
#   ('companies', 3),
#   ('industry', 3),
#   ('pressure', 3),
#   ('Shell', 3),
#   ('earlier', 3),
#   ('$', 3),
#   ('Big', 3)],
#  [(' ', 10),
#   ('demand', 6),
#   ('oil', 6),
#   ('$', 5),
#   ('prices', 4),
#   ('recent', 4),
#   ('OPEC', 4),
#   ('days', 3),
#   ('week', 3),
#   ('higher', 3),
#   ('crude', 3),
#   ('rdquo', 3),
#   ('said', 3),
#   ('global', 2),
#   ('tight', 2),
#   ('downside', 2),
#   ('risks', 2),
#   ('jumped', 2),
#   ('bullish', 2),
#   ('outlooks', 2),
#   ('Iran', 2)],
#  [('Dangote', 11),
#   ('Refinery', 10),
#   ('Nigerian', 9),
#   ('refinery', 9),
#   ('NNPC', 9),
#   ('refineries', 8),
#   ('Nigeria', 6),
#   (' ', 5),
#   ('government', 5),
#   ('ndash', 5),
#   ('Port', 5),
#   ('2019', 5),
#   ('Nigeriarsquos', 4),
#   ('domestic', 4),
#   ('oil', 4),
#   ('private', 4),
#   ('downstream', 4),
#   ('Harcourt', 4),
#   ('product', 3),
#   ('demand', 3),
#   ('company', 3)],
#  [('oil', 12),
#   (' ', 11),
#   ('prices', 10),
#   ('production', 7),
#   ('OPEC', 7),
#   ('higher', 6),
#   ('Middle', 6),
#   ('consumption', 5),
#   ('report', 4),
#   ('summer', 4),
#   ('Saudi', 4),
#   ('million', 4),
#   ('members', 4),
#   ('buyers', 4),
#   ('spare', 4),
#   ('crude', 3),
#   ('East', 3),
#   ('year', 3),
#   ('usual', 3),
#   ('electricity', 3),
#   ('Arabia', 3)],
#  [(' ', 7),
#   ('oil', 6),
#   ('new', 4),
#   ('exploration', 3),
#   ('production', 3),
#   ('said', 3),
#   ('Wunti', 3),
#   ('declining', 3),
#   ('$', 2),
#   ('200', 2),
#   ('barrel', 2),
#   ('companies', 2),
#   ('investments', 2),
#   ('National', 2),
#   ('investment', 2),
#   ('years', 2),
#   ('NNPCrsquos', 2),
#   ('Petroleum', 2),
#   ('Nigeria', 2),
#   ('International', 2),
#   ('rdquo', 2)],
#  [(' ', 11),
#   ('oil', 10),
#   ('$', 8),
#   ('barrel', 7),
#   ('EIA', 7),
#   ('prices', 5),
#   ('forecast', 5),
#   ('price', 5),
#   ('production', 5),
#   ('Crude', 4),
#   ('average', 4),
#   ('U.S.', 4),
#   ('said', 4),
#   ('crude', 4),
#   ('million', 4),
#   ('bpd', 4),
#   ('Brent', 3),
#   ('year', 3),
#   ('monthly', 3),
#   ('June', 3),
#   ('STEO', 3)],
#  [(' ', 9),
#   ('oil', 9),
#   ('said', 5),
#   ('$', 4),
#   ('barrel', 4),
#   ('year', 3),
#   ('IEA', 3),
#   ('world', 3),
#   ('price', 3),
#   ('end', 2),
#   ('week', 2),
#   ('demand', 2),
#   ('Brent', 2),
#   ('according', 2),
#   ('head', 2),
#   ('Iranian', 2),
#   ('Mizuho', 2),
#   ('executive', 2),
#   ('rdquo', 2),
#   ('global', 2),
#   ('ldquoThe', 2)],
#  [(' ', 7),
#   ('$', 7),
#   ('prices', 4),
#   ('week', 4),
#   ('United', 4),
#   ('States', 4),
#   ('Crude', 4),
#   ('demand', 4),
#   ('oil', 4),
#   ('Friday', 3),
#   ('U.S.', 3),
#   ('percent', 3),
#   ('Brent', 3),
#   ('Thursday', 3),
#   ('said', 3),
#   ('Oil', 2),
#   ('rising', 2),
#   ('return', 2),
#   ('Iranian', 2),
#   ('nuclear', 2),
#   ('deal', 2)],
#  [('oil', 10),
#   (' ', 9),
#   ('   ', 7),
#   ('prices', 5),
#   ('demand', 5),
#   ('said', 5),
#   ('energy', 5),
#   ('Novak', 4),
#   ('carbon', 4),
#   ('global', 4),
#   ('Minister', 3),
#   ('OPEC', 3),
#   ('August', 3),
#   ('output', 3),
#   ('current', 3),
#   ('Petersburg', 3),
#   ('International', 3),
#   ('price', 3),
#   ('increase', 3),
#   ('$', 3),
#   ('IEA', 3)],
#  [('demand', 7),
#   (' ', 7),
#   ('oil', 6),
#   ('prices', 3),
#   ('OPEC', 3),
#   ('quoted', 3),
#   ('told', 3),
#   ('inflation', 3),
#   ('supply', 2),
#   ('planned', 2),
#   ('production', 2),
#   ('Bloomberg', 2),
#   ('Saudi', 2),
#   ('Energy', 2),
#   ('bin', 2),
#   ('Salman', 2),
#   ('crude', 2),
#   ('economic', 2),
#   ('recovery.rdquo', 2),
#   ('Iran', 2),
#   ('U.S.', 2)],
#  [('OPEC', 9),
#   (' ', 9),
#   ('meeting', 6),
#   ('oil', 5),
#   ('market', 5),
#   ('JMMC', 4),
#   ('$', 4),
# ...
#   ('breakeven', 5),
#   ('companies', 5),
#   ('barrel', 4),
#   ('equity', 4),
#   ('investors', 4),
#   ('EampPs', 4),
#   ('ndash', 4),
#   ('services', 4),
#   ('cash', 4)],
#  [('oil', 11),
#   (' ', 10),
#   ('million', 9),
#   ('exports', 8),
#   ('crude', 7),
#   ('Saudi', 6),
#   ('bpd', 6),
#   ('week', 5),
#   ('inventories', 4),
#   ('barrels', 4),
#   ('level', 3),
#   ('August', 3),
#   ('month', 3),
#   ('Oil', 3),
#   ('U.S.', 3),
#   ('reported', 3),
#   ('EIA', 3),
#   ('draw', 3),
#   ('June', 2),
#   ('dropped', 2),
#   ('lowest', 2)],
#  [(' ', 33),
#   ('KRG', 29),
#   ('energy', 23),
#   ('Turkish', 21),
#   ('oil', 18),
#   ('Turkey', 16),
#   ('TEC', 15),
#   ('blocks', 13),
#   ('percent', 12),
#   ('Energy', 10),
#   ('Taq', 10),
#   ('GE', 10),
#   ('Kurdistan', 9),
#   ('Baghdad', 9),
#   ('ExxonMobil', 8),
#   ('deal', 8),
#   ('signed', 8),
#   ('political', 7),
#   ('ndash', 7),
#   ('pipeline', 7),
#   ('Kurdish', 6)],
#  [(' ', 12),
#   ('OPEC', 9),
#   ('cuts', 6),
#   ('JP', 6),
#   ('production', 5),
#   ('Morgan', 5),
#   ('Saudi', 5),
#   ('oil', 5),
#   ('compliance', 4),
#   ('output', 4),
#   ('year', 4),
#   ('producers', 4),
#   ('al', 4),
#   ('Iraqi', 3),
#   ('rdquo', 3),
#   ('said', 3),
#   ('members', 3),
#   ('Iraq', 3),
#   ('non', 3),
#   ('Arabia', 3),
#   ('end', 3)],
#  [(' ', 11),
#   ('prices', 10),
#   ('oil', 7),
#   ('year', 5),
#   ('U.S.', 5),
#   ('industry', 4),
#   ('Andurand', 3),
#   ('demand', 3),
#   ('shale', 3),
#   ('current', 3),
#   ('new', 3),
#   ('price', 3),
#   ('Metal', 3),
#   ('direction', 2),
#   ('rise', 2),
#   ('investment', 2),
#   ('low', 2),
#   ('mdash', 2),
#   ('level', 2),
#   ('cuts', 2),
#   ('rising', 2)],
#  [(' ', 13),
#   ('percent', 8),
#   ('Saudi', 7),
#   ('U.S.', 6),
#   ('oil', 6),
#   ('year', 6),
#   ('lower', 4),
#   ('draw', 4),
#   ('barrels', 4),
#   ('crude', 4),
#   ('demand', 4),
#   ('refinery', 3),
#   ('flows', 3),
#   ('Arabia', 3),
#   ('deliveries', 3),
#   ('Port', 3),
#   ('Motiva', 3),
#   ('bpd', 3),
#   ('months', 3),
#   ('refineries', 3),
#   ('IEA', 3)],
#  [(' ', 15),
#   ('crude', 9),
#   ('mdash', 8),
#   ('oil', 7),
#   ('Gulf', 6),
#   ('Venezuela', 6),
#   ('U.S.', 5),
#   ('sources', 4),
#   ('week', 3),
#   ('making', 3),
#   ('markets', 3),
#   ('refiners', 3),
#   ('Venezuelarsquos', 3),
#   ('major', 2),
#   ('changes', 2),
#   ('flows', 2),
#   ('big', 2),
#   ('nation', 2),
#   ('years', 2),
#   ('shipments', 2),
#   ('saying', 2)],
#  [(' ', 12),
#   ('oil', 8),
#   ('crude', 6),
#   ('million', 5),
#   ('week', 5),
#   ('prices', 4),
#   ('Monday', 4),
#   ('U.S.', 4),
#   ('lowest', 4),
#   ('barrels', 4),
#   ('Tuesday', 3),
#   ('demand', 3),
#   ('July', 3),
#   ('bpd', 3),
#   ('daily', 3),
#   ('inventories', 3),
#   ('Oil', 2),
#   ('concerns', 2),
#   ('supply', 2),
#   ('growth', 2),
#   ('WTI', 2)],
#  [(' ', 15),
#   ('oil', 14),
#   ('production', 14),
#   ('output', 10),
#   ('U.S.', 6),
#   ('year', 6),
#   ('Libya', 6),
#   ('OPEC', 5),
#   ('rdquo', 5),
#   ('shale', 5),
#   ('Nigeria', 5),
#   ('Venezuela', 5),
#   ('market', 4),
#   ('prices', 4),
#   ('week', 4),
#   ('return', 4),
#   ('gains', 4),
#   ('bpd', 4),
#   ('ndash', 4),
#   ('Permian', 4),
#   ('analysts', 3)],
#  [('bpd', 14),
#   ('output', 10),
#   (' ', 9),
#   ('Permian', 8),
#   ('production', 7),
#   ('growth', 7),
#   ('year', 7),
#   ('shale', 6),
#   ('increase', 5),
#   ('oil', 4),
#   ('300,000', 4),
#   ('analysts', 3),
#   ('reports', 3),
#   ('gas', 3),
#   ('months', 3),
#   ('rigs', 3),
#   ('US$', 3),
#   ('firms', 2),
#   ('forecasts', 2),
#   ('end', 2),
#   ('Wood', 2)],
#  [(' ', 19),
#   ('percent', 12),
#   ('oil', 10),
#   ('July', 9),
#   ('output', 9),
#   ('year', 9),
#   ('million', 8),
#   ('day', 7),
#   ('Bloomberg', 6),
#   ('month', 6),
#   ('barrels', 6),
#   ('o', 6),
#   ('crude', 5),
#   ('tons', 5),
#   ('demand', 4),
#   ('Chinese', 4),
#   ('China', 4),
#   ('refining', 4),
#   ('data', 4),
#   ('months', 4),
#   ('production', 4)],
#  [(' ', 12),
#   ('IEA', 11),
#   ('bpd', 11),
#   ('mb', 8),
#   ('oil', 7),
#   ('d', 7),
#   ('OPEC', 6),
#   ('demand', 6),
#   ('July', 5),
#   ('rdquo', 5),
#   ('year', 5),
#   ('market', 4),
#   ('time', 4),
#   ('report', 4),
#   ('things', 4),
#   ('inventories', 4),
#   ('compliance', 4),
#   ('new', 3),
#   ('prices', 3),
#   ('2018', 3),
#   ('rate', 3)],
#  [('oil', 17),
#   (' ', 12),
#   ('demand', 11),
#   ('market', 8),
#   ('prices', 7),
#   ('bpd', 7),
#   ('OPEC', 6),
#   ('year', 6),
#   ('U.S.', 5),
#   ('Oil', 5),
#   ('IEA', 5),
#   ('shale', 5),
#   ('said', 4),
#   ('global', 4),
#   ('Permian', 4),
#   ('futures', 4),
#   ('$', 4),
#   ('Korea', 4),
#   ('crude', 3),
#   ('end', 3),
#   ('week', 3)],
#  [(' ', 12),
#   ('production', 10),
#   ('mdash', 5),
#   ('oil', 4),
#   ('OPEC', 4),
#   ('output', 4),
#   ('million', 4),
#   ('barrels', 4),
#   ('day', 4),
#   ('cuts', 3),
#   ('July', 3),
#   ('prices', 2),
#   ('week', 2),
#   ('numbers', 2),
#   ('producing', 2),
#   ('nations', 2),
#   ('crude', 2),
#   ('key', 2),
#   ('2017', 2),
#   ('b', 2),
#   ('d', 2)],
#  [(' ', 20),
#   ('production', 11),
#   ('day', 7),
#   ('barrels', 6),
#   ('OPEC', 5),
#   ('June', 5),
#   ('decline', 4),
#   ('revised', 4),
#   ('upward', 4),
#   ('bpd', 4),
#   ('oil', 4),
#   ('data', 3),
#   ('Oil', 3),
#   ('peaked', 3),
#   ('$', 3),
#   ('chart', 2),
#   ('Equatorial', 2),
#   ('Guinea', 2),
#   ('10', 2),
#   ('percent', 2),
#   ('year', 2)],
#  [('bpd', 17),
#   ('million', 10),
#   ('OPEC', 8),
#   (' ', 8),
#   ('production', 7),
#   ('barrels', 5),
#   ('year', 5),
#   ('growth', 5),
#   ('oil', 4),
#   ('increase', 4),
#   ('output', 4),
#   ('demand', 4),
#   ('crude', 3),
#   ('OECD', 3),
#   ('second', 3),
#   ('non', 3),
#   ('daily', 2),
#   ('Libya', 2),
#   ('Saudi', 2),
#   ('main', 2),
#   ('drivers', 2)],
#  [('imports', 9),
#   ('oil', 8),
#   ('crude', 7),
#   (' ', 7),
#   ('percent', 6),
#   ('Chinarsquos', 6),
#   ('million', 6),
#   ('year', 5),
#   ('Chinese', 4),
#   ('Reuters', 4),
#   ('bpd', 4),
#   ('July', 3),
#   ('annual', 3),
#   ('basis', 3),
#   ('month', 3),
#   ('tons', 3),
#   ('increased', 3),
#   ('total', 3),
#   ('demand', 3),
#   ('rise', 3),
#   ('lowest', 2)],
#  [(' ', 20),
#   ('FERC', 17),
#   ('billion', 10),
#   ('US$', 9),
#   ('quorum', 8),
#   ('gas', 7),
#   ('pipeline', 7),
#   ('projects', 7),
#   ('construction', 6),
#   ('year', 6),
#   ('natural', 6),
#   ('project', 6),
#   ('said', 5),
#   ('service', 5),
#   ('quarter', 5),
#   ('Commission', 4),
#   ('worth', 4),
#   ('date', 4),
#   ('Virginia', 4),
#   ('final', 4),
#   ('Energy', 3)],
#  [(' ', 10),
#   ('oil', 5),
#   ('reports', 4),
#   ('production', 4),
#   ('armed', 4),
#   ('mdash', 4),
#   ('Libyarsquos', 4),
#   ('saying', 3),
#   ('control', 3),
#   ('room', 3),
#   ('group', 3),
#   ('problems', 3),
#   ('countryrsquos', 2),
#   ('field', 2),
#   ('local', 2),
#   ('Reuters', 2),
#   ('Sharara', 2),
#   ('sources', 2),
#   ('key', 2),
#   ('facility', 2),
#   ('action', 2)],
#  [(' ', 46),
#   ('oil', 23),
#   ('price', 21),
#   ('prices', 17),
#   ('Figure', 16),
#   ('EIA', 15),
#   ('U.S.', 12),
#   ('$', 12),
#   ('supply', 11),
#   ('C.I.', 11),
#   ('consumption', 10),
#   ('inventory', 10),
#   ('comparative', 9),
#   ('5', 9),
#   ('levels', 9),
#   ('stock', 9),
#   ('year', 8),
#   ('barrel', 8),
#   ('2016', 8),
#   ('d', 8),
#   ('data', 8)],
#  [(' ', 17),
#   ('oil', 15),
#   ('Venezuela', 11),
#   ('$', 7),
#   ('default', 7),
#   ('debt', 6),
#   ('Venezuelan', 5),
#   ('payments', 5),
#   ('exports', 5),
#   ('Croft', 4),
#   ('economic', 4),
#   ('said', 4),
#   ('year', 4),
#   ('billion', 4),
#   ('company', 4),
#   ('U.S.', 4),
#   ('Venezuelarsquos', 3),
#   ('according', 3),
#   ('Capital', 3),
#   ('rdquo', 3),
#   ('push', 3)],
#  [('oil', 24),
#   (' ', 17),
#   ('ndash', 9),
#   ('companies', 8),
#   ('growth', 7),
#   ('prices', 6),
#   ('stocks', 4),
#   ('capex', 4),
#   ('2017', 4),
#   ('going', 4),
#   ('Pioneer', 4),
#   ('horrible', 3),
#   ('2016', 3),
#   ('assets', 3),
#   ('spending', 3),
#   ('quarter', 3),
#   ('guys', 3),
#   ('reward', 3),
#   ('like', 3),
#   ('need', 3),
#   ('lemmings', 3)],
#  [(' ', 11),
#   ('prices', 6),
#   ('oil', 5),
#   ('US$', 5),
#   ('price', 4),
#   ('quarter', 4),
#   ('Barclays', 4),
#   ('month', 3),
#   ('inventory', 3),
#   ('drawdowns', 3),
#   ('rdquo', 3),
#   ('bank', 3),
#   ('July', 3),
#   ('WTI', 3),
#   ('combination', 2),
#   ('unlikely', 2),
#   ('said', 2),
#   ('note', 2),
#   ('macro', 2),
#   ('geopolitical', 2),
#   ('expect', 2)],
#  [(' ', 14),
#   ('oil', 13),
#   ('OPEC', 13),
#   ('market', 10),
#   ('prices', 10),
#   ('cuts', 7),
#   ('producers', 7),
#   ('U.S.', 5),
#   ('production', 4),
#   ('output', 4),
#   ('price', 4),
#   ('El', 4),
#   ('cartel', 3),
#   ('deal', 3),
#   ('try', 3),
#   ('relevance', 3),
#   ('shale', 3),
#   ('non', 3),
#   ('game', 3),
#   ('theory', 3),
#   ('Erian', 3)],
#  [('crude', 11),
#   (' ', 9),
#   ('U.S.', 9),
#   ('demand', 7),
#   ('exports', 6),
#   ('refiners', 5),
#   ('barrels', 5),
#   ('million', 5),
#   ('Nigerian', 4),
#   ('oil', 4),
#   ('strong', 4),
#   ('refineries', 4),
#   ('high', 3),
#   ('Angolan', 3),
#   ('Nigeria', 3),
#   ('Angola', 3),
#   ('refining', 3),
#   ('margins', 3),
#   ('capacity', 3),
#   ('Angolarsquos', 3),
#   ('US$', 3)],
#  [('oil', 9),
#   (' ', 8),
#   ('heavy', 7),
#   ('spread', 6),
#   ('U.S.', 5),
#   ('Fitch', 5),
#   ('OPEC', 4),
#   ('WTI', 4),
#   ('WCS', 4),
#   ('exports', 3),
#   ('crude', 3),
#   ('grades', 3),
#   ('price', 3),
#   ('Canadian', 3),
#   ('sands', 3),
#   ('year', 3),
#   ('supply', 3),
#   ('cutting', 2),
#   ('refining', 2),
#   ('margins', 2),
#   ('refiners', 2)],
#  [(' ', 51),
#   ('oil', 18),
#   ('U.S.', 15),
#   ('sanctions', 12),
#   ('Venezuela', 10),
#   ('PDVSA', 9),
#   ('Oil', 7),
#   ('largest', 5),
#   ('result', 5),
#   ('price', 4),
#   ('ndash', 4),
#   ('barrels', 4),
#   ('reserves', 3),
#   ('Venezuelarsquos', 3),
#   ('national', 3),
#   ('Madurorsquos', 3),
#   ('American', 3),
#   ('bank', 3),
#   ('produce', 3),
#   ('lighter', 3),
#   ('daily', 3)],
#  [('$', 28),
#   (' ', 18),
#   ('billion', 16),
#   ('oil', 12),
#   ('upstream', 11),
#   ('Shell', 11),
#   ('prices', 10),
#   ('million', 10),
#   ('2016', 8),
#   ('Q2', 7),
#   ('low', 7),
#   ('boe', 7),
#   ('major', 6),
#   ('profits', 6),
#   ('company', 6),
#   ('Chevron', 6),
#   ('d', 6),
#   ('posted', 5),
#   ('U.S.', 5),
#   ('price', 5),
#   ('companyrsquos', 5)],
#  [(' ', 10),
#   ('oil', 8),
#   ('bpd', 8),
#   ('million', 6),
#   ('exports', 4),
#   ('barrels', 4),
#   ('production', 4),
#   ('Oil', 4),
#   ('week', 3),
#   ('month', 3),
#   ('OPEC', 3),
#   ('meeting', 3),
#   ('cut', 3),
#   ('crude', 3),
#   ('said', 3),
#   ('prices', 3),
#   ('increase', 3),
#   ('year', 3),
#   ('positions', 2),
#   ('Bloomberg', 2),
#   ('rise', 2)],
#  [('oil', 20),
#   (' ', 20),
#   ('$', 12),
#   ('year', 8),
#   ('prices', 8),
#   ('billion', 7),
#   ('majors', 6),
#   ('large', 6),
#   ('cost', 5),
#   ('time', 5),
#   ('earlier', 4),
#   ('long', 4),
#   ('projects', 4),
#   ('second', 3),
#   ('quarter', 3),
#   ('companies', 3),
#   ('profit', 3),
#   ('higher', 3),
#   ('years', 3),
#   ('low', 3),
#   ('Oil', 3)],
#  [(' ', 21),
#   ('oil', 17),
#   ('prices', 14),
#   ('$', 13),
#   ('U.S.', 11),
#   ('OPEC', 10),
#   ('NYSE', 8),
#   ('Venezuela', 7),
#   ('bull', 6),
#   ('spending', 6),
#   ('production', 6),
#   ('million', 5),
#   ('Tuesday', 4),
#   ('percent', 4),
#   ('time', 4),
#   ('market', 4),
#   ('sanctions', 4),
#   ('Oil', 3),
#   ('heavy', 3),
#   ('morning', 3),
#   ('3', 3)],
#  [('bpd', 19),
#   ('million', 11),
#   (' ', 10),
#   ('exports', 6),
#   ('oil', 5),
#   ('Libya', 5),
#   ('June', 5),
#   ('July', 5),
#   ('month', 4),
#   ('Nigeria', 4),
#   ('production', 4),
#   ('crude', 3),
#   ('higher', 3),
#   ('shipments', 3),
#   ('OPEC', 3),
#   ('cut', 3),
#   ('Kpler', 2),
#   ('UAE', 2),
#   ('average', 2),
#   ('total', 2),
#   ('output', 2)],
#  [('oil', 16),
#   ('market', 14),
#   (' ', 14),
#   ('U.S.', 8),
#   ('crude', 6),
#   ('prices', 6),
#   ('OPEC', 5),
#   ('reasons', 4),
#   ('barrels', 4),
#   ('price', 4),
#   ('Venezuela', 4),
#   ('lot', 4),
#   ('week', 3),
#   ('Oil', 3),
#   ('month', 3),
#   ('rally', 3),
#   ('cuts', 3),
#   ('day', 3),
#   ('shale', 3),
#   ('exports', 3),
#   ('futures', 3)],
#  [('U.S.', 17),
#   (' ', 14),
#   ('sanctions', 10),
#   ('Venezuela', 9),
#   ('prices', 8),
#   ('government', 7),
#   ('Venezuelan', 7),
#   ('imports', 6),
#   ('Venezuelarsquos', 5),
#   ('vote', 5),
#   ('oil', 5),
#   ('country', 5),
#   ('crude', 5),
#   ('Maduro', 4),
#   ('Madurorsquos', 4),
#   ('countryrsquos', 4),
#   ('economic', 4),
#   ('OPEC', 4),
#   ('controversial', 3),
#   ('United', 3),
#   ('States', 3)],
#  [(' ', 10),
#   ('drillers', 7),
#   ('US$', 7),
#   ('shale', 5),
#   ('year', 5),
#   ('debt', 5),
#   ('OPEC', 5),
#   ('prices', 5),
#   ('billion', 5),
#   ('oil', 4),
#   ('production', 4),
#   ('price', 4),
#   ('analysts', 3),
#   ('need', 3),
#   ('barrel', 3),
#   ('rally', 3),
#   ('cut', 2),
#   ('U.S.', 2),
#   ('lenders', 2),
#   ('unsustainable', 2),
#   ('DiChristopher', 2)],
#  [('OPEC', 11),
#   (' ', 10),
#   ('compliance', 5),
#   ('meeting', 5),
#   ('non', 4),
#   ('percent', 4),
#   ('Saudi', 4),
#   ('Abu', 3),
#   ('Dhabi', 3),
#   ('output', 3),
#   ('Russia', 3),
#   ('June', 3),
#   ('according', 3),
#   ('Arabia', 3),
#   ('producers', 3),
#   ('secondary', 3),
#   ('sources', 3),
#   ('committee', 2),
#   ('week', 2),
#   ('far', 2),
#   ('Non', 2)],
#  [(' ', 9),
#   ('US$', 8),
#   ('price', 5),
#   ('poll', 5),
#   ('cut', 4),
#   ('cuts', 4),
#   ('June', 4),
#   ('OPEC', 4),
#   ('oil', 3),
#   ('expected', 3),
#   ('OPECrsquos', 3),
#   ('resolve', 3),
#   ('according', 3),
#   ('analysts', 3),
#   ('Reuters', 3),
#   ('year', 3),
#   ('month', 3),
#   ('Analysts', 2),
#   ('forecasts', 2),
#   ('2017', 2),
#   ('2018', 2)],
#  [(' ', 9),
#   ('U.S.', 9),
#   ('OPEC', 6),
#   ('year', 6),
#   ('oil', 5),
#   ('production', 5),
#   ('Saudi', 5),
#   ('million', 5),
#   ('dollar', 5),
#   ('high', 4),
#   ('percent', 4),
#   ('positions', 4),
#   ('Petersburg', 3),
#   ('prices', 3),
#   ('barrels', 3),
#   ('remains', 3),
#   ('short', 3),
#   ('increased', 3),
#   ('time', 3),
#   ('meeting', 2),
#   ('non', 2)],
#  [('oil', 26),
#   ('production', 10),
#   ('companies', 9),
#   (' ', 9),
#   ('term', 6),
#   ('capex', 5),
#   ('long', 5),
#   ('earnings', 4),
#   ('2017', 4),
#   ('prices', 4),
#   ('ndash', 4),
#   ('report', 3),
#   ('time', 3),
#   ('current', 3),
#   ('demand', 3),
#   ('fact', 3),
#   ('stocks', 3),
#   ('looking', 3),
#   ('investment', 3),
#   ('deep', 3),
#   ('like', 3)],
#  [('oil', 19),
#   (' ', 15),
#   ('year', 14),
#   ('$', 12),
#   ('prices', 10),
#   ('NYSE', 9),
#   ('billion', 8),
#   ('OPEC', 7),
#   ('Oil', 6),
#   ('cut', 6),
#   ('rdquo', 5),
#   ('gas', 5),
#   ('profits', 5),
#   ('quarter', 5),
#   ('Energy', 5),
#   ('U.S.', 5),
#   ('Venezuelan', 5),
#   ('spending', 5),
#   ('2017', 4),
#   ('week', 4),
#   ('company', 4)],
#  [('oil', 7),
#   (' ', 7),
#   ('week', 4),
#   ('U.S.', 4),
#   ('market', 4),
#   ('million', 4),
#   ('global', 3),
#   ('price', 3),
#   ('EIA', 3),
#   ('crude', 3),
#   ('inventories', 3),
#   ('barrels', 3),
#   ('rebalancing', 3),
#   ('production', 3),
#   ('Thursday', 2),
#   ('prices', 2),
#   ('inventory', 2),
#   ('draw', 2),
#   ('producers', 2),
#   ('cut', 2),
#   ('earnest', 2)],
#  [(' ', 64),
#   ('oil', 42),
#   ('price', 12),
#   ('ndash', 11),
#   ('derivatives', 11),
#   ('paper', 11),
#   ('prices', 10),
#   ('barrels', 8),
#   ('value', 8),
#   ('Oil', 7),
#   ('barrel', 6),
#   ('futures', 6),
#   ('actual', 6),
#   ('wet', 6),
#   ('contracts', 5),
#   ('market', 5),
#   ('trading', 5),
#   ('thatrsquos', 5),
#   ('trade', 5),
#   ('traders', 5),
#   ('$', 4)],
#  [(' ', 15),
#   ('OPEC', 12),
#   ('Saudi', 11),
#   ('production', 9),
#   ('said', 8),
#   ('al', 7),
#   ('Falih', 7),
#   ('mb', 7),
#   ('Arabia', 6),
#   ('oil', 6),
#   ('market', 6),
#   ('d', 6),
#   ('Nigeria', 5),
#   ('members', 5),
#   ('exports', 5),
#   ('rdquo', 5),
#   ('WSJ', 4),
#   ('output', 4),
#   ('months', 4),
#   ('Libya', 3),
#   ('grow', 3)],
#  [(' ', 18),
#   ('percent', 8),
#   ('compliant', 7),
#   ('oil', 6),
#   ('production', 6),
#   ('UAE', 6),
#   ('exports', 4),
#   ('UAErsquos', 4),
#   ('OPEC', 3),
#   ('crude', 3),
#   ('reductionnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbsp',
#    3),
#   ('Saudi', 2),
#   ('September', 2),
#   ('year', 2),
#   ('commitment', 2),
#   ('million', 2),
#   ('responsible', 2),
#   ('month', 2),
#   ('reduction', 2),
#   ('total', 2),
#   ('Following', 1)],
#  [('production', 19),
#   (' ', 18),
#   ('Saudi', 14),
#   ('OPEC', 11),
#   ('oil', 11),
#   ('prices', 11),
#   ('bpd', 9),
#   ('million', 8),
#   ('U.S.', 8),
#   ('inventories', 7),
#   ('cuts', 6),
#   ('cut', 6),
#   ('year', 5),
#   ('EIA', 5),
#   ('July', 5),
#   ('exports', 4),
#   ('high', 4),
#   ('additional', 4),
#   ('Arabia', 3),
#   ('countryrsquos', 3),
#   ('level', 3)],
#  [('oil', 24),
#   ('production', 23),
#   ('market', 14),
#   (' ', 13),
#   ('OPEC', 12),
#   ('Saudi', 8),
#   ('expected', 8),
#   ('Al', 7),
#   ('cut', 6),
#   ('Libya', 6),
#   ('Nigeria', 6),
#   ('Libyarsquos', 6),
#   ('OPECrsquos', 5),
#   ('compliance', 5),
#   ('main', 5),
#   ('Russia', 4),
#   ('current', 4),
#   ('present', 4),
#   ('possible', 4),
#   ('overall', 4),
#   ('growing', 4)],
#  ...]

# %%
common_words_list_edited = []
for c in common_words_list:
    intermediary_list = []
    for a in c:
        a_edited = a[0]
        intermediary_list.append(a_edited)
    common_words_list_edited.append(intermediary_list)
common_words_list_edited
# Out:
# [['oil',
#   ' ',
#   'OPEC',
#   '$',
#   'release',
#   'new',
#   'bpd',
#   'million',
#   'barrels',
#   'rdquo',
#   'prices',
#   'latest',
#   'variant',
#   'output',
#   'SPR',
#   'global',
#   'market',
#   'U.S.',
#   'halt',
#   'supply',
#   'demand'],
#  [' ',
#   'production',
#   'shale',
#   'oil',
#   'prices',
#   'approach',
#   'industry',
#   'drillers',
#   'way',
#   'plunging',
#   'latest',
#   'variant',
#   'selloff',
#   'U.S.',
#   'stocks',
#   'patch',
#   'discipline',
#   'cash',
#   'disciplined',
#   'said',
#   'depletion'],
#  ['oil',
#   ' ',
#   'Biden',
#   'prices',
#   'Administration',
#   'production',
#   'mdash',
#   'U.S.',
#   '   ',
#   'year',
#   'fossil',
#   'people',
#   'pump',
#   'President',
#   'higher',
#   'policies',
#   'supplies',
#   'meeting',
#   'demand',
#   'week',
#   'OPEC'],
#  ['oil',
#   ' ',
#   'prices',
#   'demand',
#   '$',
#   'higher',
#   'barrel',
#   'year',
#   'said',
#   'supply',
#   'bullish',
#   'remains',
#   'U.S.',
#   'rdquo',
#   '90',
#   'month',
#   'OPEC',
#   'price',
#   'view',
#   'note',
#   'Brent'],
#  [' ',
#   'OPEC',
#   'oil',
#   'pump',
#   'tools',
#   'President',
#   'Biden',
#   'said',
#   'crude',
#   'Washington',
#   'global',
#   'recovery',
#   'arsenal',
#   'countries',
#   'supply',
#   'response',
#   'calls',
#   'prices',
#   'respond',
#   'quoted',
#   'administration'],
#  ['OPEC',
#   'Morse',
#   'production',
#   ' ',
#   'oil',
#   'prices',
#   'said',
#   'U.S.',
#   'capacity',
#   'year',
#   'continue',
#   'role',
#   'members',
#   'administration',
#   'embarrassing',
#   'moment',
#   'levels',
#   'Crude',
#   'rising',
#   'quarter',
#   'global'],
#  [' ',
#   'oil',
#   'million',
#   'prices',
#   'U.S.',
#   'Fed',
#   '$',
#   'inflation',
#   'supply',
#   'crude',
#   'barrels',
#   'year',
#   'week',
#   'bullish',
#   'high',
#   'economic',
#   'demand',
#   'Brent',
#   'month',
#   'build',
#   'funds'],
#  [' ',
#   'crude',
#   'oil',
#   'barrels',
#   'prices',
#   'market',
#   'Fed',
#   'inventory',
#   'API',
#   'million',
#   'week',
#   'Wednesday',
#   'U.S.',
#   'year',
#   'fell',
#   'tapering',
#   'asset',
#   'inflation',
#   'EIA',
#   'report',
#   'announcement'],
#  [' ',
#   'prices',
#   'oil',
#   'energy',
#   'inflation',
#   'rdquo',
#   'supply',
#   'year',
#   'demand',
#   'high',
#   'major',
#   'analysts',
#   'banks',
#   'economic',
#   'higher',
#   'asset',
#   '$',
#   'recession',
#   'investment',
#   'rise',
#   'market'],
#  ['oil',
#   ' ',
#   'production',
#   '$',
#   'OPEC',
#   'price',
#   '100',
#   'prices',
#   'U.S.',
#   'WTI',
#   'years',
#   'demand',
#   'market',
#   'barrel',
#   '2014',
#   'significant',
#   'reason',
#   '2008',
#   'million',
#   'BPD',
#   'markets'],
#  [' ',
#   'oil',
#   'China',
#   'reserve',
#   'price',
#   'Chinese',
#   'supply',
#   'prices',
#   'crude',
#   'news',
#   'gasoline',
#   'fuel',
#   'National',
#   'Food',
#   'Strategic',
#   'Reserve',
#   'Administration',
#   'reserves',
#   'quoted',
#   'releases',
#   'Energy'],
#  [' ',
#   'gas',
#   'prices',
#   'natural',
#   'inventories',
#   'oil',
#   'demand',
#   'w',
#   'energy',
#   '$',
#   'years',
#   'crude',
#   'storage',
#   'crisis',
#   'latest',
#   'average',
#   'Cushing',
#   'says',
#   'increase',
#   'year',
#   'seasonal'],
#  [' ',
#   'oil',
#   '$',
#   'prices',
#   'weather',
#   'cold',
#   'gas',
#   'said',
#   'year',
#   '90',
#   'barrel',
#   'Ollenberg',
#   'end',
#   'demand',
#   'hit',
#   '100',
#   'winter',
#   'turns',
#   'analyst',
#   'adding',
#   'natural'],
#  ['China',
#   ' ',
#   'Monday',
#   'oil',
#   'COVID',
#   'flare',
#   'market',
#   'quickly',
#   'Chinese',
#   'said',
#   'demand',
#   '$',
#   'residents',
#   'county',
#   'lockdown',
#   'contain',
#   'new',
#   'bullish',
#   'sentiment',
#   'fresh',
#   'outbreak'],
#  [' ',
#   'oil',
#   '$',
#   'Thursday',
#   'barrels',
#   'Crude',
#   'prices',
#   'year',
#   'million',
#   'Wednesday',
#   'crude',
#   'inventories',
#   'Brent',
#   'early',
#   'week',
#   'barrel',
#   'highest',
#   'level',
#   'taking',
#   'bullish',
#   'EIA'],
#  ['nbsp',
#   'oil',
#   '$',
#   ' ',
#   'prices',
#   'said',
#   'barrel',
#   'minister',
#   '100',
#   'global',
#   'OPEC',
#   'Oil',
#   'group',
#   'Iraqi',
#   'demand',
#   'winter',
#   'hit',
#   '2022',
#   'amid',
#   'Jabbar',
#   'Ismaael'],
#  [' ',
#   'prices',
#   'coal',
#   '$',
#   'early',
#   'Wednesday',
#   'intervention',
#   'price',
#   'Oil',
#   'China',
#   'Crude',
#   'Chinese',
#   'week',
#   'estimated',
#   'dropped',
#   'said',
#   'considering',
#   'market',
#   'reduce',
#   'record',
#   'inventory'],
#  ['barrel',
#   ' ',
#   '2021',
#   'Saudi',
#   'November',
#   'month',
#   'Basrah',
#   'ndash',
#   'cut',
#   'Aramco',
#   'prices',
#   'cargoes',
#   'Asian',
#   'production',
#   'market',
#   'Graph',
#   'USD',
#   'Source',
#   'Arab',
#   'Dubai',
#   'Europe'],
#  [' ',
#   'Tuesday',
#   'said',
#   '$',
#   'rdquo',
#   'prices',
#   'Monday',
#   'Oil',
#   'Crude',
#   'September',
#   'demand',
#   'oil',
#   'market',
#   'analysts',
#   'multi',
#   'year',
#   'highs',
#   'global',
#   'crunch',
#   'WTI',
#   'highest'],
#  ['oil',
#   'prices',
#   ' ',
#   '$',
#   '100',
#   'barrel',
#   'going',
#   'Catsimatidis',
#   'said',
#   'demand',
#   'winter',
#   'recent',
#   'weeks',
#   'looks',
#   'like',
#   'food',
#   'business',
#   'told',
#   'FOX',
#   'Business',
#   'rdquo'],
#  [' ',
#   'Monday',
#   '$',
#   'oil',
#   'gas',
#   'Brent',
#   'early',
#   'energy',
#   'Europe',
#   'natural',
#   'WTI',
#   'Crude',
#   'briefly',
#   'barrel',
#   'rdquo',
#   'said',
#   'Oil',
#   'prices',
#   'gains',
#   'crisis',
#   'Asia'],
#  ['oil',
#   ' ',
#   'prices',
#   'demand',
#   'bpd',
#   'said',
#   'Crude',
#   '$',
#   'energy',
#   'gas',
#   'IEA',
#   'Friday',
#   'WTI',
#   'weekly',
#   'switch',
#   'market',
#   'Thursday',
#   'global',
#   'rdquo',
#   'year',
#   'expected'],
#  [' ',
#   'variant',
#   'early',
#   'Tuesday',
#   'Omicron',
#   'oil',
#   'Monday',
#   'rdquo',
#   'Oil',
#   'prices',
#   'market',
#   'demand',
#   'nbsp',
#   'Crude',
#   '$',
#   'Saudi',
#   'Arabia',
#   'optimism',
#   'official',
#   'crude',
#   'selling'],
#  ['oil',
#   'prices',
#   ' ',
#   '$',
#   '100',
#   'demand',
#   'said',
#   'barrel',
#   'Putin',
#   'gas',
#   'Russian',
#   'OPEC',
#   'group',
#   'despite',
#   'natural',
#   'winter',
#   'global',
#   'hit',
#   'want',
#   'market',
#   'shock'],
#  [' ',
#   'oil',
#   '$',
#   'prices',
#   'Bloomberg',
#   'year',
#   'timespread',
#   'futures',
#   'United',
#   'States',
#   'crude',
#   'According',
#   'delivery',
#   'start',
#   'pump',
#   'Cushing',
#   'end',
#   'market',
#   'told',
#   'Oilprice.com',
#   'Prices'],
#  [' ',
#   '$',
#   'coal',
#   'gas',
#   'oil',
#   'Monday',
#   'Oil',
#   'benchmark',
#   'week',
#   'prices',
#   'Europe',
#   'Crude',
#   'time',
#   'power',
#   'high',
#   'Gas',
#   'extended',
#   'rally',
#   'U.S.',
#   'topping',
#   'trading'],
#  [' ',
#   'prices',
#   'supply',
#   'oil',
#   'gas',
#   'winter',
#   'Friday',
#   '$',
#   'Oil',
#   'natural',
#   'Crude',
#   'demand',
#   'OPEC',
#   'crude',
#   'Energy',
#   'early',
#   'headed',
#   'week',
#   'U.S.',
#   'benchmark',
#   'WTI'],
#  [' ',
#   'oil',
#   'bbl',
#   'OPEC',
#   'prices',
#   '$',
#   'USD',
#   'price',
#   'market',
#   'Stanchart',
#   'economy',
#   'gas',
#   'rally',
#   'Global',
#   'higher',
#   'bearish',
#   '80',
#   '2022',
#   'Energy',
#   'markets',
#   'Wall'],
#  [' ',
#   'prices',
#   'oil',
#   'U.S.',
#   'Energy',
#   'administration',
#   'gas',
#   'year',
#   'OPEC',
#   'release',
#   'crude',
#   'emergency',
#   'reserve',
#   'pump',
#   'ban',
#   'Granholm',
#   'said',
#   'tools',
#   'gasoline',
#   'AAA',
#   'earlier'],
#  [' ',
#   'oil',
#   'bpd',
#   'prices',
#   'million',
#   'Aramco',
#   '$',
#   'cut',
#   'crude',
#   'price',
#   'barrel',
#   'said',
#   'gas',
#   'demand',
#   'capacity',
#   '13',
#   'selling',
#   'buyers',
#   'rise',
#   'OPEC',
#   'total'],
#  [' ',
#   'oil',
#   'prices',
#   'inflation',
#   '$',
#   'U.S.',
#   'high',
#   'year',
#   'gas',
#   'government',
#   'price',
#   'Oil',
#   'Biden',
#   '4',
#   'economy',
#   'consumer',
#   'spending',
#   'dollar',
#   'pandemic',
#   'economic',
#   'experts'],
#  [' ',
#   'oil',
#   'prices',
#   'Tuesday',
#   'gas',
#   'level',
#   '$',
#   'year',
#   'said',
#   'price',
#   'highest',
#   'high',
#   'rdquo',
#   'Asia',
#   'benchmark',
#   'U.S.',
#   'morning',
#   'seven',
#   'OPEC',
#   'supply',
#   '757'],
#  ['prices',
#   'oil',
#   ' ',
#   '$',
#   'energy',
#   'gas',
#   'winter',
#   '100',
#   'barrel',
#   'crisis',
#   'Bank',
#   'America',
#   'says',
#   'high',
#   'inflationary',
#   'BofA',
#   'demand',
#   'rdquo',
#   'natural',
#   'reopening',
#   'international'],
#  [' ',
#   'oil',
#   'bbl',
#   'USD',
#   'w',
#   'million',
#   'production',
#   'Brent',
#   '80',
#   'crude',
#   'barrels',
#   'September',
#   'market',
#   'OPEC',
#   'time',
#   'inventories',
#   'week',
#   'prices',
#   'rig',
#   'U.S.',
#   'Stanchart'],
#  ['prices',
#   'oil',
#   ' ',
#   '$',
#   'year',
#   'barrel',
#   'Europe',
#   'options',
#   'end',
#   'energy',
#   '200',
#   'Asia',
#   'Brent',
#   'record',
#   'months',
#   'month',
#   'traders',
#   'betting',
#   'winter',
#   '2022',
#   'data'],
#  ['gas',
#   ' ',
#   'oil',
#   '$',
#   'prices',
#   'natural',
#   'demand',
#   'market',
#   'Tuesday',
#   'Crude',
#   'time',
#   'crude',
#   'benchmark',
#   'highest',
#   'level',
#   'Europe',
#   'Asia',
#   'early',
#   'Brent',
#   'barrel',
#   'years'],
#  ['oil',
#   '$',
#   'barrel',
#   ' ',
#   'supply',
#   'Goldman',
#   'demand',
#   'prices',
#   'global',
#   'price',
#   'forecast',
#   'Brent',
#   'winter',
#   'recovery',
#   'Sachs',
#   '90',
#   '80',
#   'expected',
#   'end',
#   'year',
#   'week'],
#  [' ',
#   'oil',
#   '$',
#   'prices',
#   'supply',
#   'demand',
#   'winter',
#   'expected',
#   'Oil',
#   'Monday',
#   'Brent',
#   'Crude',
#   'barrel',
#   'global',
#   'energy',
#   'said',
#   'OPEC',
#   'early',
#   '80',
#   'WTI',
#   'U.S.'],
#  [' ',
#   'oil',
#   '$',
#   'bbl',
#   'crude',
#   'says',
#   'McGlone',
#   'Stanchart',
#   'prices',
#   'high',
#   'commodities',
#   'stones',
#   'growing',
#   'U.S.',
#   'mean',
#   'market',
#   'price',
#   'skimming',
#   'major',
#   'Brent',
#   '2018'],
#  [' ',
#   'oil',
#   '$',
#   'prices',
#   'gas',
#   'market',
#   'gains',
#   'U.S.',
#   'crude',
#   'boost',
#   'demand',
#   'barrel',
#   'Brent',
#   'high',
#   'production',
#   'rdquo',
#   'Friday',
#   'week',
#   'inventories',
#   'dropped',
#   'year'],
#  ['demand',
#   ' ',
#   'said',
#   'oil',
#   'gas',
#   'rdquo',
#   '$',
#   'year',
#   'crude',
#   'Crude',
#   'barrel',
#   'end',
#   'Vitol',
#   'chief',
#   'executive',
#   'Hardy',
#   'told',
#   'Bloomberg',
#   'According',
#   'supply',
#   'additional'],
#  ['oil',
#   ' ',
#   'demand',
#   '$',
#   '100',
#   'said',
#   'prices',
#   'Trafigura',
#   'rdquo',
#   'Rahim',
#   'Argus',
#   'year',
#   'chief',
#   'conditions',
#   'U.S.',
#   'told',
#   'end',
#   'worldrsquos',
#   'largest',
#   'traders',
#   'market'],
#  [' ',
#   'oil',
#   '$',
#   'winter',
#   'natural',
#   'gas',
#   'weather',
#   'prices',
#   'crude',
#   'barrel',
#   'colder',
#   'power',
#   'Europe',
#   'demand',
#   'trading',
#   'Brent',
#   'Goldman',
#   'said',
#   'Wednesday',
#   'effect',
#   'United'],
#  [' ',
#   'oil',
#   '$',
#   'OPEC',
#   'crude',
#   'barrel',
#   'analysts',
#   'bank',
#   'said',
#   'note',
#   'surplus',
#   'Morgan',
#   '2022',
#   'quarter',
#   'market',
#   'Deutsche',
#   'prices',
#   'year',
#   'pause',
#   'JP',
#   'forecast'],
#  [' ',
#   'prices',
#   'gas',
#   'oil',
#   'WD-143',
#   'platform',
#   'Tuesday',
#   'market',
#   'facilities',
#   'natural',
#   'potential',
#   'said',
#   'production',
#   'Oil',
#   'early',
#   'global',
#   'crunch',
#   'higher',
#   'demand',
#   'winter',
#   'season'],
#  [' ',
#   'oil',
#   'U.S.',
#   'week',
#   '$',
#   'prices',
#   'Monday',
#   'market',
#   'early',
#   'dollar',
#   'meeting',
#   'announce',
#   'tapering',
#   'production',
#   'Crude',
#   'day',
#   'broader',
#   'start',
#   'asset',
#   'Wednesday',
#   'risk'],
#  ['prices',
#   'oil',
#   'gas',
#   'winter',
#   'colder',
#   '$',
#   'barrel',
#   ' ',
#   'natural',
#   'Goldman',
#   'usual',
#   'global',
#   'market',
#   'months',
#   'year',
#   'potential',
#   'quarter',
#   'Sachs',
#   'price',
#   'combined',
#   'upside'],
#  [' ',
#   'oil',
#   'gas',
#   'price',
#   'plastics',
#   'prices',
#   'year',
#   'natural',
#   'energy',
#   '$',
#   'high',
#   'production',
#   'plastic',
#   'plants',
#   'higher',
#   'Natural',
#   'crisis',
#   'According',
#   'feeling',
#   'forced',
#   'major'],
#  [' ',
#   'prices',
#   'oil',
#   'weekly',
#   'Friday',
#   'week',
#   'demand',
#   'natural',
#   'gas',
#   'energy',
#   'seven',
#   'Wednesday',
#   'said',
#   'crude',
#   'rdquo',
#   'Oil',
#   'fourth',
#   'consecutive',
#   'gain',
#   'early',
#   'surging'],
#  ['Wirth',
#   ' ',
#   'oil',
#   'companies',
#   'interview',
#   'rdquo',
#   'said',
#   'create',
#   'wind',
#   'solar',
#   'gas',
#   'told',
#   'Bloomberg',
#   'investors',
#   'term',
#   'future',
#   'returns',
#   'equity',
#   'markets',
#   'Irsquom',
#   'investor'],
#  ['shale',
#   ' ',
#   'production',
#   'oil',
#   'companies',
#   'U.S.',
#   'investors',
#   'drilling',
#   'new',
#   'industry',
#   'wells',
#   'spending',
#   'cash',
#   'Energy',
#   'months',
#   'drillers',
#   'recovery',
#   'demand',
#   'lot',
#   'inventory',
#   'citing'],
#  ['demand',
#   'oil',
#   'Tuesday',
#   ' ',
#   'prices',
#   'IEA',
#   'day',
#   'Texas',
#   'Oil',
#   'early',
#   'said',
#   'rebound',
#   'storm',
#   'Gulf',
#   'Crude',
#   '$',
#   'bpd',
#   'highest',
#   'level',
#   'weeks',
#   'expects'],
#  [' ',
#   'oil',
#   'months',
#   'prices',
#   '$',
#   '100',
#   'winter',
#   'energy',
#   'barrel',
#   'markets',
#   'Bank',
#   'America',
#   'demand',
#   'said',
#   'BofA',
#   'June',
#   'analysts',
#   'Oil',
#   'hit',
#   'colder',
#   'important'],
#  [' ',
#   'oil',
#   'Friday',
#   'Chinese',
#   'Thursday',
#   'demand',
#   'crude',
#   'prices',
#   'U.S.',
#   '$',
#   'markets',
#   'rdquo',
#   'production',
#   'release',
#   'Oil',
#   'bullish',
#   'sentiment',
#   'strategic',
#   'Crude',
#   'trade',
#   'President'],
#  [' ',
#   'oil',
#   '$',
#   'bbl',
#   'day',
#   'shale',
#   'gas',
#   'previous',
#   'market',
#   'companies',
#   'Stanchart',
#   'high',
#   'production',
#   'price',
#   'days',
#   'trading',
#   '2022',
#   'ESG',
#   'investments',
#   'BlackRock',
#   'prices'],
#  ['oil',
#   '$',
#   'barrel',
#   ' ',
#   'prices',
#   'Brent',
#   'energy',
#   'said',
#   'ndash',
#   'Crude',
#   'end',
#   'Energy',
#   'new',
#   '200',
#   'higher',
#   'OPEC',
#   'production',
#   'shale',
#   'quarter',
#   'levels',
#   'rdquo'],
#  ['China',
#   'prices',
#   'oil',
#   'high',
#   'raw',
#   ' ',
#   'August',
#   'price',
#   'material',
#   'year',
#   'recent',
#   'months',
#   '   ',
#   'release',
#   'bbl',
#   'producer',
#   'inflation',
#   'Beijing',
#   'step',
#   'national',
#   'crude'],
#  [' ',
#   'oil',
#   'production',
#   'U.S.',
#   'percent',
#   'Wednesday',
#   'total',
#   'Gulf',
#   'shut',
#   'Hurricane',
#   'Ida',
#   '$',
#   'Es',
#   'Sider',
#   'Oil',
#   'prices',
#   'early',
#   'crude',
#   'Mexico',
#   'Louisiana',
#   'price'],
#  [' ',
#   'Russia',
#   '$',
#   'oil',
#   'barrel',
#   'Alekperov',
#   'OPEC',
#   'Lukoil',
#   'projects',
#   'percent',
#   'Brent',
#   'said',
#   'investments',
#   'outside',
#   'alliance',
#   'prices',
#   '65',
#   '75',
#   'price',
#   'told',
#   'Russian'],
#  ['oil',
#   ' ',
#   'prices',
#   'crude',
#   'U.S.',
#   'month',
#   'Tuesday',
#   'dollar',
#   'demand',
#   'market',
#   'Brent',
#   'imports',
#   'August',
#   'million',
#   'bpd',
#   'Gulf',
#   'production',
#   'Oil',
#   'morning',
#   'weighed',
#   'benchmark'],
#  [' ',
#   'Fed',
#   'oil',
#   'prices',
#   'tapering',
#   'August',
#   '$',
#   'jobs',
#   'WTI',
#   'weaker',
#   'expected',
#   'report',
#   'likely',
#   'losing',
#   'streak',
#   'data',
#   'push',
#   'taper',
#   'news',
#   'year',
#   'breaking'],
#  [' ',
#   'demand',
#   'prices',
#   '$',
#   'Thursday',
#   'oil',
#   'Crude',
#   '70',
#   'U.S.',
#   'inventory',
#   'crude',
#   'reported',
#   'draw',
#   'record',
#   'million',
#   'barrels',
#   'week',
#   'rdquo',
#   'Oil',
#   'early',
#   'WTI'],
#  [' ',
#   'oil',
#   'demand',
#   'Reuters',
#   '$',
#   '2021',
#   'year',
#   'set',
#   'prices',
#   'told',
#   'poll',
#   'forecast',
#   'Crude',
#   'month',
#   'Delta',
#   'variant',
#   'surge',
#   'COVID',
#   'globally',
#   'slow',
#   'recovery'],
#  [' ',
#   'oil',
#   'month',
#   'Oil',
#   'production',
#   'bpd',
#   'prices',
#   'likely',
#   'percent',
#   'Covid-19',
#   'refining',
#   'Gulf',
#   'OPEC',
#   'end',
#   'started',
#   '$',
#   'barrel',
#   'U.S.',
#   'markets',
#   'sources',
#   'fourth'],
#  ['oil',
#   ' ',
#   'new',
#   '$',
#   'weeks',
#   'news',
#   'SPR',
#   'release',
#   'variant',
#   'According',
#   'Bloomberg',
#   'percent',
#   'Omicron',
#   'OPEC',
#   'January',
#   'demand',
#   'U.S.',
#   'end',
#   'United',
#   'detected',
#   'suggest'],
#  [' ',
#   'oil',
#   'crude',
#   'bullish',
#   'major',
#   'rally',
#   'times',
#   'strategist',
#   'told',
#   'cross',
#   'chart',
#   'Maley',
#   'energy',
#   'market',
#   'Delta',
#   'percent',
#   'pattern',
#   'asset',
#   'century',
#   'CNBC',
#   'called'],
#  [' ',
#   'Pemex',
#   'fire',
#   'production',
#   'bpd',
#   'oil',
#   'gas',
#   'lost',
#   'platform',
#   'outage',
#   'Reuters',
#   'Romero',
#   'caused',
#   'said',
#   'Mexico',
#   'restored',
#   'erupted',
#   'offshore',
#   'reported',
#   'result',
#   'Ku'],
#  ['oil',
#   ' ',
#   'demand',
#   'week',
#   'news',
#   'Covid-19',
#   'prices',
#   'Reuters',
#   'million',
#   'barrels',
#   'infections',
#   'world',
#   'growing',
#   'vaccine',
#   'China',
#   'U.S.',
#   'traders',
#   'selling',
#   'analyst',
#   'remains',
#   'travel'],
#  [' ',
#   'oil',
#   '$',
#   'prices',
#   'crude',
#   'platform',
#   'early',
#   'Tuesday',
#   'demand',
#   'outage',
#   'Brent',
#   'market',
#   'approval',
#   'vaccine',
#   'Oil',
#   'extended',
#   'Mondayrsquos',
#   '5',
#   'major',
#   'supply',
#   'Crude'],
#  ['oil',
#   ' ',
#   'demand',
#   'market',
#   'prices',
#   'signal',
#   'stimulus',
#   'Crude',
#   'end',
#   'dollar',
#   'rdquo',
#   'Friday',
#   'growing',
#   'concerns',
#   'global',
#   'Fed',
#   '$',
#   'week',
#   'surging',
#   'cases',
#   'major'],
#  [' ',
#   'oil',
#   'bbl',
#   '$',
#   'high',
#   'day',
#   'Stanchart',
#   'skimming',
#   'stones',
#   'cycle',
#   'Brent',
#   'dollar',
#   'days',
#   'previous',
#   'U.S.',
#   'price',
#   'sub',
#   'trading',
#   'Biden',
#   'prices',
#   'fact'],
#  ['oil',
#   ' ',
#   'prices',
#   '$',
#   'month',
#   'concern',
#   'start',
#   'winding',
#   'bond',
#   'buying',
#   'economy',
#   'Fed',
#   'report',
#   'coronavirus',
#   '120',
#   'billion',
#   'monthly',
#   'According',
#   'latest',
#   'crude',
#   'West'],
#  [' ',
#   'oil',
#   'prices',
#   'output',
#   'demand',
#   'crude',
#   'year',
#   'July',
#   'OPEC',
#   'U.S.',
#   'week',
#   'pre',
#   'pandemic',
#   'month',
#   'rates',
#   'months',
#   'rig',
#   'count',
#   'confidence',
#   'global',
#   'price'],
#  [' ',
#   'U.S.',
#   'oil',
#   'Tuesday',
#   'demand',
#   'week',
#   'prices',
#   '$',
#   'Monday',
#   'said',
#   'barrels',
#   'million',
#   'gasoline',
#   'day',
#   'Crude',
#   'concerns',
#   'crude',
#   'rdquo',
#   'Vanda',
#   'Insights',
#   'shale'],
#  ['US$',
#   'price',
#   'oil',
#   'barrel',
#   'U.S.',
#   'gasoline',
#   'prices',
#   'crude',
#   'OPEC',
#   'Brent',
#   ' ',
#   'gallon',
#   'election',
#   'President',
#   'cap',
#   'years',
#   'reasons',
#   'economy',
#   '75',
#   '80',
#   '2014'],
#  [' ',
#   'demand',
#   'China',
#   'data',
#   'Monday',
#   'U.S.',
#   'consumer',
#   'oil',
#   'fuel',
#   'economic',
#   'July',
#   'Chinese',
#   'said',
#   'Consumers',
#   'prices',
#   'percent',
#   'weak',
#   'economy',
#   'confidence',
#   'Crude',
#   '$'],
#  [' ',
#   'oil',
#   'prices',
#   'demand',
#   'key',
#   'port',
#   'said',
#   'second',
#   'Friday',
#   'China',
#   'Asia',
#   'rdquo',
#   'crude',
#   'Oil',
#   'hit',
#   'terminal',
#   'busiest',
#   'world',
#   'Crude',
#   '$',
#   'Thursday'],
#  ['oil',
#   ' ',
#   'demand',
#   '$',
#   'prices',
#   'market',
#   'Monday',
#   'Tuesday',
#   'crude',
#   'price',
#   'Brent',
#   'OPEC',
#   'low',
#   'weakness',
#   'importer',
#   'Crude',
#   'day',
#   'COVID',
#   'July',
#   'following',
#   'Oil'],
#  ['$',
#   'billion',
#   ' ',
#   'year',
#   'Aramco',
#   'percent',
#   'second',
#   'quarter',
#   'increase',
#   'net',
#   'half',
#   'earlier',
#   'dividend',
#   'pipeline',
#   'business',
#   'Saudi',
#   'reported',
#   'profits',
#   'company',
#   'cash',
#   'flow'],
#  ['oil',
#   ' ',
#   'Saudi',
#   'prices',
#   'latest',
#   'year',
#   'Chinarsquos',
#   'raised',
#   'selling',
#   'crude',
#   '$',
#   'month',
#   'Bloomberg',
#   'largest',
#   'OPEC',
#   'biggest',
#   'demand',
#   'resurgence',
#   'likely',
#   'competitive',
#   'alternatives'],
#  [' ',
#   'cases',
#   'oil',
#   'China',
#   'travel',
#   'demand',
#   'Asia',
#   'new',
#   'worst',
#   'fuel',
#   'prices',
#   'early',
#   'Friday',
#   'March',
#   'COVID',
#   'Crude',
#   '$',
#   'week',
#   'Delta',
#   'variant',
#   'rest'],
#  ['oil',
#   ' ',
#   'prices',
#   'Thursday',
#   'demand',
#   'NYSE',
#   'crude',
#   'Oil',
#   'morning',
#   'energy',
#   'stocks',
#   'higher',
#   'concerns',
#   'rising',
#   'COVID',
#   'cases',
#   'early',
#   'continued',
#   'new',
#   'EDT',
#   'Crude'],
#  [' ',
#   'Exxon',
#   'shale',
#   '$',
#   'oil',
#   'production',
#   'U.S.',
#   'Y',
#   'earnings',
#   'company',
#   'gas',
#   'years',
#   'says',
#   'debt',
#   'prices',
#   'year',
#   'day',
#   'Permian',
#   'cash',
#   'record',
#   '1'],
#  ['$',
#   ' ',
#   'oil',
#   'Saudi',
#   'Asia',
#   'barrel',
#   'price',
#   'September',
#   'Aramco',
#   'crude',
#   'grades',
#   'raised',
#   'prices',
#   'Middle',
#   'Arab',
#   'expected',
#   'premium',
#   'going',
#   'pricing',
#   'OSPs',
#   'Light'],
#  [' ',
#   'Tuesday',
#   'variant',
#   'Delta',
#   'China',
#   'rdquo',
#   'Crude',
#   '$',
#   'early',
#   'cases',
#   'spread',
#   'said',
#   'U.S.',
#   'WTI',
#   'day',
#   'sell',
#   'economies',
#   'prices',
#   '3',
#   'Chinese',
#   'according'],
#  [' ',
#   'oil',
#   'markets',
#   'demand',
#   'Iran',
#   'U.S.',
#   'expectations',
#   'attack',
#   'prices',
#   'additional',
#   'strong',
#   'concerns',
#   'believe',
#   'Eberhart',
#   'Canary',
#   'nuclear',
#   'week',
#   'killed',
#   'said',
#   'Secretary',
#   'Blinken'],
#  [' ',
#   'oil',
#   '$',
#   'Delta',
#   'variant',
#   'Monday',
#   'number',
#   'demand',
#   'vaccinated',
#   'prices',
#   'started',
#   'trading',
#   'Mondayrsquos',
#   'barrel',
#   'coronavirus',
#   'importer',
#   'spread',
#   'outbreak',
#   'increase',
#   'people',
#   'surrounding'],
#  [' ',
#   'oil',
#   'Monday',
#   'gains',
#   'OPEC',
#   'early',
#   'August',
#   'higher',
#   'Friday',
#   'rdquo',
#   'said',
#   'market',
#   'China',
#   'bpd',
#   'attack',
#   'Oil',
#   'prices',
#   'start',
#   'fourth',
#   'month',
#   'July'],
#  ['$',
#   'prices',
#   ' ',
#   'Brent',
#   'oil',
#   'Reuters',
#   'analysts',
#   'barrel',
#   'year',
#   'poll',
#   'believe',
#   'Crude',
#   'economists',
#   'rest',
#   '80',
#   'COVID',
#   'variants',
#   'Friday',
#   'expected',
#   'higher',
#   'price'],
#  [' ',
#   'Monday',
#   'early',
#   'market',
#   'variant',
#   'prices',
#   'percent',
#   'Delta',
#   'rdquo',
#   'key',
#   'week',
#   'said',
#   'oil',
#   'demand',
#   'trading',
#   'slightly',
#   'fallen',
#   '1',
#   'Asia',
#   'factor',
#   'tight'],
#  ['oil',
#   ' ',
#   'market',
#   'volatility',
#   'prices',
#   'price',
#   'OPEC',
#   'demand',
#   '$',
#   'traders',
#   'participants',
#   'U.S.',
#   'options',
#   'coming',
#   'data',
#   'recovery',
#   'Monday',
#   'Delta',
#   'variant',
#   'generally',
#   'period'],
#  ['week',
#   'million',
#   ' ',
#   'barrels',
#   'inventory',
#   'oil',
#   'build',
#   'July',
#   'compared',
#   'previous',
#   'prices',
#   'crude',
#   '16',
#   'reported',
#   '$',
#   'gasoline',
#   'bpd',
#   'draw',
#   'barrel',
#   'day',
#   'demand'],
#  [' ',
#   '$',
#   'crude',
#   'oil',
#   'Wednesday',
#   'API',
#   'week',
#   'prices',
#   'report',
#   'inventory',
#   'million',
#   'early',
#   'Asia',
#   'Tuesday',
#   'build',
#   'inventories',
#   'barrels',
#   'July',
#   'draw',
#   'barrel',
#   'EIA'],
#  [' ',
#   'oil',
#   'prices',
#   'OPEC',
#   'week',
#   'market',
#   'managers',
#   'supply',
#   'July',
#   'long',
#   'contracts',
#   'petroleum',
#   'short',
#   'positions',
#   'taking',
#   'profits',
#   'hit',
#   'highs',
#   'buying',
#   'money',
#   'continued'],
#  ['oil',
#   ' ',
#   'market',
#   'demand',
#   'prices',
#   'Tuesday',
#   'new',
#   '$',
#   'Delta',
#   'variant',
#   'nearly',
#   'Monday',
#   'saw',
#   'WTI',
#   'sharply',
#   'price',
#   'time',
#   'additional',
#   'production',
#   'quotas',
#   '400,000'],
#  ['$',
#   ' ',
#   'OPEC',
#   'barrel',
#   'oil',
#   'Goldman',
#   '80',
#   'group',
#   'production',
#   'agreement',
#   'reached',
#   'forecast',
#   'Brent',
#   'summer',
#   'said',
#   'bpd',
#   'Sachs',
#   'despite',
#   'market',
#   'deal',
#   'Sunday'],
#  ['OPEC',
#   ' ',
#   '$',
#   'market',
#   'oil',
#   'supply',
#   'Crude',
#   'barrel',
#   'prices',
#   'percent',
#   'Monday',
#   'demand',
#   'Brent',
#   'deal',
#   'production',
#   'early',
#   'WTI',
#   'bpd',
#   'alliance',
#   'rising',
#   'global'],
#  [' ',
#   'oil',
#   'prices',
#   'million',
#   'week',
#   'OPEC',
#   'Energy',
#   'barrels',
#   'production',
#   'supply',
#   'inventory',
#   'United',
#   'Saudi',
#   'allow',
#   'reached',
#   'deal',
#   'Emirati',
#   'coverage',
#   'time',
#   'Voice',
#   'agreement'],
#  ['week',
#   'million',
#   ' ',
#   'OPEC',
#   'UAE',
#   'barrels',
#   'bpd',
#   'Oil',
#   'prices',
#   'Thursday',
#   'reported',
#   'Wednesday',
#   'baseline',
#   'production',
#   'oil',
#   'market',
#   'crude',
#   'supply',
#   'compromise',
#   'Saudi',
#   'Arabia'],
#  ['oil',
#   'production',
#   ' ',
#   'OPEC',
#   'million',
#   'bpd',
#   'deal',
#   'year',
#   'agreement',
#   'UAE',
#   'baseline',
#   'reached',
#   'Emirati',
#   'Goldman',
#   '$',
#   '80',
#   'Brent',
#   'Saudi',
#   'Emirates',
#   'end',
#   'future'],
#  ['oil',
#   ' ',
#   'prices',
#   'market',
#   'compromise',
#   'percent',
#   'demand',
#   'crude',
#   'million',
#   'imports',
#   'barrels',
#   'year',
#   'Tuesday',
#   'half',
#   'Oil',
#   'Wednesday',
#   'reported',
#   'Saudi',
#   'UAE',
#   'production',
#   'uncertainty'],
#  ['oil',
#   ' ',
#   'prices',
#   'economic',
#   'economies',
#   'developed',
#   'growth',
#   'higher',
#   '$',
#   'analysts',
#   'term',
#   'burden',
#   'rising',
#   'share',
#   'GDP',
#   'long',
#   'percent',
#   'average',
#   'demand',
#   'barrel',
#   'earlier'],
#  ['year',
#   'half',
#   'inventory',
#   'spreads',
#   ' ',
#   'levels',
#   'oil',
#   'spread',
#   'draws',
#   'calendar',
#   'expiration',
#   'inventories',
#   'second',
#   'month',
#   'pattern',
#   'Dec',
#   'backwardation',
#   '2020',
#   '2021',
#   'crude',
#   'higher'],
#  ['$',
#   ' ',
#   'prices',
#   'average',
#   'oil',
#   'b',
#   'Brent',
#   'price',
#   'forecast',
#   'July',
#   'spot',
#   'year',
#   'EIA',
#   'demand',
#   'supply',
#   'WTI',
#   'U.S.',
#   'said',
#   '2022',
#   'June',
#   'forecasts'],
#  ['oil',
#   'prices',
#   ' ',
#   'OPEC',
#   'high',
#   'long',
#   'consumers',
#   'economic',
#   'U.S.',
#   'price',
#   'pandemic',
#   'sector',
#   'devastation',
#   'gas',
#   '2020',
#   'talks',
#   '$',
#   'barrel',
#   'United',
#   'rdquo',
#   'March'],
#  ['oil',
#   ' ',
#   'crude',
#   'variant',
#   'prices',
#   'week',
#   'demand',
#   '$',
#   'Brent',
#   'latest',
#   'bullish',
#   'million',
#   'barrels',
#   'November',
#   'according',
#   'Omicron',
#   'new',
#   'barrel',
#   'confidence',
#   'OPEC',
#   'news'],
#  [' ',
#   'market',
#   'Thursday',
#   'OPEC',
#   'COVID',
#   '$',
#   'period',
#   'cases',
#   'fell',
#   'uncertainty',
#   'weekly',
#   'inventory',
#   'Crude',
#   'percent',
#   'Brent',
#   'API',
#   'crude',
#   'oil',
#   'week',
#   'UAE',
#   'increased'],
#  [' ',
#   'oil',
#   'hedging',
#   'producers',
#   '$',
#   'shale',
#   'prices',
#   'U.S.',
#   'right',
#   'report',
#   'production',
#   'wants',
#   'Reuters',
#   'losses',
#   'citing',
#   'IHS',
#   'Markit',
#   'barrel',
#   'selling',
#   'half',
#   'year'],
#  [' ',
#   'production',
#   'mm',
#   'OPEC',
#   'BOPD',
#   'year',
#   'Russia',
#   'output',
#   'producers',
#   'oil',
#   'prices',
#   'capacity',
#   'new',
#   'shale',
#   '2021',
#   'demand',
#   'article',
#   'UAE',
#   'noted',
#   'increases',
#   'increase'],
#  [' ',
#   'oil',
#   'U.S.',
#   'prices',
#   'Wednesday',
#   'OPEC',
#   'supply',
#   'crude',
#   'market',
#   'dollar',
#   'rdquo',
#   'said',
#   'assess',
#   'demand',
#   'Crude',
#   'percent',
#   '$',
#   'trade',
#   'stronger',
#   'morning',
#   'term'],
#  [' ',
#   'OPEC',
#   'oil',
#   '$',
#   'supply',
#   'market',
#   'rdquo',
#   'production',
#   'prices',
#   'group',
#   'Saudi',
#   'demand',
#   'analysts',
#   'UAE',
#   'price',
#   'alliance',
#   'month',
#   'time',
#   'said',
#   'August',
#   '90'],
#  ['OPEC',
#   ' ',
#   'oil',
#   'prices',
#   'WTI',
#   'Crude',
#   'said',
#   'supply',
#   'rising',
#   'price',
#   'level',
#   'Monday',
#   'called',
#   'management',
#   'months',
#   'meeting',
#   'market',
#   'deal',
#   'global',
#   'collapse',
#   'year'],
#  [' ',
#   'oil',
#   'OPEC',
#   'price',
#   'production',
#   'Saudi',
#   'August',
#   'prices',
#   'war',
#   'barrel',
#   'year',
#   'agreement',
#   'million',
#   'Aramco',
#   'crude',
#   'market',
#   'Biden',
#   'administration',
#   'settle',
#   'differences',
#   'Bloomberg'],
#  [' ',
#   'UAE',
#   'production',
#   'OPEC',
#   'Saudi',
#   'million',
#   'year',
#   'exclude',
#   'goods',
#   'talks',
#   'Arabia',
#   'opposed',
#   'ldquounfairrdquo',
#   'Saudis',
#   'tariff',
#   'amendments',
#   'designed',
#   'Chief',
#   'meeting',
#   'indications',
#   'bpd'],
#  [' ',
#   'group',
#   'Monday',
#   'OPEC',
#   'UAE',
#   'prices',
#   'trading',
#   'early',
#   'market',
#   'day',
#   'production',
#   'baseline',
#   'slightly',
#   'begin',
#   'oil',
#   'a.m.',
#   'EDT',
#   'Crude',
#   'percent',
#   '$',
#   'meeting'],
#  ['UAE',
#   ' ',
#   'production',
#   'OPEC',
#   'agreement',
#   'oil',
#   'Al',
#   'exclude',
#   'Saudi',
#   'challenge',
#   'million',
#   'deal',
#   'year',
#   'extension',
#   'GCC',
#   'goods',
#   'proposal',
#   'extend',
#   'end',
#   'Monday',
#   'morning'],
#  ['oil',
#   'prices',
#   'markets',
#   'production',
#   ' ',
#   'China',
#   'U.S.',
#   'sentiment',
#   '$',
#   '100',
#   'bearish',
#   'Chinese',
#   'shift',
#   'Oil',
#   'geopolitical',
#   'increase',
#   'rigs',
#   '2021',
#   'global',
#   'plenty',
#   'factors'],
#  [' ',
#   'market',
#   'prices',
#   'OPEC',
#   'said',
#   'production',
#   'barrels',
#   '$',
#   'add',
#   'bpd',
#   'oil',
#   'lower',
#   'today',
#   'return',
#   'Brent',
#   'crude',
#   'barrel',
#   'agreement',
#   'expected',
#   'come',
#   'mean'],
#  [' ',
#   'OPEC',
#   '$',
#   'increase',
#   'Reuters',
#   'JMMC',
#   'Russia',
#   'output',
#   '2',
#   'million',
#   'barrels',
#   'day',
#   'August',
#   'December',
#   'said',
#   'EDT',
#   'Bakr',
#   'Chief',
#   'proposal',
#   'oil',
#   'sentiments'],
#  ['OPEC',
#   'bpd',
#   ' ',
#   'million',
#   'August',
#   '2',
#   'meeting',
#   'end',
#   'agreement',
#   'ndash',
#   'increase',
#   'supply',
#   'market',
#   '$',
#   'Thursday',
#   'Russia',
#   'gradual',
#   'December',
#   'EDT',
#   'Crude',
#   'output'],
#  ['oil',
#   ' ',
#   'prices',
#   'supply',
#   '$',
#   'Hamm',
#   'said',
#   '100',
#   'rdquo',
#   'executive',
#   'market',
#   'barrel',
#   'demand',
#   'week',
#   'today',
#   'chairman',
#   'Continental',
#   'told',
#   'FOX',
#   'Business',
#   'coming'],
#  ['oil',
#   ' ',
#   'crude',
#   'demand',
#   'market',
#   'Brent',
#   'WTI',
#   'Crude',
#   'U.S.',
#   'week',
#   'June',
#   'futures',
#   '$',
#   'OPEC',
#   'driving',
#   'prices',
#   'physical',
#   'Asia',
#   'regional',
#   'benchmark',
#   'grades'],
#  [' ',
#   'market',
#   'Wednesday',
#   'oil',
#   'demand',
#   'WTI',
#   'percent',
#   'week',
#   'said',
#   'prices',
#   'rose',
#   'economic',
#   'United',
#   'States',
#   'inventory',
#   'U.S.',
#   'EIA',
#   'Crude',
#   '$',
#   'Brent',
#   'support'],
#  [' ',
#   'oil',
#   '$',
#   'prices',
#   'Iran',
#   'nuclear',
#   'WTI',
#   'barrel',
#   'crude',
#   'market',
#   'hardliner',
#   'risen',
#   'roughly',
#   'Brent',
#   'pricing',
#   '100',
#   'new',
#   'president',
#   'hopes',
#   'sanctions',
#   'Market'],
#  ['oil',
#   ' ',
#   'prices',
#   '$',
#   'demand',
#   'supply',
#   'barrel',
#   'production',
#   'pandemic',
#   'year',
#   'energy',
#   'usual',
#   'gas',
#   '35',
#   'investment',
#   'new',
#   '100',
#   'time',
#   'International',
#   'question',
#   'peak'],
#  ['oil',
#   ' ',
#   'prices',
#   '$',
#   'barrel',
#   'BofA',
#   'demand',
#   'supply',
#   'said',
#   'Global',
#   'rdquo',
#   'average',
#   'Brent',
#   'year',
#   'strong',
#   'recovery',
#   'outpace',
#   'months',
#   'lead',
#   '100',
#   '2022'],
#  ['oil',
#   ' ',
#   'supply',
#   'prices',
#   'year',
#   'demand',
#   '$',
#   'OPEC',
#   '100',
#   'rdquo',
#   'global',
#   'market',
#   'time',
#   'expected',
#   'crude',
#   'bullish',
#   'said',
#   'levels',
#   'Oil',
#   'high',
#   'higher'],
#  [' ',
#   'week',
#   'oil',
#   'U.S.',
#   'WTI',
#   'Brent',
#   'percent',
#   'Crude',
#   'million',
#   'bpd',
#   '$',
#   'demand',
#   'production',
#   'recent',
#   'gasoline',
#   'June',
#   'compared',
#   'said',
#   'barrel',
#   'crude',
#   'spread'],
#  [' ',
#   'oil',
#   'prices',
#   '$',
#   'dollar',
#   'week',
#   'Thursday',
#   'afternoon',
#   'WTI',
#   'Wednesday',
#   'said',
#   'inflation',
#   'expected',
#   'earlier',
#   'U.S.',
#   'demand',
#   'crude',
#   'inventories',
#   'loss',
#   'price',
#   'million'],
#  ['oil',
#   ' ',
#   'energy',
#   'world',
#   'emissions',
#   'Oil',
#   'transition',
#   'renewable',
#   'fossil',
#   'fuels',
#   'demand',
#   'investors',
#   'investing',
#   'new',
#   'companies',
#   'industry',
#   'pressure',
#   'Shell',
#   'earlier',
#   '$',
#   'Big'],
#  [' ',
#   'demand',
#   'oil',
#   '$',
#   'prices',
#   'recent',
#   'OPEC',
#   'days',
#   'week',
#   'higher',
#   'crude',
#   'rdquo',
#   'said',
#   'global',
#   'tight',
#   'downside',
#   'risks',
#   'jumped',
#   'bullish',
#   'outlooks',
#   'Iran'],
#  ['Dangote',
#   'Refinery',
#   'Nigerian',
#   'refinery',
#   'NNPC',
#   'refineries',
#   'Nigeria',
#   ' ',
#   'government',
#   'ndash',
#   'Port',
#   '2019',
#   'Nigeriarsquos',
#   'domestic',
#   'oil',
#   'private',
#   'downstream',
#   'Harcourt',
#   'product',
#   'demand',
#   'company'],
#  ['oil',
#   ' ',
#   'prices',
#   'production',
#   'OPEC',
#   'higher',
#   'Middle',
#   'consumption',
#   'report',
#   'summer',
#   'Saudi',
#   'million',
#   'members',
#   'buyers',
#   'spare',
#   'crude',
#   'East',
#   'year',
#   'usual',
#   'electricity',
#   'Arabia'],
#  [' ',
#   'oil',
#   'new',
#   'exploration',
#   'production',
#   'said',
#   'Wunti',
#   'declining',
#   '$',
#   '200',
#   'barrel',
#   'companies',
#   'investments',
#   'National',
#   'investment',
#   'years',
#   'NNPCrsquos',
#   'Petroleum',
#   'Nigeria',
#   'International',
#   'rdquo'],
#  [' ',
#   'oil',
#   '$',
#   'barrel',
#   'EIA',
#   'prices',
#   'forecast',
#   'price',
#   'production',
#   'Crude',
#   'average',
#   'U.S.',
#   'said',
#   'crude',
#   'million',
#   'bpd',
#   'Brent',
#   'year',
#   'monthly',
#   'June',
#   'STEO'],
#  [' ',
#   'oil',
#   'said',
#   '$',
#   'barrel',
#   'year',
#   'IEA',
#   'world',
#   'price',
#   'end',
#   'week',
#   'demand',
#   'Brent',
#   'according',
#   'head',
#   'Iranian',
#   'Mizuho',
#   'executive',
#   'rdquo',
#   'global',
#   'ldquoThe'],
#  [' ',
#   '$',
#   'prices',
#   'week',
#   'United',
#   'States',
#   'Crude',
#   'demand',
#   'oil',
#   'Friday',
#   'U.S.',
#   'percent',
#   'Brent',
#   'Thursday',
#   'said',
#   'Oil',
#   'rising',
#   'return',
#   'Iranian',
#   'nuclear',
#   'deal'],
#  ['oil',
#   ' ',
#   '   ',
#   'prices',
#   'demand',
#   'said',
#   'energy',
#   'Novak',
#   'carbon',
#   'global',
#   'Minister',
#   'OPEC',
#   'August',
#   'output',
#   'current',
#   'Petersburg',
#   'International',
#   'price',
#   'increase',
#   '$',
#   'IEA'],
#  ['demand',
#   ' ',
#   'oil',
#   'prices',
#   'OPEC',
#   'quoted',
#   'told',
#   'inflation',
#   'supply',
#   'planned',
#   'production',
#   'Bloomberg',
#   'Saudi',
#   'Energy',
#   'bin',
#   'Salman',
#   'crude',
#   'economic',
#   'recovery.rdquo',
#   'Iran',
#   'U.S.'],
#  ['OPEC',
#   ' ',
#   'meeting',
#   'oil',
#   'market',
#   'JMMC',
#   '$',
#   'year',
#   'rdquo',
#   'production',
#   'mb',
#   'd',
#   'Barkindo',
#   'Tuesday',
#   'signaled',
#   'barrels',
#   'Crude',
#   'percent',
#   'Brent',
#   'earlier',
#   'global'],
#  ['oil',
#   'US$',
#   'Iran',
#   'barrel',
#   'Azadegan',
#   'price',
#   'Brent',
#   'prices',
#   'U.S.',
#   ' ',
#   'bpd',
#   'Iranian',
#   'ndash',
#   'crude',
#   'China',
#   'fields',
#   'million',
#   'trading',
#   'North',
#   'South',
#   'cent'],
#  [' ',
#   'percent',
#   'Monday',
#   'demand',
#   'summer',
#   'week',
#   'Sunday',
#   'early',
#   'OPEC',
#   'Crude',
#   'said',
#   'highest',
#   'year',
#   'U.S.',
#   'gasoline',
#   'average',
#   'GasBuddy',
#   'travel',
#   'accommodate',
#   'production',
#   'WTI'],
#  [' ',
#   'oil',
#   'demand',
#   'stability',
#   'prices',
#   'months',
#   'talks',
#   'said',
#   'Reuters',
#   'million',
#   'crude',
#   'market',
#   'bullish',
#   'bearish',
#   'news',
#   'deal',
#   'quoted',
#   'Iran',
#   'expectations',
#   'Goldman',
#   'global'],
#  [' ',
#   'demand',
#   'said',
#   'oil',
#   'U.S.',
#   'rise',
#   'year',
#   'note',
#   'bank',
#   'analysts',
#   'vaccinations',
#   'Iran',
#   'Goldman',
#   'Sachs',
#   'crude',
#   '$',
#   '80',
#   'barrel',
#   'end',
#   'Iranian',
#   'talks'],
#  [' ',
#   '$',
#   'prices',
#   'talks',
#   'Thursday',
#   'Iran',
#   'Iranian',
#   'early',
#   'said',
#   'Crude',
#   'nuclear',
#   'oil',
#   'rdquo',
#   'reported',
#   'market',
#   'Oil',
#   'powers',
#   'accepted',
#   'sanctions',
#   'percent',
#   'Brent'],
#  [' ',
#   'oil',
#   'demand',
#   'crude',
#   'supply',
#   'United',
#   'million',
#   'barrels',
#   'week',
#   'prices',
#   'months',
#   'States',
#   'year',
#   'contracts',
#   'government',
#   'Brent',
#   'hit',
#   '$',
#   'biggest',
#   'optimism',
#   'round'],
#  [' ',
#   'Wednesday',
#   'early',
#   'oil',
#   '$',
#   'prices',
#   'inflation',
#   'U.S.',
#   'talks',
#   'second',
#   'day',
#   'markets',
#   'crude',
#   'Crude',
#   'percent',
#   'Brent',
#   '70',
#   'Tuesday',
#   'breakthrough',
#   'deal',
#   'later'],
#  ['Iran',
#   '   ',
#   'oil',
#   'prices',
#   'plunged',
#   'nuclear',
#   'deal',
#   'Ulyanov',
#   'earlier',
#   'talks',
#   'likely',
#   ' ',
#   '$',
#   'Update',
#   '1245ETnbspWell',
#   'long',
#   'optimism',
#   'surged',
#   'higher',
#   'Russian',
#   'Envoy'],
#  ['barrel',
#   'Saudi',
#   ' ',
#   'cents',
#   'month',
#   '2021',
#   'Light',
#   'June',
#   'Aramco',
#   'ndash',
#   'USD',
#   'Dubai',
#   'Basrah',
#   'oil',
#   'Middle',
#   'OSPs',
#   'differentials',
#   'grades',
#   'April',
#   'Arab',
#   'SOMO'],
#  [' ',
#   'Thursday',
#   'prices',
#   'oil',
#   'Wednesday',
#   'percent',
#   'early',
#   'Colonial',
#   'U.S.',
#   'demand',
#   'year',
#   'said',
#   'Oil',
#   'April',
#   'restart',
#   'Pipeline',
#   'eased',
#   'concerns',
#   'shortages',
#   'East',
#   'Crude'],
#  [' ',
#   'oil',
#   'hedging',
#   'prices',
#   'fuel',
#   'airlines',
#   'price',
#   'hedge',
#   'carriers',
#   'low',
#   'year',
#   'Airlines',
#   'market',
#   'use',
#   'lock',
#   'future',
#   'like',
#   'hedges',
#   'years',
#   'costs',
#   'time'],
#  [' ',
#   'oil',
#   'market',
#   'prices',
#   'demand',
#   'Europe',
#   'Oil',
#   'Friday',
#   'reopening',
#   'United',
#   'States',
#   'draw',
#   'inventories',
#   'week',
#   '$',
#   'European',
#   'early',
#   'weekly',
#   'gain',
#   'U.S.',
#   'crude'],
#  ['oil',
#   ' ',
#   'week',
#   'demand',
#   'inflation',
#   'percent',
#   'prices',
#   'economic',
#   'bullish',
#   'commodities',
#   'managers',
#   'hedge',
#   'economies',
#   'time',
#   'including',
#   'run',
#   'year',
#   'expectations',
#   'rebound',
#   'months',
#   'highest'],
#  [' ',
#   'price',
#   'oil',
#   'Saudi',
#   'Dubai',
#   'Arabia',
#   'Asia',
#   'according',
#   'expected',
#   'crude',
#   'cut',
#   'demand',
#   'India',
#   'benchmark',
#   'Reuters',
#   'Asian',
#   'average',
#   '$',
#   'barrel',
#   'prices',
#   'June'],
#  [' ',
#   'oil',
#   '$',
#   'Wednesday',
#   'reopening',
#   'Europe',
#   'travel',
#   'EU',
#   'prices',
#   'mid',
#   'domestic',
#   'Brent',
#   'barrel',
#   'early',
#   'market',
#   'United',
#   'States',
#   'economies',
#   'demand',
#   'U.S.',
#   'Crude'],
#  ['oil',
#   ' ',
#   'demand',
#   'year',
#   'prices',
#   'price',
#   '$',
#   'barrel',
#   'recovery',
#   'bpd',
#   'market',
#   'million',
#   'OPEC',
#   'restrictions',
#   'increase',
#   'sees',
#   'India',
#   'Indiarsquos',
#   'Europe',
#   'crude',
#   'result'],
#  ['bpd',
#   'oil',
#   'million',
#   ' ',
#   'demand',
#   'prices',
#   'levels',
#   'crude',
#   'markets',
#   'currently',
#   'expected',
#   'rise',
#   'affect',
#   'India',
#   'pre',
#   '2019',
#   'continued',
#   'year',
#   'aviation',
#   'OPEC',
#   'U.S.'],
#  [' ',
#   'EU',
#   'Monday',
#   'travel',
#   'prices',
#   'European',
#   'oil',
#   'Commission',
#   'percent',
#   'non',
#   'Oil',
#   'earlier',
#   'losses',
#   'vaccinated',
#   'hope',
#   'set',
#   'Crude',
#   '$',
#   'situation',
#   'new',
#   'essential'],
#  [' ',
#   'oil',
#   'prices',
#   'Friday',
#   'India',
#   'crisis',
#   'COVID',
#   'U.S.',
#   '$',
#   'percent',
#   'demand',
#   'profit',
#   'taking',
#   'dollar',
#   'rally',
#   'week',
#   'Thursday',
#   'Crude',
#   'day',
#   'offset',
#   'market'],
#  [' ',
#   'demand',
#   'oil',
#   '$',
#   'week',
#   'fuel',
#   'barrel',
#   'inventories',
#   'year',
#   'million',
#   'bpd',
#   'according',
#   'OPEC',
#   'Brent',
#   'rise',
#   'forecast',
#   'diesel',
#   'Goldman',
#   'need',
#   'prices',
#   'major'],
#  ['Gulf',
#   ' ',
#   'oil',
#   'economies',
#   '$',
#   'prices',
#   'year',
#   'said',
#   'debt',
#   'percent',
#   'producers',
#   'budget',
#   'diversification',
#   'governments',
#   'need',
#   'higher',
#   'remain',
#   'forecast',
#   'Brent',
#   'term',
#   'needs'],
#  [' ',
#   'Nigerian',
#   '2021',
#   'April',
#   'barrel',
#   'India',
#   'Spain',
#   'crudes',
#   'ndash',
#   'USD',
#   'market',
#   'Dated',
#   'Brent',
#   'refiners',
#   'Nigeria',
#   'grades',
#   'levels',
#   'month',
#   'prices',
#   'year',
#   'exports'],
#  ['oil',
#   '$',
#   ' ',
#   'hedged',
#   'production',
#   'output',
#   'prices',
#   'barrel',
#   'companies',
#   'hedge',
#   '2021',
#   'losses',
#   'price',
#   'hedging',
#   'said',
#   'Oil',
#   'million',
#   'Reuters',
#   'year',
#   'producers',
#   'higher'],
#  [' ',
#   'OPEC',
#   'meeting',
#   'oil',
#   'Tuesday',
#   'JMMC',
#   'market',
#   'production',
#   'India',
#   '1',
#   'bpd',
#   'group',
#   'hold',
#   'ministerial',
#   'Wednesday',
#   'planned',
#   'Joint',
#   'Committee',
#   'agreed',
#   'despite',
#   'COVID'],
#  ['oil',
#   'week',
#   ' ',
#   'OPEC',
#   'legislation',
#   'crude',
#   'long',
#   'NOPEC',
#   'shift',
#   'bias',
#   'prices',
#   'things',
#   'end',
#   'way',
#   'weeks',
#   'ago',
#   'change',
#   'said',
#   'trading',
#   'CL',
#   'lower'],
#  [' ',
#   'oil',
#   'market',
#   'U.S.',
#   '2020',
#   'pandemic',
#   'million',
#   'year',
#   'global',
#   'April',
#   'crude',
#   'Russia',
#   'OPEC',
#   'production',
#   'demand',
#   'economy',
#   '$',
#   'time',
#   'Saudi',
#   'economies',
#   'months'],
#  ['OPEC',
#   ' ',
#   'meeting',
#   'Friday',
#   'said',
#   'early',
#   'Thursday',
#   'January',
#   'demand',
#   '$',
#   'oil',
#   'production',
#   'variant',
#   'group',
#   'market',
#   'prices',
#   '400,000',
#   'Crude',
#   'day',
#   'expected',
#   'impact'],
#  ['demand',
#   'bpd',
#   'million',
#   ' ',
#   'data',
#   'U.S.',
#   'prices',
#   'growth',
#   'continues',
#   'production',
#   'seen',
#   'oil',
#   'markets',
#   '2021',
#   'w',
#   'forecast',
#   'rising',
#   'capacity',
#   'improving',
#   'week',
#   '$'],
#  [' ',
#   'oil',
#   'percent',
#   'U.S.',
#   'Monday',
#   'week',
#   'demand',
#   'prices',
#   'Crude',
#   '$',
#   'limited',
#   'cases',
#   'crude',
#   '6',
#   'weekly',
#   'dollar',
#   'Brent',
#   'India',
#   'major',
#   'country',
#   'new'],
#  ['oil',
#   ' ',
#   'energy',
#   'scenario',
#   'prices',
#   'world',
#   'Wood',
#   'Mackenzie',
#   'said',
#   'global',
#   'low',
#   'change',
#   'demand',
#   'case',
#   'Big',
#   'companies',
#   'Brent',
#   'fall',
#   '$',
#   '10',
#   'barrel'],
#  ['2021',
#   'barrel',
#   ' ',
#   'Saudi',
#   'Light',
#   'Aramco',
#   'cents',
#   'month',
#   'Dubai',
#   'Iranian',
#   'Arab',
#   'OSPs',
#   'Asia',
#   'ADNOC',
#   'Oman',
#   'pricing',
#   'oil',
#   'Graph',
#   'vs',
#   'Source',
#   '50'],
#  ['oil',
#   ' ',
#   'Brent',
#   'Middle',
#   'production',
#   'linked',
#   'Eastern',
#   'grades',
#   'Bloomberg',
#   'crude',
#   'start',
#   'comes',
#   'region',
#   'cheaper',
#   'analyst',
#   'rdquo',
#   'Lim',
#   'need',
#   'buyers',
#   'OPEC',
#   'higher'],
#  ['oil',
#   ' ',
#   '$',
#   'prices',
#   'Morgan',
#   'Stanley',
#   'likely',
#   'U.S.',
#   'said',
#   'Brent',
#   'drilling',
#   'activity',
#   'return',
#   'Oil',
#   'summer',
#   'forecast',
#   '70',
#   'Iranian',
#   'factors',
#   'recovery',
#   'barrels'],
#  [' ',
#   'oil',
#   'production',
#   'U.S.',
#   'OPEC',
#   'million',
#   'prices',
#   'producers',
#   'spending',
#   'bpd',
#   'said',
#   'year',
#   'market',
#   'quarter',
#   'cash',
#   'return',
#   '2020',
#   'average',
#   'American',
#   '$',
#   '60'],
#  [' ',
#   'Tuesday',
#   'percent',
#   'oil',
#   'China',
#   'year',
#   'prices',
#   'economic',
#   '$',
#   'Services',
#   'United',
#   'States',
#   'global',
#   'Crude',
#   'helped',
#   'U.S.',
#   'dollar',
#   'worldrsquos',
#   'consumer',
#   'importer',
#   'Monday'],
#  [' ',
#   '$',
#   'oil',
#   'prices',
#   'Monday',
#   'trading',
#   'day',
#   'demand',
#   'market',
#   'WTI',
#   'barrel',
#   'price',
#   'continue',
#   'coronavirus',
#   'ramp',
#   'cases',
#   'Iran',
#   'week',
#   'crude',
#   'production',
#   'Oil'],
#  [' ',
#   'oil',
#   'demand',
#   'Monday',
#   'market',
#   'prices',
#   'OPEC',
#   'decision',
#   '$',
#   'percent',
#   'Oil',
#   'cuts',
#   '1',
#   'million',
#   'months',
#   'amid',
#   'recovery',
#   'Crude',
#   'start',
#   'long',
#   'weekend'],
#  ['oil',
#   ' ',
#   'OPEC',
#   'bpd',
#   'prices',
#   'percent',
#   'production',
#   'nbsp',
#   'market',
#   'day',
#   'Thursday',
#   'decision',
#   'demand',
#   'meeting',
#   'trade',
#   'settled',
#   'gains',
#   '3',
#   'Crude',
#   '$',
#   'finished'],
#  [' ',
#   'Murban',
#   'crude',
#   'oil',
#   'Abu',
#   'Dhabi',
#   'East',
#   'futures',
#   'markets',
#   'Middle',
#   'global',
#   'Brent',
#   'benchmark',
#   'good',
#   'benchmarks',
#   'barrels',
#   'production',
#   'companies',
#   'investors',
#   'Saudi',
#   'ADNOC'],
#  [' ',
#   'prices',
#   'Tuesday',
#   'oil',
#   'Suez',
#   'Canal',
#   'week',
#   'Crude',
#   'demand',
#   'said',
#   'rdquo',
#   'market',
#   'Oil',
#   'long',
#   'blockage',
#   'U.S.',
#   'dollar',
#   'percent',
#   '$',
#   'Walensky',
#   'Monday'],
#  [' ',
#   'oil',
#   '$',
#   'production',
#   'trading',
#   'Canal',
#   'barrel',
#   'crude',
#   'prices',
#   'Monday',
#   'market',
#   'vessel',
#   'days',
#   'traffic',
#   'soon',
#   'moving',
#   'time',
#   'vessels',
#   'day',
#   'decision',
#   'current'],
#  [' ',
#   'oil',
#   'prices',
#   '$',
#   'lockdowns',
#   'day',
#   'Poland',
#   'lockdown',
#   'market',
#   'tanker',
#   'Suez',
#   'Canal',
#   'traffic',
#   'wave',
#   'coronavirus',
#   'crude',
#   'trading',
#   'barrel',
#   'Europe',
#   'strict',
#   'measures'],
#  [' ',
#   'oil',
#   'prices',
#   'demand',
#   '$',
#   'contract',
#   'percent',
#   'concerns',
#   'long',
#   'Crude',
#   'month',
#   'Tuesday',
#   'positions',
#   'trading',
#   'day',
#   'Brent',
#   'nearest',
#   'price',
#   'market',
#   'days',
#   'emerged'],
#  ['oil',
#   ' ',
#   'INEOS',
#   'production',
#   'Hess',
#   'Denmark',
#   'carbon',
#   'bpd',
#   'expected',
#   'Denmarkrsquos',
#   'field',
#   '2020',
#   'Danish',
#   'purchase',
#   'stake',
#   'EU',
#   'million',
#   'aims',
#   'boost',
#   'planned',
#   'currently'],
#  [' ',
#   'U.S.',
#   'crude',
#   'vaccination',
#   'Europe',
#   'oil',
#   'prices',
#   'percent',
#   'dollar',
#   'inventories',
#   'AstraZeneca',
#   'Oil',
#   'rising',
#   'setbacks',
#   'weighed',
#   'market',
#   'Crude',
#   '$',
#   '   ',
#   'commercial',
#   'stronger'],
#  [' ',
#   '$',
#   'prices',
#   'Europe',
#   'demand',
#   'Tuesday',
#   'wave',
#   'vaccine',
#   'stronger',
#   'rebound',
#   'concerns',
#   'vaccinations',
#   'day',
#   'infections',
#   'EU',
#   'dollar',
#   'market',
#   'Crude',
#   'percent',
#   'Brent',
#   'major'],
#  [' ',
#   '$',
#   'oil',
#   'prices',
#   'WTI',
#   'profit',
#   'Biden',
#   'tax',
#   'according',
#   'people',
#   'familiar',
#   '   ',
#   'Despite',
#   'optimism',
#   'Chinese',
#   'data',
#   'overnight',
#   'forecasts',
#   'lower',
#   'OPEC',
#   'output'],
#  ['oil',
#   ' ',
#   'prices',
#   'week',
#   'OPEC',
#   'taking',
#   'production',
#   'Saudi',
#   '$',
#   'price',
#   'weeks',
#   'higher',
#   'profit',
#   'boost',
#   'demand',
#   'million',
#   'cuts',
#   'infrastructure',
#   'attack',
#   'shale',
#   'new'],
#  ['OPEC',
#   'bpd',
#   'cuts',
#   'prices',
#   ' ',
#   'production',
#   'million',
#   'Saudi',
#   'oil',
#   '$',
#   'demand',
#   'current',
#   'global',
#   'markets',
#   'week',
#   'year',
#   'April',
#   'supported',
#   'shale',
#   'continue',
#   'level'],
#  ['Saudi',
#   ' ',
#   'attack',
#   'oil',
#   'Arabia',
#   'said',
#   'military',
#   'Houthis',
#   'hit',
#   'Oil',
#   'prices',
#   'hours',
#   'early',
#   'price',
#   'drone',
#   'infrastructure',
#   'later',
#   'confirmed',
#   'Brent',
#   'close',
#   'percent'],
#  [' ',
#   'OPEC',
#   'market',
#   'oil',
#   'Friday',
#   'production',
#   'April',
#   '$',
#   'prices',
#   'group',
#   'percent',
#   'barrel',
#   'decided',
#   'shale',
#   'Oil',
#   '5',
#   'decision',
#   'levels',
#   'unchanged',
#   'nbsp',
#   'Crude'],
#  [' ',
#   'gasoline',
#   'average',
#   '$',
#   'demand',
#   'U.S.',
#   'national',
#   '3',
#   'data',
#   'GasBuddy',
#   'gallon',
#   'OPEC',
#   'million',
#   'highest',
#   'pandemic',
#   'Sunday',
#   'De',
#   'rdquo',
#   'refinery',
#   'price',
#   'time'],
#  [' ',
#   'OPEC',
#   'production',
#   'Saudi',
#   '$',
#   'April',
#   'Arabia',
#   'Crude',
#   'sources',
#   'increase',
#   'meeting',
#   'Russia',
#   'cut',
#   'Prince',
#   'Abdulaziz',
#   'bin',
#   'Salman',
#   'oil',
#   'WTI',
#   'jumped',
#   'Thursday'],
#  [' ',
#   'OPEC',
#   'April',
#   'prices',
#   'oil',
#   '$',
#   'cuts',
#   'Saudi',
#   'Wednesday',
#   'production',
#   'expected',
#   'trading',
#   '1',
#   'Arabia',
#   'jumped',
#   'reports',
#   'group',
#   'increase',
#   'widely',
#   'EIA',
#   'report'],
#  ['oil',
#   ' ',
#   'Saudi',
#   'prices',
#   'U.S.',
#   'OPEC',
#   'meeting',
#   'production',
#   'murder',
#   'involved',
#   'Arabia',
#   'Biden',
#   'report',
#   'government',
#   'Jamal',
#   'Khashoggi',
#   'sanctions',
#   'said',
#   'Prince',
#   'Mohammed',
#   'Washington'],
#  ['oil',
#   ' ',
#   'market',
#   'prices',
#   'OPEC',
#   'production',
#   'group',
#   'week',
#   '$',
#   'U.S.',
#   'national',
#   'average',
#   'rdquo',
#   'month',
#   'April',
#   'share',
#   'Russia',
#   'demand',
#   'large',
#   'rally',
#   'supply'],
#  [' ',
#   '$',
#   'oil',
#   'average',
#   'barrel',
#   'Brent',
#   'year',
#   'stimulus',
#   'prices',
#   'forecast',
#   'said',
#   'expected',
#   'Reuters',
#   'survey',
#   'analysts',
#   'consensus',
#   'activity',
#   'pandemic',
#   'rdquo',
#   'government',
#   'OPEC'],
#  ['oil',
#   ' ',
#   '$',
#   'production',
#   'barrels',
#   'barrel',
#   'prices',
#   'price',
#   'Brent',
#   'year',
#   '100',
#   'U.S.',
#   'demand',
#   'stimulus',
#   'million',
#   'bpd',
#   'course',
#   'recovery',
#   'increase',
#   'OPEC',
#   'Saudi'],
#  ['$',
#   ' ',
#   'barrel',
#   'average',
#   'year',
#   'Crude',
#   'Barclays',
#   'price',
#   'quarter',
#   'bank',
#   'oil',
#   'inventories',
#   'prices',
#   'raised',
#   'Brent',
#   '2021',
#   'OPEC',
#   'market',
#   '70',
#   'Thursday',
#   'forecasts'],
#  [' ',
#   'production',
#   'prices',
#   'bpd',
#   'said',
#   'oil',
#   '$',
#   'bank',
#   'OPEC',
#   'increase',
#   'years',
#   'analysts',
#   'return',
#   'price',
#   'Brent',
#   'according',
#   'added',
#   'shale',
#   'agreement',
#   'higher',
#   'likely'],
#  ['carbon',
#   ' ',
#   'dioxide',
#   'fuels',
#   'CO2',
#   '$',
#   'utilization',
#   'market',
#   'Lux',
#   'growth',
#   'capture',
#   'according',
#   'area',
#   'materials',
#   'industry',
#   'expensive',
#   'graphene',
#   'building',
#   'concrete',
#   'direct',
# ...
#   'extension',
#   'Minister',
#   'Saudi',
#   'oil',
#   'agreed',
#   'earlier',
#   'Russiarsquos',
#   'Energy',
#   'Novak',
#   'said',
#   'meeting',
#   'prices',
#   'especially',
#   'Oil',
#   'Zanganeh'],
#  ['percent',
#   'capacity',
#   ' ',
#   'refining',
#   'prices',
#   'US$',
#   'gasoline',
#   'trading',
#   'offline',
#   'oil',
#   'spike',
#   'North',
#   'Korea',
#   'refineries',
#   'Gulf',
#   'Coast',
#   'Harvey',
#   'yesterday',
#   '920',
#   'CST',
#   'today'],
#  ['nuclear',
#   ' ',
#   'Korea',
#   'North',
#   'war',
#   'crude',
#   'open',
#   'oil',
#   'said',
#   'China',
#   'Japan',
#   'military',
#   'conflict',
#   'refining',
#   'capacity',
#   'South',
#   'far',
#   'Pyongyang',
#   'missile',
#   'pressure',
#   'Northern'],
#  [' ',
#   'oil',
#   'refining',
#   'barrels',
#   'crude',
#   'U.S.',
#   'Hurricane',
#   'million',
#   'offline',
#   'outages',
#   'WTI',
#   'coast',
#   'online',
#   'mb',
#   'd',
#   'capacity',
#   'refineries',
#   'come',
#   'larger',
#   'effects',
#   'prices'],
#  ['oil',
#   ' ',
#   'price',
#   'prices',
#   'ago',
#   'Della',
#   'Vigna',
#   'Goldman',
#   'costs',
#   'Big',
#   'Oil',
#   'Sachs',
#   '2014',
#   '100',
#   'companies',
#   'production',
#   'cash',
#   'said',
#   'half',
#   'years',
#   'better'],
#  [' ',
#   'bpd',
#   'oil',
#   'OPEC',
#   'Iraq',
#   'Al',
#   'exports',
#   'compliance',
#   'OPECrsquos',
#   'million',
#   'deal',
#   'Iraqrsquos',
#   'Luaibi',
#   'cuts',
#   'production',
#   'Minister',
#   'said',
#   'worst',
#   'compliant',
#   'producers',
#   'set'],
#  [' ',
#   'oil',
#   'pricing',
#   'change',
#   'Basra',
#   'price',
#   'prices',
#   'Iraqrsquos',
#   'crude',
#   'Iraq',
#   'Heavy',
#   'Middle',
#   'SOMO',
#   'plan',
#   'DME',
#   'Oman',
#   'futures',
#   'refinement',
#   'time',
#   'barrel',
#   'Eastern'],
#  [' ',
#   'refiners',
#   'gasoline',
#   'European',
#   'Coast',
#   'Gulf',
#   'Mexico',
#   'Bloomberg',
#   'refined',
#   'supply',
#   'Texas',
#   'products',
#   'oil',
#   'Europe',
#   'U.S.',
#   'Energy',
#   'barrels',
#   'disruptions',
#   'capacity',
#   'prices',
#   'spreads'],
#  [' ',
#   'Oil',
#   'prices',
#   'Texas',
#   'Gulf',
#   'Harvey',
#   'said',
#   'spread',
#   '$',
#   'storm',
#   'weeks',
#   'demand',
#   'continues',
#   'Houston',
#   'oil',
#   'crude',
#   'Energy',
#   'Brent',
#   'U.S.',
#   'coast',
#   '5'],
#  [' ',
#   'oil',
#   'U.S.',
#   'Texas',
#   'Gulf',
#   'refined',
#   'production',
#   'shut',
#   'capacity',
#   'bpd',
#   'Platts',
#   'mb',
#   'shale',
#   'rain',
#   'SampP',
#   'Global',
#   'Coast',
#   'd',
#   'Latin',
#   'product',
#   'Hurricane'],
#  ['bpd',
#   ' ',
#   'Texas',
#   'million',
#   'Harvey',
#   'capacity',
#   'shut',
#   'percent',
#   'oil',
#   'U.S.',
#   'Gasoline',
#   'hit',
#   'today',
#   'shutdown',
#   'refineries',
#   'US$',
#   'refining',
#   'Corpus',
#   'Christi',
#   'area',
#   'storm'],
#  [' ',
#   'oil',
#   'WTI',
#   'crude',
#   'demand',
#   'barrels',
#   'Brent',
#   'contango',
#   'million',
#   '$',
#   'inventory',
#   'prices',
#   'spread',
#   'contract',
#   '2016',
#   'trading',
#   'levels',
#   'Oil',
#   'production',
#   'lower',
#   'OPEC'],
#  [' ',
#   'mdash',
#   'state',
#   'Brazilrsquos',
#   'major',
#   'opportunity',
#   'gold',
#   'oil',
#   'government',
#   'open',
#   'energy',
#   'list',
#   'infrastructure',
#   'assets',
#   'strategic',
#   'including',
#   'country.nbsp',
#   'sale',
#   'Para',
#   'economy',
#   'Brazil'],
#  ['OPEC',
#   ' ',
#   'oil',
#   'market',
#   'cuts',
#   'year',
#   '2018',
#   'extension',
#   'March',
#   'non',
#   'June',
#   'energy',
#   'action',
#   'extending',
#   'joint',
#   'committee',
#   'said',
#   'meetings',
#   'Vienna',
#   'growth',
#   'panel'],
#  [' ',
#   'WTI',
#   'U.S.',
#   'Brent',
#   'oil',
#   'spread',
#   'ndash',
#   'supply',
#   'market',
#   'conditions',
#   'benchmarks',
#   'crude',
#   'recently',
#   'demand',
#   'years',
#   'closely',
#   '$',
#   'barrel',
#   'export',
#   'ban',
#   'gap'],
#  [' ',
#   'oil',
#   'revenues',
#   'Saudi',
#   'Riyadh',
#   'MBS',
#   'KSA',
#   '$',
#   'billion',
#   'months',
#   'Bin',
#   'Iranian',
#   'new',
#   'non',
#   '2017',
#   'Oil',
#   'production',
#   '2018',
#   'IPO',
#   'Arabian',
#   'Iran'],
#  ['shale',
#   ' ',
#   'wells',
#   'oil',
#   'U.S.',
#   '$',
#   'producers',
#   'production',
#   'prices',
#   'drilling',
#   'industry',
#   'barrel',
#   'WSJ',
#   'new',
#   'investors',
#   'Permian',
#   'reported',
#   'conventional',
#   'companies',
#   'old',
#   'trouble'],
#  [' ',
#   'crude',
#   'change',
#   'pricing',
#   'letter',
#   'Asia',
#   'oil',
#   'Iraq',
#   'customers',
#   'Basra',
#   'market',
#   'Reuters',
#   'exports',
#   'Iraqi',
#   'benchmark',
#   'grade',
#   'told',
#   'prices',
#   'Asian',
#   'Iraqrsquos',
#   'company'],
#  [' ',
#   'OPEC',
#   'Oil',
#   'market',
#   'meeting',
#   'compliance',
#   'weeks',
#   'oil',
#   'draws',
#   'prices',
#   'cuts',
#   'producers',
#   'production',
#   'percent',
#   'U.S.',
#   'cartel',
#   'output',
#   'US$',
#   'ago',
#   'members',
#   'non'],
#  ['oil',
#   ' ',
#   'year',
#   'prices',
#   'price',
#   'US$',
#   'Oil',
#   'new',
#   'sector',
#   'stocks',
#   'dividend',
#   'Europe',
#   'percent',
#   'value',
#   'according',
#   'Nelson',
#   '60',
#   'end',
#   'said',
#   'Wittmann',
#   '$'],
#  [' ',
#   'shale',
#   'prices',
#   'oil',
#   'industry',
#   'price',
#   '$',
#   'U.S.',
#   'production',
#   'new',
#   'year',
#   'drillers',
#   'breakeven',
#   'companies',
#   'barrel',
#   'equity',
#   'investors',
#   'EampPs',
#   'ndash',
#   'services',
#   'cash'],
#  ['oil',
#   ' ',
#   'million',
#   'exports',
#   'crude',
#   'Saudi',
#   'bpd',
#   'week',
#   'inventories',
#   'barrels',
#   'level',
#   'August',
#   'month',
#   'Oil',
#   'U.S.',
#   'reported',
#   'EIA',
#   'draw',
#   'June',
#   'dropped',
#   'lowest'],
#  [' ',
#   'KRG',
#   'energy',
#   'Turkish',
#   'oil',
#   'Turkey',
#   'TEC',
#   'blocks',
#   'percent',
#   'Energy',
#   'Taq',
#   'GE',
#   'Kurdistan',
#   'Baghdad',
#   'ExxonMobil',
#   'deal',
#   'signed',
#   'political',
#   'ndash',
#   'pipeline',
#   'Kurdish'],
#  [' ',
#   'OPEC',
#   'cuts',
#   'JP',
#   'production',
#   'Morgan',
#   'Saudi',
#   'oil',
#   'compliance',
#   'output',
#   'year',
#   'producers',
#   'al',
#   'Iraqi',
#   'rdquo',
#   'said',
#   'members',
#   'Iraq',
#   'non',
#   'Arabia',
#   'end'],
#  [' ',
#   'prices',
#   'oil',
#   'year',
#   'U.S.',
#   'industry',
#   'Andurand',
#   'demand',
#   'shale',
#   'current',
#   'new',
#   'price',
#   'Metal',
#   'direction',
#   'rise',
#   'investment',
#   'low',
#   'mdash',
#   'level',
#   'cuts',
#   'rising'],
#  [' ',
#   'percent',
#   'Saudi',
#   'U.S.',
#   'oil',
#   'year',
#   'lower',
#   'draw',
#   'barrels',
#   'crude',
#   'demand',
#   'refinery',
#   'flows',
#   'Arabia',
#   'deliveries',
#   'Port',
#   'Motiva',
#   'bpd',
#   'months',
#   'refineries',
#   'IEA'],
#  [' ',
#   'crude',
#   'mdash',
#   'oil',
#   'Gulf',
#   'Venezuela',
#   'U.S.',
#   'sources',
#   'week',
#   'making',
#   'markets',
#   'refiners',
#   'Venezuelarsquos',
#   'major',
#   'changes',
#   'flows',
#   'big',
#   'nation',
#   'years',
#   'shipments',
#   'saying'],
#  [' ',
#   'oil',
#   'crude',
#   'million',
#   'week',
#   'prices',
#   'Monday',
#   'U.S.',
#   'lowest',
#   'barrels',
#   'Tuesday',
#   'demand',
#   'July',
#   'bpd',
#   'daily',
#   'inventories',
#   'Oil',
#   'concerns',
#   'supply',
#   'growth',
#   'WTI'],
#  [' ',
#   'oil',
#   'production',
#   'output',
#   'U.S.',
#   'year',
#   'Libya',
#   'OPEC',
#   'rdquo',
#   'shale',
#   'Nigeria',
#   'Venezuela',
#   'market',
#   'prices',
#   'week',
#   'return',
#   'gains',
#   'bpd',
#   'ndash',
#   'Permian',
#   'analysts'],
#  ['bpd',
#   'output',
#   ' ',
#   'Permian',
#   'production',
#   'growth',
#   'year',
#   'shale',
#   'increase',
#   'oil',
#   '300,000',
#   'analysts',
#   'reports',
#   'gas',
#   'months',
#   'rigs',
#   'US$',
#   'firms',
#   'forecasts',
#   'end',
#   'Wood'],
#  [' ',
#   'percent',
#   'oil',
#   'July',
#   'output',
#   'year',
#   'million',
#   'day',
#   'Bloomberg',
#   'month',
#   'barrels',
#   'o',
#   'crude',
#   'tons',
#   'demand',
#   'Chinese',
#   'China',
#   'refining',
#   'data',
#   'months',
#   'production'],
#  [' ',
#   'IEA',
#   'bpd',
#   'mb',
#   'oil',
#   'd',
#   'OPEC',
#   'demand',
#   'July',
#   'rdquo',
#   'year',
#   'market',
#   'time',
#   'report',
#   'things',
#   'inventories',
#   'compliance',
#   'new',
#   'prices',
#   '2018',
#   'rate'],
#  ['oil',
#   ' ',
#   'demand',
#   'market',
#   'prices',
#   'bpd',
#   'OPEC',
#   'year',
#   'U.S.',
#   'Oil',
#   'IEA',
#   'shale',
#   'said',
#   'global',
#   'Permian',
#   'futures',
#   '$',
#   'Korea',
#   'crude',
#   'end',
#   'week'],
#  [' ',
#   'production',
#   'mdash',
#   'oil',
#   'OPEC',
#   'output',
#   'million',
#   'barrels',
#   'day',
#   'cuts',
#   'July',
#   'prices',
#   'week',
#   'numbers',
#   'producing',
#   'nations',
#   'crude',
#   'key',
#   '2017',
#   'b',
#   'd'],
#  [' ',
#   'production',
#   'day',
#   'barrels',
#   'OPEC',
#   'June',
#   'decline',
#   'revised',
#   'upward',
#   'bpd',
#   'oil',
#   'data',
#   'Oil',
#   'peaked',
#   '$',
#   'chart',
#   'Equatorial',
#   'Guinea',
#   '10',
#   'percent',
#   'year'],
#  ['bpd',
#   'million',
#   'OPEC',
#   ' ',
#   'production',
#   'barrels',
#   'year',
#   'growth',
#   'oil',
#   'increase',
#   'output',
#   'demand',
#   'crude',
#   'OECD',
#   'second',
#   'non',
#   'daily',
#   'Libya',
#   'Saudi',
#   'main',
#   'drivers'],
#  ['imports',
#   'oil',
#   'crude',
#   ' ',
#   'percent',
#   'Chinarsquos',
#   'million',
#   'year',
#   'Chinese',
#   'Reuters',
#   'bpd',
#   'July',
#   'annual',
#   'basis',
#   'month',
#   'tons',
#   'increased',
#   'total',
#   'demand',
#   'rise',
#   'lowest'],
#  [' ',
#   'FERC',
#   'billion',
#   'US$',
#   'quorum',
#   'gas',
#   'pipeline',
#   'projects',
#   'construction',
#   'year',
#   'natural',
#   'project',
#   'said',
#   'service',
#   'quarter',
#   'Commission',
#   'worth',
#   'date',
#   'Virginia',
#   'final',
#   'Energy'],
#  [' ',
#   'oil',
#   'reports',
#   'production',
#   'armed',
#   'mdash',
#   'Libyarsquos',
#   'saying',
#   'control',
#   'room',
#   'group',
#   'problems',
#   'countryrsquos',
#   'field',
#   'local',
#   'Reuters',
#   'Sharara',
#   'sources',
#   'key',
#   'facility',
#   'action'],
#  [' ',
#   'oil',
#   'price',
#   'prices',
#   'Figure',
#   'EIA',
#   'U.S.',
#   '$',
#   'supply',
#   'C.I.',
#   'consumption',
#   'inventory',
#   'comparative',
#   '5',
#   'levels',
#   'stock',
#   'year',
#   'barrel',
#   '2016',
#   'd',
#   'data'],
#  [' ',
#   'oil',
#   'Venezuela',
#   '$',
#   'default',
#   'debt',
#   'Venezuelan',
#   'payments',
#   'exports',
#   'Croft',
#   'economic',
#   'said',
#   'year',
#   'billion',
#   'company',
#   'U.S.',
#   'Venezuelarsquos',
#   'according',
#   'Capital',
#   'rdquo',
#   'push'],
#  ['oil',
#   ' ',
#   'ndash',
#   'companies',
#   'growth',
#   'prices',
#   'stocks',
#   'capex',
#   '2017',
#   'going',
#   'Pioneer',
#   'horrible',
#   '2016',
#   'assets',
#   'spending',
#   'quarter',
#   'guys',
#   'reward',
#   'like',
#   'need',
#   'lemmings'],
#  [' ',
#   'prices',
#   'oil',
#   'US$',
#   'price',
#   'quarter',
#   'Barclays',
#   'month',
#   'inventory',
#   'drawdowns',
#   'rdquo',
#   'bank',
#   'July',
#   'WTI',
#   'combination',
#   'unlikely',
#   'said',
#   'note',
#   'macro',
#   'geopolitical',
#   'expect'],
#  [' ',
#   'oil',
#   'OPEC',
#   'market',
#   'prices',
#   'cuts',
#   'producers',
#   'U.S.',
#   'production',
#   'output',
#   'price',
#   'El',
#   'cartel',
#   'deal',
#   'try',
#   'relevance',
#   'shale',
#   'non',
#   'game',
#   'theory',
#   'Erian'],
#  ['crude',
#   ' ',
#   'U.S.',
#   'demand',
#   'exports',
#   'refiners',
#   'barrels',
#   'million',
#   'Nigerian',
#   'oil',
#   'strong',
#   'refineries',
#   'high',
#   'Angolan',
#   'Nigeria',
#   'Angola',
#   'refining',
#   'margins',
#   'capacity',
#   'Angolarsquos',
#   'US$'],
#  ['oil',
#   ' ',
#   'heavy',
#   'spread',
#   'U.S.',
#   'Fitch',
#   'OPEC',
#   'WTI',
#   'WCS',
#   'exports',
#   'crude',
#   'grades',
#   'price',
#   'Canadian',
#   'sands',
#   'year',
#   'supply',
#   'cutting',
#   'refining',
#   'margins',
#   'refiners'],
#  [' ',
#   'oil',
#   'U.S.',
#   'sanctions',
#   'Venezuela',
#   'PDVSA',
#   'Oil',
#   'largest',
#   'result',
#   'price',
#   'ndash',
#   'barrels',
#   'reserves',
#   'Venezuelarsquos',
#   'national',
#   'Madurorsquos',
#   'American',
#   'bank',
#   'produce',
#   'lighter',
#   'daily'],
#  ['$',
#   ' ',
#   'billion',
#   'oil',
#   'upstream',
#   'Shell',
#   'prices',
#   'million',
#   '2016',
#   'Q2',
#   'low',
#   'boe',
#   'major',
#   'profits',
#   'company',
#   'Chevron',
#   'd',
#   'posted',
#   'U.S.',
#   'price',
#   'companyrsquos'],
#  [' ',
#   'oil',
#   'bpd',
#   'million',
#   'exports',
#   'barrels',
#   'production',
#   'Oil',
#   'week',
#   'month',
#   'OPEC',
#   'meeting',
#   'cut',
#   'crude',
#   'said',
#   'prices',
#   'increase',
#   'year',
#   'positions',
#   'Bloomberg',
#   'rise'],
#  ['oil',
#   ' ',
#   '$',
#   'year',
#   'prices',
#   'billion',
#   'majors',
#   'large',
#   'cost',
#   'time',
#   'earlier',
#   'long',
#   'projects',
#   'second',
#   'quarter',
#   'companies',
#   'profit',
#   'higher',
#   'years',
#   'low',
#   'Oil'],
#  [' ',
#   'oil',
#   'prices',
#   '$',
#   'U.S.',
#   'OPEC',
#   'NYSE',
#   'Venezuela',
#   'bull',
#   'spending',
#   'production',
#   'million',
#   'Tuesday',
#   'percent',
#   'time',
#   'market',
#   'sanctions',
#   'Oil',
#   'heavy',
#   'morning',
#   '3'],
#  ['bpd',
#   'million',
#   ' ',
#   'exports',
#   'oil',
#   'Libya',
#   'June',
#   'July',
#   'month',
#   'Nigeria',
#   'production',
#   'crude',
#   'higher',
#   'shipments',
#   'OPEC',
#   'cut',
#   'Kpler',
#   'UAE',
#   'average',
#   'total',
#   'output'],
#  ['oil',
#   'market',
#   ' ',
#   'U.S.',
#   'crude',
#   'prices',
#   'OPEC',
#   'reasons',
#   'barrels',
#   'price',
#   'Venezuela',
#   'lot',
#   'week',
#   'Oil',
#   'month',
#   'rally',
#   'cuts',
#   'day',
#   'shale',
#   'exports',
#   'futures'],
#  ['U.S.',
#   ' ',
#   'sanctions',
#   'Venezuela',
#   'prices',
#   'government',
#   'Venezuelan',
#   'imports',
#   'Venezuelarsquos',
#   'vote',
#   'oil',
#   'country',
#   'crude',
#   'Maduro',
#   'Madurorsquos',
#   'countryrsquos',
#   'economic',
#   'OPEC',
#   'controversial',
#   'United',
#   'States'],
#  [' ',
#   'drillers',
#   'US$',
#   'shale',
#   'year',
#   'debt',
#   'OPEC',
#   'prices',
#   'billion',
#   'oil',
#   'production',
#   'price',
#   'analysts',
#   'need',
#   'barrel',
#   'rally',
#   'cut',
#   'U.S.',
#   'lenders',
#   'unsustainable',
#   'DiChristopher'],
#  ['OPEC',
#   ' ',
#   'compliance',
#   'meeting',
#   'non',
#   'percent',
#   'Saudi',
#   'Abu',
#   'Dhabi',
#   'output',
#   'Russia',
#   'June',
#   'according',
#   'Arabia',
#   'producers',
#   'secondary',
#   'sources',
#   'committee',
#   'week',
#   'far',
#   'Non'],
#  [' ',
#   'US$',
#   'price',
#   'poll',
#   'cut',
#   'cuts',
#   'June',
#   'OPEC',
#   'oil',
#   'expected',
#   'OPECrsquos',
#   'resolve',
#   'according',
#   'analysts',
#   'Reuters',
#   'year',
#   'month',
#   'Analysts',
#   'forecasts',
#   '2017',
#   '2018'],
#  [' ',
#   'U.S.',
#   'OPEC',
#   'year',
#   'oil',
#   'production',
#   'Saudi',
#   'million',
#   'dollar',
#   'high',
#   'percent',
#   'positions',
#   'Petersburg',
#   'prices',
#   'barrels',
#   'remains',
#   'short',
#   'increased',
#   'time',
#   'meeting',
#   'non'],
#  ['oil',
#   'production',
#   'companies',
#   ' ',
#   'term',
#   'capex',
#   'long',
#   'earnings',
#   '2017',
#   'prices',
#   'ndash',
#   'report',
#   'time',
#   'current',
#   'demand',
#   'fact',
#   'stocks',
#   'looking',
#   'investment',
#   'deep',
#   'like'],
#  ['oil',
#   ' ',
#   'year',
#   '$',
#   'prices',
#   'NYSE',
#   'billion',
#   'OPEC',
#   'Oil',
#   'cut',
#   'rdquo',
#   'gas',
#   'profits',
#   'quarter',
#   'Energy',
#   'U.S.',
#   'Venezuelan',
#   'spending',
#   '2017',
#   'week',
#   'company'],
#  ['oil',
#   ' ',
#   'week',
#   'U.S.',
#   'market',
#   'million',
#   'global',
#   'price',
#   'EIA',
#   'crude',
#   'inventories',
#   'barrels',
#   'rebalancing',
#   'production',
#   'Thursday',
#   'prices',
#   'inventory',
#   'draw',
#   'producers',
#   'cut',
#   'earnest'],
#  [' ',
#   'oil',
#   'price',
#   'ndash',
#   'derivatives',
#   'paper',
#   'prices',
#   'barrels',
#   'value',
#   'Oil',
#   'barrel',
#   'futures',
#   'actual',
#   'wet',
#   'contracts',
#   'market',
#   'trading',
#   'thatrsquos',
#   'trade',
#   'traders',
#   '$'],
#  [' ',
#   'OPEC',
#   'Saudi',
#   'production',
#   'said',
#   'al',
#   'Falih',
#   'mb',
#   'Arabia',
#   'oil',
#   'market',
#   'd',
#   'Nigeria',
#   'members',
#   'exports',
#   'rdquo',
#   'WSJ',
#   'output',
#   'months',
#   'Libya',
#   'grow'],
#  [' ',
#   'percent',
#   'compliant',
#   'oil',
#   'production',
#   'UAE',
#   'exports',
#   'UAErsquos',
#   'OPEC',
#   'crude',
#   'reductionnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbspnbsp',
#   'Saudi',
#   'September',
#   'year',
#   'commitment',
#   'million',
#   'responsible',
#   'month',
#   'reduction',
#   'total',
#   'Following'],
#  ['production',
#   ' ',
#   'Saudi',
#   'OPEC',
#   'oil',
#   'prices',
#   'bpd',
#   'million',
#   'U.S.',
#   'inventories',
#   'cuts',
#   'cut',
#   'year',
#   'EIA',
#   'July',
#   'exports',
#   'high',
#   'additional',
#   'Arabia',
#   'countryrsquos',
#   'level'],
#  ['oil',
#   'production',
#   'market',
#   ' ',
#   'OPEC',
#   'Saudi',
#   'expected',
#   'Al',
#   'cut',
#   'Libya',
#   'Nigeria',
#   'Libyarsquos',
#   'OPECrsquos',
#   'compliance',
#   'main',
#   'Russia',
#   'current',
#   'present',
#   'possible',
#   'overall',
#   'growing'],
#  ...]

# %%
corpus_alternative_energies['content'] = corpus_alternative_energies['content'].str.replace('"','')
corpus_alternative_energies['content'] = corpus_alternative_energies['content'].str.replace('&','')
corpus_alternative_energies['content'] = corpus_alternative_energies['content'].str.replace(';','')
col_one_list_2 = corpus_alternative_energies['content'].tolist()

# %%
common_words_list_2 = []
for a in col_one_list_2:
    complete_doc = nlp(a)
    # Remove stop words and punctuation symbols
    words = [token.text for token in complete_doc
         if not token.is_stop and not token.is_punct]
    word_freq = Counter(words)
    # 5 commonly occurring words with their frequencies
    common_words = word_freq.most_common(21)
    # Unique words
    common_words_list_2.append(common_words)

# %%
common_words_list_edited_2 = []
for c in common_words_list_2:
    intermediary_list = []
    for a in c:
        a_edited = a[0]
        intermediary_list.append(a_edited)
    common_words_list_edited_2.append(intermediary_list)
common_words_list_edited_2
# Out:
# [[' ',
#   'energy',
#   'tons',
#   'metals',
#   '$',
#   'costs',
#   'battery',
#   'prices',
#   'renewable',
#   'copper',
#   'big',
#   'solar',
#   'transition',
#   'new',
#   'estimates',
#   'global',
#   'trillion',
#   'BNEF',
#   '2030',
#   'EV',
#   'green'],
#  [' ',
#   'report',
#   'Southeast',
#   'Asiarsquos',
#   'carbon',
#   'green',
#   'climate',
#   'Hardcastle',
#   'action',
#   '$',
#   'Net',
#   'Zero',
#   'rdquo',
#   'energy',
#   'said',
#   'public',
#   'Asia',
#   'governments',
#   'Global',
#   'capital',
#   'collective'],
#  ['energy',
#   'Europe',
#   ' ',
#   'prices',
#   'gas',
#   'European',
#   'transition',
#   'high',
#   'said',
#   'EU',
#   'plans',
#   'Birol',
#   'sky',
#   'Russia',
#   'send',
#   'additional',
#   'volumes',
#   'Gazprom',
#   'market',
#   'storage',
#   'coal'],
#  ['energy',
#   ' ',
#   'global',
#   'like',
#   'transition',
#   'renewable',
#   'clean',
#   'fossil',
#   'fuels',
#   'world',
#   'oil',
#   'going',
#   'lithium',
#   'supply',
#   'decades',
#   'energies',
#   'batteries',
#   'infrastructure',
#   'battery',
#   'nations',
#   'industry'],
#  [' ',
#   'carbon',
#   'solar',
#   'oil',
#   'Chevron',
#   'wind',
#   'energy',
#   'power',
#   'gas',
#   'renewable',
#   'emissions',
#   'CCS',
#   'Exxon',
#   'low',
#   'lower',
#   'plans',
#   'invest',
#   'businesses',
#   'production',
#   'investments',
#   'hydrogen'],
#  ['solar',
#   ' ',
#   'capacity',
#   'energy',
#   'installations',
#   'GW',
#   'study',
#   'Energy',
#   'cost',
#   'U.S.',
#   'government',
#   'support',
#   'power',
#   'year',
#   'supply',
#   'chain',
#   'disruptions',
#   'price',
#   'percent',
#   'utility',
#   'scale'],
#  ['Manchin',
#   ' ',
#   'Sen.',
#   'Democratic',
#   '$',
#   '3.5',
#   'trillion',
#   'plan',
#   'said',
#   'CNN',
#   'bill',
#   'recovery',
#   'Biden',
#   'energy',
#   'openly',
#   'price',
#   'explain',
#   'vote',
#   'notes',
#   '100',
#   'percent'],
#  ['oil',
#   'major',
#   ' ',
#   'energy',
#   'green',
#   'climate',
#   'hydrocarbon',
#   'projects',
#   'UAE',
#   'power',
#   'world',
#   'renewable',
#   'Gulf',
#   'hydrogen',
#   'gas',
#   'producing',
#   'countries',
#   'Iraqrsquos',
#   'Finance',
#   'producers',
#   'like'],
#  ['solar',
#   'capacity',
#   ' ',
#   'silver',
#   'supply',
#   'Energy',
#   '2021',
#   '$',
#   'years',
#   'GW',
#   'Rystad',
#   'costs',
#   '2020',
#   'prices',
#   'input',
#   'factors',
#   'price',
#   'polysilicon',
#   'kg',
#   'global',
#   'industry'],
#  ['oil',
#   'Saudi',
#   ' ',
#   'plans',
#   'Arabia',
#   'energy',
#   'production',
#   'prices',
#   'price',
#   'market',
#   'Kingdom',
#   'way',
#   'transition',
#   'renewable',
#   'going',
#   'year',
#   'importers',
#   'needs',
#   'Arabiarsquos',
#   'billion',
#   'reality'],
#  ['energy',
#   'wind',
#   ' ',
#   'power',
#   'potential',
#   'United',
#   'global',
#   'year',
#   'capacity',
#   'world',
#   'States',
#   'production',
#   'renewable',
#   'negative',
#   'U.S.',
#   'policy',
#   'Wind',
#   'carbon',
#   'free',
#   'revolution',
#   'capable'],
#  ['consumption',
#   'energy',
#   ' ',
#   'renewable',
#   '2020',
#   'category',
#   'power',
#   'global',
#   'rate',
#   'growth',
#   'decade',
#   'solar',
#   'overall',
#   '   ',
#   'exajoules',
#   'wind',
#   'renewables',
#   'U.S.',
#   'past',
#   'Review',
#   'World'],
#  [' ',
#   'energy',
#   'Wood',
#   'government',
#   'transition',
#   'loan',
#   'climate',
#   'emissions',
#   'said',
#   'carbon',
#   'giant',
#   'm',
#   'backed',
#   'green',
#   'ndash',
#   'UKrsquos',
#   'percent',
#   'UK',
#   'Export',
#   'Transition',
#   'EDG'],
#  [' ',
#   'SPAC',
#   'energy',
#   'companies',
#   'SPACs',
#   'start',
#   'public',
#   'ups',
#   'check',
#   'firm',
#   'business',
#   'rdquo',
#   'said',
#   'clean',
#   'blank',
#   'sector',
#   'technology',
#   'market',
#   'Energy',
#   '$',
#   'billion'],
#  [' ',
#   'wind',
#   'Big',
#   'Oil',
#   'solar',
#   'lower',
#   'Mathis',
#   'renewables',
#   'energy',
#   'Oilrsquos',
#   'results',
#   'oil',
#   'industry',
#   'renewable',
#   'demand',
#   'afford',
#   'lot',
#   'raw',
#   'year',
#   'farms',
#   'generation'],
#  ['Oil',
#   'Big',
#   'energy',
#   ' ',
#   'wind',
#   'renewable',
#   'transition',
#   'oil',
#   'power',
#   'renewables',
#   'industry',
#   'gas',
#   'carbon',
#   'offshore',
#   'floating',
#   'technology',
#   'connection',
#   'Scotland',
#   'said',
#   'low',
#   'business'],
#  [' ',
#   '$',
#   'growth',
#   'Y',
#   'Fisker',
#   'reported',
#   'Q2',
#   'year',
#   '2021',
#   'cash',
#   'vehicles',
#   'electric',
#   'company',
#   'million',
#   'M',
#   'Oil',
#   'earnings',
#   'sector',
#   'revenue',
#   'ago',
#   'Biden'],
#  [' ',
#   'geothermal',
#   'energy',
#   'ndash',
#   'capacity',
#   'MW',
#   '$',
#   'TWh',
#   'sources',
#   'countries',
#   'Kenya',
#   'cost',
#   'wind',
#   'power',
#   'electricity',
#   'installed',
#   'potential',
#   '2030',
#   'projects',
#   'Indonesia',
#   'incentives'],
#  ['vehicles',
#   'EVs',
#   'service',
#   'times',
#   'report',
#   'months',
#   'noted',
#   'costs',
#   'E',
#   '$',
#   'batteries',
#   'better',
#   'internal',
#   'combustion',
#   'engine',
#   'ICE',
#   'cost',
#   'time',
#   'expensive',
#   'ownership',
#   'Predict'],
#  ['wind',
#   ' ',
#   'energy',
#   'oil',
#   'offshore',
#   'U.S.',
#   'projects',
#   '$',
#   'development',
#   'Big',
#   'Oil',
#   'years',
#   'firms',
#   'international',
#   'significant',
#   'percent',
#   'billion',
#   'investment',
#   'million',
#   'power',
#   'financial'],
#  [' ',
#   'battery',
#   'storage',
#   'fire',
#   'energy',
#   'lithium',
#   'batteries',
#   'ion',
#   'cell',
#   'risk',
#   'fires',
#   'Battery',
#   'rdquo',
#   'year',
#   'GWh',
#   'site',
#   'way',
#   'risks',
#   'build',
#   'EcoGeneration',
#   'start'],
#  [' ',
#   '$',
#   'solar',
#   'Solar',
#   'company',
#   'says',
#   'Daqo',
#   'new',
#   'panels',
#   'Energy',
#   'Xinjiang',
#   'tax',
#   'Enphase',
#   'year',
#   'quarter',
#   'Biden',
#   'companies',
#   'GAAP',
#   'EPS',
#   'consensus',
#   'M'],
#  [' ',
#   'Saudi',
#   'Arabia',
#   'energy',
#   'oil',
#   '$',
#   'gas',
#   'hydrogen',
#   'UAE',
#   'power',
#   'year',
#   'wind',
#   'green',
#   'develop',
#   'capacity',
#   'plants',
#   'Aramco',
#   'waste',
#   'GCC',
#   'world',
#   'prices'],
#  ['wind',
#   ' ',
#   'power',
#   'capacity',
#   'offshore',
#   '30',
#   'GW',
#   'year',
#   'infrastructure',
#   'credit',
#   'set',
#   'according',
#   'tax',
#   '$',
#   'transmission',
#   'generation',
#   'IHS',
#   'target',
#   'December',
#   'farm',
#   'incentives'],
#  ['energy',
#   'United',
#   'oil',
#   'States',
#   'shale',
#   'security',
#   'clean',
#   ' ',
#   'independence',
#   'gas',
#   'global',
#   'world',
#   'long',
#   'supply',
#   'far',
#   'U.S.',
#   'country',
#   'geopolitical',
#   'change',
#   'Statesrsquo',
#   'threat'],
#  [' ',
#   'Mercedes',
#   'auto',
#   'electric',
#   'like',
#   'said',
#   'targets',
#   'luxury',
#   'going',
#   'years',
#   'car',
#   'Bloomberg',
#   'says',
#   'getting',
#   'end',
#   'EVs',
#   'Stellantis',
#   'week',
#   'coming',
#   'prices',
#   'rising'],
#  [' ',
#   'coal',
#   'assets',
#   'fossil',
#   'companies',
#   'mining',
#   '$',
#   'bad',
#   'Fink',
#   'environmental',
#   'fuel',
#   'energy',
#   'year',
#   'oil',
#   'banks',
#   'help',
#   'climate',
#   'm',
#   'projects',
#   'Energy',
#   'gas'],
#  [' ',
#   'tech',
#   'green',
#   'investment',
#   'funds',
#   'new',
#   'energy',
#   'technology',
#   'company',
#   'market',
#   'EV',
#   'startups',
#   'years',
#   'ago',
#   'investors',
#   'breakthroughs',
#   'funding',
#   'capital',
#   'ESG',
#   'investing',
#   'rush'],
#  ['$',
#   'trillion',
#   ' ',
#   'net',
#   'zero',
#   'world',
#   'need',
#   'BNEF',
#   'energy',
#   'emissions',
#   'achieve',
#   '2050',
#   'investments',
#   'invest',
#   '173',
#   '30',
#   'carbon',
#   'said',
#   'transition',
#   'investment',
#   'says'],
#  [' ',
#   'Indiana',
#   'INDOT',
#   'project',
#   'wireless',
#   'charging',
#   'electric',
#   'phase',
#   'pavement',
#   'vehicles',
#   'ASPIRE',
#   'technology',
#   'highway',
#   'Magment',
#   'said',
#   'partnership',
#   'Purdue',
#   'University',
#   'vehicle',
#   'adoption',
#   'support'],
#  [' ',
#   'EU',
#   'combustion',
#   'emissions',
#   'targets',
#   'new',
#   '2030',
#   '   ',
#   'measures',
#   'engines',
#   'ban',
#   'sales',
#   'European',
#   'internal',
#   'vehicles',
#   'carbon',
#   'policy',
#   'likely',
#   'emission',
#   'said',
#   'reduction'],
#  [' ',
#   'biomass',
#   'energy',
#   'United',
#   'States',
#   'Europe',
#   'market',
#   'EU',
#   'emissions',
#   'European',
#   'solar',
#   'wind',
#   'carbon',
#   'world',
#   'renewables',
#   'fossil',
#   'coal',
#   'renewable',
#   'Energy',
#   'source',
#   'wood'],
#  ['PACE',
#   ' ',
#   'loan',
#   'program',
#   'people',
#   'homes',
#   '$',
#   'government',
#   'losing',
#   'homeowners',
#   '2008',
#   'crisis',
#   'housing',
#   'predatory',
#   'low',
#   'risk',
#   'payments',
#   'Missouri',
#   'Thomas',
#   'decade',
#   'mortgage'],
#  [' ',
#   'cities',
#   'climate',
#   'national',
#   'Cities',
#   'policy',
#   'sustainability',
#   'data',
#   'change',
#   'governance',
#   'governments',
#   'urban',
#   'green',
#   'public',
#   'city',
#   'ecosystem',
#   'growth',
#   'objectives',
#   'goals',
#   'building',
#   'programmes'],
#  [' ',
#   'lithium',
#   'Lithium',
#   'demand',
#   'prices',
#   'rdquo',
#   'world',
#   'year',
#   'set',
#   'industry',
#   'Ganfeng',
#   'said',
#   'supply',
#   'producers',
#   'production',
#   'EVs',
#   'energy',
#   'market',
#   'EV',
#   'batteries',
#   'jump'],
#  [' ',
#   'hydrogen',
#   'projects',
#   'green',
#   'market',
#   'production',
#   'year',
#   'capacity',
#   'Germany',
#   'EUR',
#   'says',
#   'based',
#   'Matthes',
#   'billion',
#   'new',
#   'electrolyser',
#   'Hydrogen',
#   'announced',
#   'development',
#   'rdquo',
#   'H2Global'],
#  [' ',
#   'solar',
#   'ban',
#   'U.S.',
#   'Xinjiang',
#   'products',
#   'industry',
#   'said',
#   'materials',
#   'forced',
#   'labor',
#   'based',
#   'United',
#   'States',
#   'Hoshine',
#   'polysilicon',
#   'Solar',
#   'capacity',
#   'Administration',
#   'supply',
#   'China'],
#  [' ',
#   'CSP',
#   'solar',
#   'energy',
#   'Solar',
#   'power',
#   'mirrors',
#   'thermal',
#   '     ',
#   'fuels',
#   'sunlight',
#   'aviation',
#   'Energy',
#   'technology',
#   'Heliogen',
#   'carbon',
#   'panels',
#   'air',
#   'efficiency',
#   'receiver',
#   'oil'],
#  [' ',
#   'solar',
#   'Xinjiang',
#   'company',
#   'polysilicon',
#   'Solar',
#   'Biden',
#   'ban',
#   'panels',
#   'U.S.',
#   'administration',
#   'imports',
#   'products',
#   'based',
#   'latest',
#   'cost',
#   'tax',
#   'market',
#   'forced',
#   'labor',
#   'Chinese'],
#  ['EV',
#   ' ',
#   'vehicle',
#   'sales',
#   'car',
#   'market',
#   'China',
#   'making',
#   'switch',
#   'boom',
#   'expected',
#   '2033',
#   'new',
#   'research',
#   'vehicles',
#   'Europe',
#   'U.S.',
#   'powered',
#   'EVs',
#   'world',
#   'electric'],
#  [' ',
#   'energy',
#   'Iran',
#   'renewables',
#   'sector',
#   'sanctions',
#   'production',
#   'potential',
#   'country',
#   'government',
#   'Iranrsquos',
#   'countryrsquos',
#   'Tehran',
#   'Iranian',
#   'U.S.',
#   'Middle',
#   'largest',
#   'reserves',
#   'solar',
#   'fossil',
#   'nuclear'],
#  ['solar',
#   ' ',
#   'energy',
#   'panels',
#   'Solar',
#   'narrative',
#   'cost',
#   'farm',
#   'electricity',
#   'problem',
#   'world',
#   'power',
#   'industry',
#   'farms',
#   'percent',
#   'said',
#   'capacity',
#   'panel',
#   'renewable',
#   'land',
#   'fact'],
#  ['hydrogen',
#   'energy',
#   'green',
#   ' ',
#   'wind',
#   'solar',
#   'Green',
#   'production',
#   'canrsquot',
#   'fossil',
#   'fuels',
#   'storage',
#   'industry',
#   'grid',
#   'clean',
#   'future',
#   'forms',
#   'power',
#   'time',
#   'flow',
#   'cost'],
#  [' ',
#   'sustainable',
#   'construction',
#   'region',
#   'development',
#   'use',
#   'ndash',
#   'areas',
#   'world',
#   'environmental',
#   'social',
#   'energy',
#   'carbon',
#   'sustainability',
#   'rdquo',
#   'told',
#   'OBG',
#   'project',
#   'urban',
#   'transport',
#   'governance'],
#  [' ',
#   'solar',
#   'Kazakhstan',
#   'energy',
#   'China',
#   'Chinese',
#   'plant',
#   'news',
#   'report',
#   'wind',
#   'project',
#   'said',
#   '100',
#   'addition',
#   'Bank',
#   'MW',
#   'agency',
#   'farm',
#   'near',
#   'Belt',
#   'Road'],
#  [' ',
#   'energy',
#   'emissions',
#   'climate',
#   'carbon',
#   'ndash',
#   'fossil',
#   'new',
#   'net',
#   'zero',
#   'global',
#   'transition',
#   'emerging',
#   'markets',
#   'change',
#   'IEA',
#   'report',
#   'solar',
#   'oil',
#   'sources',
#   'significant'],
#  [' ',
#   'EV',
#   '$',
#   'companies',
#   'Ford',
#   'share',
#   'prices',
#   'GM',
#   'electric',
#   'vehicles',
#   'startups',
#   'tech',
#   'aim',
#   'development',
#   'public',
#   'boom',
#   'year',
#   'cash',
#   'end',
#   'early',
#   'EVs'],
#  [' ',
#   'battery',
#   'CO2',
#   'EU',
#   'EV',
#   'rules',
#   'sales',
#   '2025',
#   'Europe',
#   'Europersquos',
#   'Transport',
#   'amp',
#   'decade',
#   'UK',
#   '2030',
#   'new',
#   'Environment',
#   'cars',
#   'GWh',
#   'rdquo',
#   'investments'],
#  ['hydrogen',
#   'Iceland',
#   ' ',
#   'energy',
#   'green',
#   'buses',
#   'resources',
#   'geothermal',
#   'country',
#   'countries',
#   'start',
#   'Arnason',
#   'renewable',
#   'power',
#   'economy',
#   'Icelandic',
#   'plans',
#   'technology',
#   'viable',
#   'small',
#   'thing'],
#  ['hydrogen',
#   ' ',
#   'Germany',
#   'projects',
#   'said',
#   'billion',
#   'transport',
#   'making',
#   'carbon',
#   'fund',
#   '62',
#   'US$',
#   'leader',
#   'economy',
#   'emissions',
#   'transportation',
#   'steelmaking',
#   'chemicals',
#   'Minister',
#   'Altmaier',
#   'Germanyrsquos'],
#  ['solar',
#   'polysilicon',
#   'Daqo',
#   'prices',
#   'year',
#   'China',
#   'high',
#   'production',
#   'supply',
#   'grade',
#   'forced',
#   'labor',
#   'energy',
#   'Polysilicon',
#   'suppliers',
#   'manufacturers',
#   'kg',
#   'project',
#   ' ',
#   'Energy',
#   'million'],
#  ['energy',
#   ' ',
#   'solar',
#   'wind',
#   'renewable',
#   'stocks',
#   'percent',
#   'MSCI',
#   'investors',
#   'stock',
#   'market',
#   'crowding',
#   'sector',
#   'shortage',
#   'power',
#   'credits',
#   'industry',
#   'shocks',
#   'tech',
#   'index',
#   'report'],
#  [' ',
#   'demand',
#   'prices',
#   'oil',
#   'year',
#   'commodity',
#   'price',
#   'market',
#   'lithium',
#   'copper',
#   'years',
#   'commodities',
#   'including',
#   'economy',
#   'world',
#   'inflation',
#   'renewable',
#   'China',
#   'thanks',
#   '$',
#   'LFP'],
#  [' ',
#   'hydrogen',
#   '$',
#   'Hydrogen',
#   'Plug',
#   'company',
#   'electric',
#   'stocks',
#   'sector',
#   'M',
#   'says',
#   'U.S.',
#   'vehicles',
#   'infrastructure',
#   'year',
#   'Power',
#   'time',
#   '2020',
#   'gross',
#   'billings',
#   'stations'],
#  [' ',
#   '2030',
#   '2021',
#   'GW',
#   'wind',
#   'battery',
#   'power',
#   'set',
#   'energy',
#   'Rystad',
#   'needs',
#   'solar',
#   'targets',
#   'mix',
#   '$',
#   'costs',
#   'needed',
#   'flexible',
#   'deliver',
#   'million',
#   'grow'],
#  [' ',
#   'Big',
#   'renewable',
#   'Oil',
#   'solar',
#   'oil',
#   'energy',
#   'wind',
#   'power',
#   'capacity',
#   'companies',
#   'increase',
#   'shareholders',
#   'emission',
#   'Energy',
#   'major',
#   'generation',
#   'week',
#   'investment',
#   'fact',
#   'government'],
#  ['energy',
#   ' ',
#   'ETFs',
#   'clean',
#   'year',
#   'investors',
#   'funds',
#   'percent',
#   'ESG',
#   'ETF',
#   '2020',
#   'sustainable',
#   'decades',
#   'recent',
#   'oil',
#   'NYSEARCA',
#   'told',
#   'Yones',
#   'focused',
#   'green',
#   'seen'],
#  ['energy',
#   ' ',
#   'world',
#   'solar',
#   'large',
#   'scale',
#   'airports',
#   'global',
#   'major',
#   'new',
#   'clean',
#   'panels',
#   'need',
#   'rdquo',
#   '$',
#   'billion',
#   'power',
#   'study',
#   'residential',
#   'buildings',
#   'time'],
#  ['capacity',
#   'additions',
#   'power',
#   'year',
#   'new',
#   ' ',
#   'record',
#   'solar',
#   'wind',
#   'percent',
#   'said',
#   '90',
#   '2019',
#   'GW',
#   'pace',
#   'IEA',
#   'renewable',
#   'global',
#   'generation',
#   'jumped',
#   'report'],
#  [' ',
#   'electricity',
#   'solar',
#   'bills',
#   'California',
#   'state',
#   'energy',
#   'costs',
#   'grid',
#   'power',
#   'Californians',
#   'installations',
#   '$',
#   'emissions',
#   'report',
#   'electric',
#   'cost',
#   'program',
#   'billion',
#   'summer',
#   'storage'],
#  ['hydrogen',
#   ' ',
#   'carbon',
#   'production',
#   'produced',
#   'nuclear',
#   'process',
#   'power',
#   'methane',
#   'temperature',
#   'cost',
#   'footprint',
#   'produce',
#   'high',
#   'electricity',
#   'water',
#   'low',
#   'mdash',
#   'SMR',
#   'Hydrogen',
#   'energy'],
#  ['wind',
#   'Australiarsquos',
#   'energy',
#   ' ',
#   'Australia',
#   'South',
#   'offshore',
#   'renewables',
#   'capacity',
#   'ndash',
#   'coal',
#   'Star',
#   'projects',
#   'Graph',
#   'Energy',
#   'farms',
#   'largest',
#   'located',
#   '2020',
#   'Australian',
#   'authorities'],
#  [' ',
#   'offshore',
#   'wind',
#   '$',
#   'billion',
#   'capex',
#   'capacity',
#   'GW',
#   'expected',
#   '2030',
#   'projects',
#   'spending',
#   'installed',
#   'decade',
#   'global',
#   'Rystad',
#   'Energy',
#   'investments',
#   'significant',
#   'total',
#   'share'],
#  ['China',
#   ' ',
#   'year',
#   'Gorges',
#   'billion',
#   'Bloomberg',
#   'wind',
#   'capacity',
#   'renewables',
#   'unit',
#   'Shanghai',
#   'biggest',
#   'Renewables',
#   'US$',
#   'power',
#   'Corporation',
#   'shares',
#   'initial',
#   'public',
#   'offering',
#   'IPO'],
#  ['$',
#   ' ',
#   'Saudi',
#   '2030',
#   'Arabia',
#   'oil',
#   'said',
#   'years',
#   'Kingdom',
#   'Mohammed',
#   'Jadaan',
#   'largest',
#   'trillion',
#   'Vision',
#   'fiscal',
#   'crude',
#   'gas',
#   'renewables',
#   '6',
#   'OPEC',
#   'investment'],
#  [' ',
#   'energy',
#   'wind',
#   'solar',
#   'blackouts',
#   'capacity',
#   'electricity',
#   'California',
#   'renewable',
#   'Texas',
#   'power',
#   'August',
#   'CAISO',
#   'resources',
#   'people',
#   'gas',
#   'state',
#   'reliance',
#   'risk',
#   'turbines',
#   'plants'],
#  ['hydrogen',
#   ' ',
#   'energy',
#   'industry',
#   'America',
#   'production',
#   'Chile',
#   'development',
#   'Latin',
#   'global',
#   'carbon',
#   '2020',
#   'transportation',
#   'use',
#   'develop',
#   'world',
#   'push',
#   'low',
#   'Hydrogen',
#   'decarbonize',
#   'Argentina'],
#  [' ',
#   'wind',
#   'energy',
#   'offshore',
#   'cost',
#   'option',
#   'fees',
#   'solar',
#   'sector',
#   'renewable',
#   'decade',
#   'oil',
#   'costs',
#   'IEA',
#   'power',
#   'electricity',
#   'end',
#   '35',
#   'billion',
#   'investors',
#   'GW'],
#  [' ',
#   'energy',
#   'solar',
#   'clean',
#   'China',
#   'Valley',
#   'tech',
#   'sector',
#   'year',
#   'Silicon',
#   'startups',
#   'investors',
#   'Clean',
#   '$',
#   'cost',
#   'decade',
#   'going',
#   'including',
#   'past',
#   'Energy',
#   'technologies'],
#  ['hydrogen',
#   ' ',
#   'produced',
#   'Enel',
#   'Green',
#   'green',
#   'Power',
#   '$',
#   'according',
#   'kilo',
#   'today',
#   'Zorzoli',
#   'company',
#   'emissions',
#   'price',
#   'industrial',
#   '2',
#   'rdquo',
#   'said',
#   'grey',
#   'energy'],
#  ['oil',
#   'energy',
#   ' ',
#   'global',
#   'world',
#   'countries',
#   'rdquo',
#   'worldrsquos',
#   'geopolitical',
#   'transition',
#   'new',
#   'United',
#   'Saudi',
#   'green',
#   'clean',
#   'States',
#   'political',
#   'power',
#   'question',
#   'conflict',
#   'largest'],
#  ['wind',
#   'capacity',
#   ' ',
#   'year',
#   '2020',
#   'power',
#   'China',
#   'GW',
#   'installations',
#   'growth',
#   'said',
#   'record',
#   'storage',
#   'additions',
#   'United',
#   'States',
#   'U.S.',
#   'Wind',
#   'commissioned',
#   'new',
#   'set'],
#  ['solar',
#   ' ',
#   'Energy',
#   'PV',
#   'capacity',
#   'land',
#   'Rystad',
#   'wind',
#   'scale',
#   'projects',
#   'demand',
#   'country',
#   'utility',
#   'Solar',
#   'farms',
#   'plants',
#   'GW',
#   'new',
#   'transmission',
#   'ndash',
#   'storage'],
#  ['solar',
#   ' ',
#   'new',
#   'percent',
#   'industry',
#   'year',
#   'pandemic',
#   'capacity',
#   'increase',
#   'Solar',
#   'GW',
#   '2019',
#   'report',
#   'Wood',
#   'scale',
#   'additions',
#   'total',
#   'continue',
#   'trajectory',
#   'energy',
#   'SEIA'],
#  ['solar',
#   ' ',
#   'energy',
#   'China',
#   'tariffs',
#   'sector',
#   'modules',
#   'U.S.',
#   'renewable',
#   'United',
#   'States',
#   'Biden',
#   'cents',
#   'America',
#   'panels',
#   'end',
#   'independence',
#   'world',
#   'market',
#   'oil',
#   '$'],
#  [' ',
#   'ESG',
#   'year',
#   'GCC',
#   'standards',
#   'ndash',
#   'Saudi',
#   'investors',
#   'announced',
#   'set',
#   'September',
#   'region',
#   'launched',
#   '$',
#   'governance',
#   'recovery',
#   'Covid-19',
#   'evaluate',
#   'investments',
#   'sustainable',
#   'criteria'],
#  ['hydrogen',
#   ' ',
#   'cars',
#   'fuel',
#   'fueling',
#   'technology',
#   'stations',
#   'car',
#   'Diess',
#   'EVs',
#   'cell',
#   'carmakers',
#   'years',
#   'major',
#   'EV',
#   'need',
#   'according',
#   'European',
#   'viable',
#   'battery',
#   'vehicles'],
#  ['hydrogen',
#   ' ',
#   'green',
#   'Saudi',
#   'Arabia',
#   'energy',
#   'produced',
#   'capacity',
#   '$',
#   'project',
#   'Helios',
#   'able',
#   'wind',
#   'need',
#   'cost',
#   'exporter',
#   'water',
#   'solar',
#   'resources',
#   'scale',
#   'GW'],
#  ['South',
#   'wind',
#   'energy',
#   ' ',
#   'Korean',
#   'coal',
#   'Sinan',
#   'capacity',
#   'farm',
#   'companies',
#   'project',
#   'KEPCO',
#   'Phase',
#   'assumed',
#   'Korearsquos',
#   'generation',
#   'total',
#   'utilization',
#   'renewables',
#   'largest',
#   '2021'],
#  [' ',
#   'wind',
#   'energy',
#   'solar',
#   'grid',
#   'Africa',
#   'potential',
#   'renewable',
#   'electricity',
#   'African',
#   'countries',
#   'oil',
#   'cheap',
#   'infrastructure',
#   'Gill',
#   'power',
#   'projects',
#   'Davis',
#   'GW',
#   'renewables',
#   'scale'],
#  [' ',
#   'solar',
#   'panel',
#   'space',
#   'energy',
#   'earth',
#   'power',
#   'orbit',
#   'systems',
#   'capturing',
#   'Sun',
#   'CNN',
#   'Jaffe',
#   'told',
#   'Pentagon',
#   'potential',
#   'light',
#   'U.S.',
#   'Naval',
#   'Research',
#   'Laboratory'],
#  ['geothermal',
#   'wells',
#   ' ',
#   'heat',
#   'drilling',
#   'electricity',
#   'oil',
#   'abandoned',
#   'companies',
#   'generation',
#   'heating',
#   'water',
#   'industry',
#   'emission',
#   'reach',
#   'need',
#   'deep',
#   'heated',
#   'equipment',
#   'costs',
#   'Oil'],
#  [' ',
#   'fossil',
#   'oil',
#   'fuels',
#   'energy',
#   'mdash',
#   'consumption',
#   'pipeline',
#   'fuel',
#   'U.S.',
#   'decade',
#   'renewables',
#   'need',
#   'dependence',
#   'years',
#   'past',
#   'donrsquot',
#   'supplied',
#   'power',
#   'risk',
#   'quickly'],
#  [' ',
#   'energy',
#   'hydrogen',
#   'Texas',
#   'power',
#   'renewable',
#   'storage',
#   'Energy',
#   'state',
#   'grid',
#   'batteries',
#   'fuel',
#   'revenue',
#   '$',
#   '   ',
#   'year',
#   'far',
#   'massive',
#   'Electric',
#   'Reliability',
#   'gas'],
#  ['jobs',
#   'offshore',
#   'wind',
#   ' ',
#   '2030',
#   'expected',
#   'ndash',
#   'capacity',
#   'employment',
#   'total',
#   'installed',
#   'manufacturing',
#   'OampM',
#   'gas',
#   'Rystad',
#   'Energy',
#   'decade',
#   'workers',
#   'development',
#   'oil',
#   'years'],
#  ['geothermal',
#   ' ',
#   'energy',
#   'technology',
#   'new',
#   'power',
#   'underground',
#   'carbon',
#   'Eavorrsquos',
#   'system',
#   'BP',
#   'investment',
#   'zero',
#   'constant',
#   'oil',
#   'Chevron',
#   'invest',
#   'Eavor',
#   'provides',
#   'source',
#   'largely'],
#  ['offshore',
#   'wind',
#   ' ',
#   'U.S.',
#   'energy',
#   'Wind',
#   'said',
#   'GW',
#   'Vineyard',
#   'policies',
#   'industry',
#   'federal',
#   'clean',
#   'States',
#   'projects',
#   'New',
#   'rdquo',
#   'Oil',
#   'President',
#   'Biden',
#   'environmental'],
#  ['wind',
#   ' ',
#   'energy',
#   'oil',
#   'BP',
#   'renewable',
#   'U.K.',
#   'majors',
#   'production',
#   'offshore',
#   'power',
#   '$',
#   'carbon',
#   'farms',
#   'expected',
#   '2030.nbsp',
#   'Oil',
#   'million',
#   '2020',
#   'project',
#   'BPrsquos'],
#  ['energy',
#   ' ',
#   'electricity',
#   'storage',
#   'hydro',
#   'demand',
#   'U.K.',
#   'power',
#   'new',
#   'renewable',
#   'technologies',
#   'provide',
#   'hydropower',
#   'high',
#   'project',
#   'RheEnergise',
#   'lower',
#   'fossil',
#   'innovative',
#   'underground',
#   'dams'],
#  [' ',
#   'hydrogen',
#   'said',
#   'energy',
#   'green',
#   'rdquo',
#   'nbsp',
#   'carbon',
#   'system',
#   'molecules',
#   'power',
#   'cost',
#   'years',
#   'need',
#   'fuel',
#   'pipeline',
#   'Energy',
#   'CEO',
#   'Europe',
#   'Snam',
#   'ldquoWe'],
#  [' ',
#   'battery',
#   'energy',
#   'CEP',
#   'storage',
#   'power',
#   'South',
#   'Wales',
#   'Australia',
#   'grid',
#   'batteries',
#   'solar',
#   'renewable',
#   'new',
#   'New',
#   'company',
#   'Energy',
#   'GW',
#   'Australian',
#   'electricity',
#   'coal'],
#  ['stocks',
#   'energy',
#   'market',
#   'stock',
#   ' ',
#   'clean',
#   'meme',
#   'GameStop',
#   'hedge',
#   'change',
#   'value',
#   'climate',
#   'paying',
#   'attention',
#   'real',
#   'GME',
#   'week',
#   'Redditors',
#   'lot',
#   'world',
#   'cap'],
#  [' ',
#   '$',
#   'energy',
#   'worth',
#   'billion',
#   'net',
#   'green',
#   'clean',
#   'solar',
#   'Tesla',
#   'market',
#   'sector',
#   'EV',
#   'Li',
#   'year',
#   'founder',
#   'Musk',
#   'billionaires',
#   'new',
#   'thanks',
#   'Elon'],
#  ['solar',
#   'panels',
#   ' ',
#   'energy',
#   'renewable',
#   'industry',
#   'waste',
#   'recycling',
#   'infrastructure',
#   'environmental',
#   'like',
#   'rdquo',
#   '2050',
#   'double',
#   'environment',
#   'photovoltaic',
#   'affordable',
#   'growing',
#   'turn',
#   'fossil',
#   'clean'],
#  [' ',
#   'e',
#   'fuel',
#   'fuels',
#   'synthetic',
#   'Siemens',
#   'Porsche',
#   'project',
#   'energy',
#   'companies',
#   'alternative',
#   'wind',
#   'power',
#   'carbon',
#   'use',
#   'EV',
#   'produce',
#   'Energy',
#   'neutral',
#   'million',
#   'company'],
#  [' ',
#   'energy',
#   'GW',
#   'Saudi',
#   'Arabia',
#   'solar',
#   'said',
#   'power',
#   'capacity',
#   'Germany',
#   'renewable',
#   'Energy',
#   'Prince',
#   'Abdulaziz',
#   'bin',
#   'Salman',
#   'renewables',
#   'week',
#   'ldquoWe',
#   'rdquo',
#   'Future'],
#  ['renewable',
#   ' ',
#   'percent',
#   'net',
#   'zero',
#   'Total',
#   'renewables',
#   'energy',
#   'oil',
#   'announcing',
#   'billion',
#   'Bloomberg',
#   'nbsp',
#   'BP',
#   'new',
#   'gas',
#   '40',
#   'deal',
#   'largest',
#   'year',
#   'targets'],
#  [' ',
#   'energy',
#   'India',
#   'solar',
#   'Total',
#   'sector',
#   'investment',
#   'gas',
#   'oil',
#   'Indiarsquos',
#   'percent',
#   'year',
#   'renewable',
#   'AGEL',
#   '$',
#   'billion',
#   'stake',
#   'largest',
#   'power',
#   'GW',
#   'capacity'],
#  ['oil',
#   'business',
#   'risk',
#   ' ',
#   'companies',
#   'capital',
#   'investors',
#   'lower',
#   'equity',
#   'renewable',
#   'return',
#   'renewables',
#   'market',
#   'cost',
#   'company',
#   'Oil',
#   'higher',
#   'Figure',
#   'energy',
#   'financial',
#   'debt'],
#  [' ',
#   'billion',
#   '$',
#   'fund',
#   'BEVrsquos',
#   'start',
#   'global',
#   'emissions',
#   'venture',
#   'capital',
#   'technologies',
#   'backed',
#   'Bloomberg',
#   'second',
#   'years',
#   'help',
#   'emerging',
#   'companies',
#   '40',
#   'nbsp',
#   'steel'],
#  ['energy',
#   ' ',
#   'wind',
#   'Colombia',
#   'renewable',
#   'solar',
#   'Colombian',
#   'oil',
#   'projects',
#   'hydropower',
#   'government',
#   'country',
#   'new',
#   'capacity',
#   'electricity',
#   'renewables',
#   'La',
#   'Guajira',
#   'hydrogen',
#   'Ministry',
#   'GW'],
#  ['hydrogen',
#   ' ',
#   'Adnoc',
#   'Dhabi',
#   'produce',
#   'green',
#   'Abu',
#   'Bloomberg',
#   'natural',
#   'blue',
#   'gas',
#   'state',
#   'oil',
#   'company',
#   'Investment',
#   'Mubadala',
#   'Alliance',
#   'production',
#   'export',
#   'growing',
#   'betting'],
#  [' ',
#   'energy',
#   'hydrogen',
#   'air',
#   'capture',
#   'transition',
#   'storage',
#   'carbon',
#   'fuel',
#   'electricity',
#   'emissions',
#   'problem',
#   'help',
#   'world',
#   'need',
#   'industry',
#   'Green',
#   'renewable',
#   'green',
#   'electrolysis',
#   'reduce'],
#  ['energy',
#   'Texas',
#   ' ',
#   'wind',
#   'power',
#   'coal',
#   'fossil',
#   'long',
#   'jobs',
#   'shale',
#   'oil',
#   'fuels',
#   'mix',
#   'renewable',
#   'fuel',
#   'leaders',
#   'past',
#   'generation',
#   'industry',
#   'clean',
#   'infrastructure'],
#  ['capacity',
#   'new',
#   ' ',
#   'power',
#   'GW',
#   'percent',
#   'electricity',
#   'generation',
#   'U.S.',
#   'additions',
#   'solar',
#   'wind',
#   'year',
#   'set',
#   'account',
#   '2021',
#   '2020',
#   'record',
#   'energy',
#   'EIA',
#   'generating'],
#  ['energy',
#   'year',
#   ' ',
#   'itrsquos',
#   'oil',
#   'fact',
#   'world',
#   '2020',
#   'likely',
#   'United',
#   'green',
#   'companies',
#   'history',
#   'remembered',
#   'economic',
#   'away',
#   'certain',
#   'climate',
#   'change',
#   'right',
#   'rock'],
#  ['hydrogen',
#   'energy',
#   ' ',
#   'gas',
#   'natural',
#   'Russiarsquos',
#   'new',
#   'produce',
#   'Russia',
#   'process',
#   'carbon',
#   'global',
#   'industry',
#   'Moscow',
#   'technologies',
#   'countryrsquos',
#   'Rosatom',
#   'Gazprom',
#   'looking',
#   'different',
#   'develop'],
#  ['cell',
#   'fuel',
#   'cars',
#   ' ',
#   'technology',
#   'California',
#   'car',
#   '$',
#   'Fuel',
#   'Mirai',
#   'tax',
#   'credit',
#   'year',
#   'major',
#   'report',
#   'EVs',
#   'vehicles',
#   'hydrogen',
#   'price',
#   'end',
#   'product'],
#  [' ',
#   'hydrogen',
#   'green',
#   'Hydrogen',
#   'energy',
#   'U.S.',
#   'ACWA',
#   'scale',
#   'rdquo',
#   'initiative',
#   '$',
#   '2',
#   'industries',
#   'Power',
#   'years',
#   'support',
#   'deployment',
#   'industry',
#   'deliver',
#   'cost',
#   'plant'],
#  ['energy',
#   'India',
#   'renewable',
#   ' ',
#   'GW',
#   'capacity',
#   'climate',
#   'nation',
#   'world',
#   'great',
#   'targets',
#   'meet',
#   'wind',
#   'solar',
#   'growing',
#   'worldrsquos',
#   'clean',
#   'security',
#   'demand',
#   'people',
#   'Indian'],
#  [' ',
#   'percent',
#   'solar',
#   'power',
#   'installations',
#   'year',
#   '2020',
#   'U.S.',
#   'electricity',
#   'generation',
#   'capacity',
#   'additions',
#   'GW',
#   'said',
#   'market',
#   'pandemic',
#   'renewable',
#   'record',
#   'wind',
#   'new',
#   'quarter'],
#  [' ',
#   'battery',
#   'ion',
#   'batteries',
#   'nickel',
#   'lithium',
#   'energy',
#   'cathode',
#   'rich',
#   'crystal',
#   'kWh',
#   'cost',
#   'single',
#   '100',
#   'PNNL',
#   'pack',
#   'US$',
#   'prices',
#   'average',
#   'cell',
#   'IHS'],
#  ['hydrogen',
#   ' ',
#   'green',
#   'project',
#   'carbon',
#   'said',
#   'Green',
#   'production',
#   'support',
#   'low',
#   'trial',
#   'funding',
#   'energy',
#   'rdquo',
#   'million',
#   'homes',
#   'year',
#   'emissions',
#   'percent',
#   'Scottish',
#   'costs'],
#  [' ',
#   'Norway',
#   'oil',
#   'espionage',
#   'gas',
#   'new',
#   'energy',
#   'world',
#   'foreign',
#   'companies',
#   'fracking',
#   'country',
#   'China',
#   'trade',
#   'secrets',
#   'Russia',
#   'renewable',
#   'Europe',
#   'year',
#   'spies',
#   'time'],
#  [' ',
#   'energy',
#   'investment',
#   'green',
#   'private',
#   'technologies',
#   'US$',
#   'packages',
#   'need',
#   'carbon',
#   'trillion',
#   'world',
#   'transition',
#   'capital',
#   'zero',
#   'global',
#   'emissions',
#   'low',
#   'net',
#   'stimulus',
#   'companies'],
#  ['energy',
#   ' ',
#   'space',
#   'solar',
#   'power',
#   'global',
#   'stations',
#   'year',
#   'economy',
#   'renewable',
#   'Earthrsquos',
#   'industry',
#   'development',
#   'station',
#   'system',
#   'reality',
#   'green',
#   'ldquonew',
#   'theyrsquore',
#   'potential',
#   'ground'],
#  [' ',
#   'hydrogen',
#   '$',
#   'FCEV',
#   'FCEVs',
#   'Hyundai',
#   'Ineos',
#   'market',
#   'company',
#   'sector',
#   'infrastructure',
#   'future',
#   'time',
#   'fuel',
#   'range',
#   'electric',
#   'vehicles',
#   'BEVs',
#   'United',
#   'States',
#   'compared'],
#  [' ',
#   'installation',
#   'vessels',
#   'wind',
#   'offshore',
#   'turbine',
#   'vessel',
#   'Rystad',
#   'projects',
#   'demand',
#   'turbines',
#   'Energy',
#   'fleet',
#   'expected',
#   'MW',
#   'lifting',
#   'years',
#   'foundation',
#   'larger',
#   'equipment',
#   'able'],
#  ['energy',
#   ' ',
#   'clean',
#   'renewable',
#   'power',
#   'solar',
#   'companies',
#   'purchase',
#   'Big',
#   'signed',
#   'Energy',
#   'BNEF',
#   'contracts',
#   'year',
#   'wind',
#   'Google',
#   'PPA',
#   'option',
#   'change',
#   'biggest',
#   'corporations'],
#  [' ',
#   'investment',
#   'projects',
#   'gold',
#   'Australiarsquos',
#   'battery',
#   'energy',
#   'value',
#   'percent',
#   'growth',
#   'past',
#   'LNG',
#   'commodities',
#   'years',
#   'resource',
#   'prices',
#   'demand',
#   'commodity',
#   'year',
#   '2020',
#   'report'],
#  [' ',
#   'power',
#   'solar',
#   'line',
#   'project',
#   'worldrsquos',
#   'renewable',
#   'capacity',
#   'largest',
#   'battery',
#   'undersea',
#   'GW',
#   'scale',
#   'challenges',
#   'resources',
#   '25',
#   'factor',
#   'energy',
#   'farm',
#   'cable',
#   '10'],
#  ['hydrogen',
#   ' ',
#   'energy',
#   'Japan',
#   'companies',
#   'project',
#   'Japanese',
#   'future',
#   'largest',
#   'import',
#   'transportation',
#   'Japanrsquos',
#   'country',
#   'development',
#   'develop',
#   'working',
#   'Kobe',
#   'Australiarsquos',
#   'sector',
#   'Energy',
#   'technological'],
#  ['wind',
#   'capacity',
#   'year',
#   'GW',
#   'additions',
#   'U.S.',
#   ' ',
#   'energy',
#   'record',
#   'online',
#   'renewable',
#   'United',
#   'States',
#   'turbine',
#   'previous',
#   'nearly',
#   'EIA',
#   'years',
#   'end',
#   'total',
#   'power'],
#  ['energy',
#   'electricity',
#   ' ',
#   'living',
#   'people',
#   'solar',
#   'world',
#   'access',
#   'investment',
#   'communities',
#   'small',
#   'canrsquot',
#   'imagine',
#   'grid',
#   'number',
#   'million',
#   'poorest',
#   'live',
#   'Africa',
#   'World',
#   'Economic'],
#  ['hydrogen',
#   ' ',
#   'green',
#   'countries',
#   'gas',
#   'project',
#   'AREH',
#   'phase',
#   'natural',
#   'Australia',
#   'plans',
#   'development',
#   'export',
#   'solar',
#   'production',
#   'Energy',
#   'like',
#   'Japan',
#   'fuel',
#   'strategy',
#   'world'],
#  [' ',
#   'hydrogen',
#   'cell',
#   'fuel',
#   'company',
#   'Bloom',
#   'Power',
#   '$',
#   'green',
#   'PlugPower',
#   'ITM',
#   'energy',
#   'Returns',
#   'forklifts',
#   'thanks',
#   'scale',
#   'Energy',
#   'market',
#   'technology',
#   'year',
#   'sector'],
#  [' ',
#   'hydrogen',
#   'platinum',
#   'green',
#   'Platinum',
#   'supply',
#   'gold',
#   '$',
#   'diesel',
#   'demand',
#   'new',
#   'fuel',
#   'sector',
#   'energy',
#   'million',
#   'global',
#   'big',
#   'industry',
#   'taking',
#   'prices',
#   'water'],
#  [' ',
#   'solar',
#   '$',
#   'Array',
#   'IPO',
#   'M',
#   'company',
#   'market',
#   'energy',
#   'projects',
#   'including',
#   'renewable',
#   'shares',
#   'Focus',
#   'Energia',
#   'year',
#   'Technologies',
#   'billion',
#   'systems',
#   'power',
#   'generation'],
#  ['geothermal',
#   ' ',
#   'energy',
#   'oil',
#   'gas',
#   'heat',
#   'industry',
#   'drilling',
#   'source',
#   'Geothermal',
#   'parts',
#   'resources',
#   'drillers',
#   'wells',
#   'scale',
#   'solar',
#   'abundant',
#   'emission',
#   'attention',
#   'renewable',
#   'world'],
#  [' ',
#   'solar',
#   'cells',
#   'panels',
#   'efficiency',
#   'energy',
#   'thin',
#   'film',
#   'perovskite',
#   'silicon',
#   'PV',
#   'coal',
#   'Energy',
#   'cell',
#   '25',
#   'Perovskite',
#   'Silicon',
#   'achieve',
#   'glass',
#   'electricity',
#   'carrier'],
#  ['energy',
#   'consumption',
#   'renewable',
#   'percent',
#   'year',
#   ' ',
#   'coal',
#   '2019',
#   'U.S.',
#   'electricity',
#   'generation',
#   'wind',
#   'EIA',
#   '24',
#   'said',
#   'accounted',
#   'renewables',
#   'United',
#   'States',
#   'rise',
#   'row'],
#  ['hydrogen',
#   ' ',
#   'energy',
#   'renewable',
#   'sector',
#   'green',
#   'Energy',
#   'EU',
#   '$',
#   'goal',
#   'clean',
#   'global',
#   'coming',
#   'Wall',
#   'Street',
#   'big',
#   'win',
#   'market',
#   'source',
#   'ambitious',
#   'says'],
#  ['hydrogen',
#   'green',
#   ' ',
#   'energy',
#   'clean',
#   'U.S.',
#   'renewable',
#   'fossil',
#   'fuels',
#   'electricity',
#   'countries',
#   'post',
#   'sector',
#   'approach',
#   'CleanTechnica',
#   'announcement',
#   'DOE',
#   'points',
#   'called',
#   'National',
#   'Zero'],
#  ['energy',
#   ' ',
#   'economies',
#   'global',
#   'China',
#   'emerging',
#   'India',
#   'Brazil',
#   'emissions',
#   'clean',
#   'carbon',
#   'Conversation',
#   'worldrsquos',
#   'change',
#   'renewable',
#   'ndash',
#   'largest',
#   'considerable',
#   'effort',
#   'LED',
#   'solar'],
#  ['energy',
#   'India',
#   'renewable',
#   'capacity',
#   ' ',
#   'coal',
#   'rdquo',
#   'growth',
#   'working',
#   'power',
#   'local',
#   'sector',
#   'fuel',
#   'addition',
#   'decade',
#   'domestic',
#   'emissions',
#   'nationrsquos',
#   'Argus',
#   'Indiarsquos',
#   'manufacturing'],
#  [' ',
#   'carbon',
#   'China',
#   'emissions',
#   '2060',
#   'report',
#   'electrification',
#   'noted',
#   'peak',
#   'plan',
#   'neutrality',
#   'Wood',
#   'Mackenzie',
#   'said',
#   'new',
#   'total',
#   'generation',
#   'capacity',
#   'growth',
#   'biggest',
#   'energy'],
#  [' ',
#   'wind',
#   'turbine',
#   'energy',
#   'blades',
#   'power',
#   'turbines',
#   'Wind',
#   'industry',
#   'long',
#   'renewable',
#   'carbon',
#   'having',
#   'end',
#   'blade',
#   'capacity',
#   'term',
#   'crisis',
#   'companies',
#   'high',
#   'clean'],
#  ['US$',
#   'trillion',
#   ' ',
#   'net',
#   'zero',
#   'coalition',
#   'years',
#   'said',
#   'investment',
#   '1',
#   '30',
#   'energy',
#   'ETC',
#   'global',
#   'additional',
#   'investments',
#   'world',
#   'achieve',
#   'emissions',
#   'century',
#   'annual'],
#  ['Google',
#   'carbon',
#   'energy',
#   'renewable',
#   'data',
#   'green',
#   'tech',
#   'free',
#   'Pichai',
#   'itrsquos',
#   'giant',
#   'giants',
#   'years',
#   'ldquoWe',
#   'rdquo',
#   'fact',
#   'credits',
#   'isnrsquot',
#   'million',
#   'powered',
#   'centers'],
#  ['energy',
#   ' ',
#   'oil',
#   'renewables',
#   'coal',
#   'gas',
#   'percent',
#   'sources',
#   'power',
#   'capacity',
#   'natural',
#   'demand',
#   'BP',
#   'growing',
#   'ndash',
#   'new',
#   'fossil',
#   'fuels',
#   'EVs',
#   'accounted',
#   'use'],
#  [' ',
#   'solar',
#   'panels',
#   'energy',
#   'windows',
#   'cells',
#   'power',
#   'efficiency',
#   'electricity',
#   'silicon',
#   'thin',
#   'film',
#   'Perovskite',
#   'PV',
#   'cell',
#   'perovskite',
#   'year',
#   'change',
#   'use',
#   'climate',
#   'global'],
#  ['coal',
#   'power',
#   ' ',
#   'generation',
#   'gas',
#   'TWh',
#   'wind',
#   'Rystad',
#   'electricity',
#   'Energy',
#   'solar',
#   'transmission',
#   'Australiarsquos',
#   'year',
#   'GW',
#   'Australia',
#   'million',
#   'tonnes',
#   'capacity',
#   'energy',
#   'domestic'],
#  [' ',
#   'energy',
#   'fossil',
#   'clean',
#   'policies',
#   'climate',
#   'jobs',
#   'emissions',
#   'U.S.',
#   'element',
#   'like',
#   'gas',
#   'new',
#   'pollution',
#   'fuel',
#   'companies',
#   'plan',
#   'Bidenrsquos',
#   'oil',
#   'zero',
#   'carbon'],
#  [' ',
#   'CO2',
#   'metals',
#   'magma',
#   'University',
#   'role',
#   'mantle',
#   'upper',
#   'crust',
#   'deposits',
#   'sulphide',
#   'metal',
#   'rich',
#   'evidence',
#   'fuel',
#   'rocket',
#   'plays',
#   'technologies',
#   'study',
#   'rocks',
#   'fluid'],
#  ['hydrogen',
#   ' ',
#   'green',
#   'cost',
#   'gas',
#   'production',
#   'produce',
#   'costs',
#   'energy',
#   'produced',
#   'prices',
#   'natural',
#   'renewable',
#   'solar',
#   'going',
#   'analysts',
#   '2040',
#   'fuel',
#   'technology',
#   'big',
#   'plans'],
#  ['hydrogen',
#   'fuel',
#   'cell',
#   ' ',
#   'cars',
#   'China',
#   'year',
#   'subsidies',
#   'package',
#   'reports',
#   'support',
#   'car',
#   'Reuters',
#   'official',
#   'vehicles',
#   'future',
#   'energy',
#   'plan',
#   'Beijing',
#   'end',
#   'finance'],
#  ['energy',
#   ' ',
#   'distributed',
#   'systems',
#   'management',
#   'solar',
#   'resources',
#   'power',
#   'software',
#   'grid',
#   'generation',
#   'Wood',
#   'DERMS',
#   'demand',
#   'supply',
#   'vision',
#   'future',
#   'renewable',
#   'increasingly',
#   'facilities',
#   'according'],
#  [' ',
#   'prices',
#   'oil',
#   'low',
#   'energy',
#   'electricity',
#   'coal',
#   'Figure',
#   'supply',
#   'economy',
#   '   ',
#   'solar',
#   'world',
#   'production',
#   'wind',
#   'World',
#   'Prices',
#   'use',
#   'like',
#   'Energy',
#   'humans'],
#  ['solar',
#   'panels',
#   ' ',
#   'anti',
#   'energy',
#   'electricity',
#   'heat',
#   'produce',
#   'work',
#   'new',
#   'generate',
#   'cooling',
#   'power',
#   'Munday',
#   'sun',
#   'panel',
#   'turn',
#   'night',
#   'radiated',
#   'generator',
#   'potential'],
#  ['carbon',
#   ' ',
#   'hydrogen',
#   'fuel',
#   'biofuel',
#   'aviation',
#   'energy',
#   'ammonia',
#   'neutral',
#   'new',
#   'solution',
#   'electric',
#   'planes',
#   'jet',
#   'density',
#   'plane',
#   'flight',
#   'industry',
#   '2',
#   'percent',
#   'emissions'],
#  [' ',
#   'Taiwan',
#   'renewable',
#   'Apple',
#   'tech',
#   'suppliers',
#   'energy',
#   'deal',
#   'leading',
#   'power',
#   'carbon',
#   'neutral',
#   'push',
#   'giant',
#   '$',
#   'green',
#   'goal',
#   'facilities',
#   'supply',
#   'corporate',
#   'Orsted'],
#  ['percent',
#   'energy',
#   ' ',
#   'oil',
#   'gas',
#   'share',
#   'total',
#   'supply',
#   'wind',
#   '2018',
#   'renewables',
#   'accounted',
#   'solar',
#   'consumption',
#   'mix',
#   'fossil',
#   '1973',
#   'years',
#   'lot',
#   '45',
#   'accounting'],
#  ['hydrogen',
#   ' ',
#   'gas',
#   '$',
#   'project',
#   'cost',
#   'fuel',
#   'natural',
#   'export',
#   'FCEVs',
#   'decade',
#   '40',
#   'solar',
#   'energy',
#   'economy',
#   'like',
#   'Kalbarri',
#   'blend',
#   'years',
#   'steel',
#   'California'],
#  ['wind',
#   ' ',
#   'energy',
#   'renewable',
#   'birds',
#   'deaths',
#   'turbines',
#   'problems',
#   'industry',
#   'U.S.',
#   'bird',
#   'test',
#   'group',
#   'black',
#   'issues',
#   'recently',
#   'clean',
#   'solar',
#   'plants',
#   'farms',
#   'single'],
#  ['solar',
#   ' ',
#   'land',
#   'crops',
#   'modules',
#   'farmland',
#   'projects',
#   'use',
#   'farm',
#   'energy',
#   'agricultural',
#   'dual',
#   'agroPV',
#   'AgroPV',
#   'power',
#   'installations',
#   'choice',
#   'United',
#   'States',
#   'shown',
#   'farmers'],
#  ['hydrogen',
#   ' ',
#   'projects',
#   'energy',
#   'carbon',
#   'fuel',
#   'industry',
#   'scale',
#   'heavy',
#   'new',
#   'technologies',
#   'low',
#   'storage',
#   'large',
#   'markets',
#   'million',
#   'cell',
#   'duty',
#   'rdquo',
#   'says',
#   'national'],
#  [' ',
#   'power',
#   'energy',
#   'California',
#   'grid',
#   'renewable',
#   'Californiarsquos',
#   'solar',
#   'outages',
#   'rdquo',
#   'said',
#   'reliability',
#   'demand',
#   'supply',
#   'warning',
#   'peak',
#   'issues',
#   'system',
#   'generation',
#   'ndash',
#   'blame'],
#  [' ',
#   'EVs',
#   'EV',
#   'sales',
#   'drivers',
#   'electric',
#   'vehicles',
#   'cars',
#   'power',
#   'people',
#   'percent',
#   'million',
#   'vision',
#   'Xcel',
#   'Energy',
#   'communities',
#   'customers',
#   'costs',
#   'report',
#   'U.S.',
#   'utility'],
#  ['U.S.',
#   ' ',
#   'energy',
#   'China',
#   'oil',
#   'minerals',
#   'fossil',
#   'climate',
#   'clean',
#   'REE',
#   'Biden',
#   '$',
#   'achieve',
#   'independence',
#   'United',
#   'States',
#   'shift',
#   '2019',
#   'imports',
#   'trillion',
#   'true'],
#  [' ',
#   'Cornish',
#   'geothermal',
#   'lithium',
#   'Lithium',
#   'plant',
#   'Cornwall',
#   'waters',
#   'pilot',
#   'Geothermal',
#   'Engineering',
#   'GEL',
#   'deep',
#   'environmentally',
#   'technology',
#   'technologies',
#   'rdquo',
#   'said',
#   'injection',
#   'resources',
#   'extraction'],
#  ['energy',
#   'economy',
#   'U.S.',
#   ' ',
#   'jobs',
#   'United',
#   'green',
#   'world',
#   'global',
#   'States',
#   'COVID-19',
#   'decarbonization',
#   'Vox',
#   'decarbonize',
#   'carbon',
#   'new',
#   'rapid',
#   'electrification',
#   'million',
#   'demand',
#   'fossil'],
#  [' ',
#   'power',
#   'wind',
#   'percent',
#   'energy',
#   'solar',
#   'costs',
#   'world',
#   'generation',
#   'sources',
#   'said',
#   'renewable',
#   'renewables',
#   'climate',
#   'modern',
#   'According',
#   'people',
#   'industrial',
#   'nbsp',
#   'change',
#   'Carbon'],
#  ['hydrogen',
#   'green',
#   ' ',
#   'energy',
#   'gas',
#   'sector',
#   'rdquo',
#   'oil',
#   'major',
#   'utilities',
#   'future',
#   'created',
#   'production',
#   'fossil',
#   'renewable',
#   'Iberdrola',
#   'Uniper',
#   'Greentech',
#   'need',
#   'U.S.',
#   'electrolyzer'],
#  ['hydrogen',
#   ' ',
#   'EU',
#   'economy',
#   'Germany',
#   'industry',
#   'production',
#   'policies',
#   'companies',
#   'industrial',
#   'strategy',
#   'solar',
#   'situation',
#   'concerning',
#   'emissions',
#   'China',
#   'market',
#   'success',
#   'strong',
#   'European',
#   'Beijing'],
#  [' ',
#   'subsidies',
#   '$',
#   'billion',
#   'renewable',
#   'solar',
#   'government',
#   'wind',
#   'power',
#   'EVs',
#   'year',
#   'hydrogen',
#   'energy',
#   'Germany',
#   'euro',
#   'generous',
#   'capacity',
#   'China',
#   'plans',
#   'cheaper',
#   'electric'],
#  ['geothermal',
#   ' ',
#   'oil',
#   'gas',
#   'energy',
#   'industry',
#   'heat',
#   'time',
#   'challenges',
#   'extraction',
#   'money',
#   'Waters',
#   'new',
#   'technologies',
#   'best',
#   'technology',
#   'right',
#   'business',
#   'way',
#   'system',
#   'need'],
#  ['panels',
#   'solar',
#   ' ',
#   'panel',
#   'years',
#   'capacity',
#   'recycling',
#   'waste',
#   'life',
#   'year',
#   'end',
#   'toxic',
#   '20',
#   'million',
#   'tons',
#   'Solar',
#   'kW',
#   'instance',
#   'installation',
#   'smaller',
#   'need'],
#  ['hydrogen',
#   ' ',
#   'energy',
#   'strategy',
#   'new',
#   'Hydrogen',
#   '2030',
#   'EU',
#   'system',
#   'GW',
#   'European',
#   'capacity',
#   'industry',
#   'carbon',
#   'renewable',
#   'market',
#   'production',
#   '40',
#   'EUrsquos',
#   'Strategy',
#   'target'],
#  [' ',
#   'dams',
#   'hydropower',
#   'projects',
#   'electricity',
#   'Chinese',
#   'GW',
#   'dam',
#   'Chinarsquos',
#   'massive',
#   'world',
#   'abroad',
#   'capacity',
#   'production',
#   'large',
#   'investments',
#   'producing',
#   'power',
#   '   ',
#   'construction',
#   'China'],
#  ['hydrogen',
#   ' ',
#   'gas',
#   'government',
#   'fuel',
#   'Russiarsquos',
#   'Gazprom',
#   'start',
#   '2024',
#   'plan',
#   'year',
#   'energy',
#   'global',
#   'beginning',
#   'develop',
#   'largest',
#   'road',
#   'map',
#   'oil',
#   'exporters',
#   'projects'],
#  ['hydrogen',
#   ' ',
#   'waste',
#   'cost',
#   'production',
#   'solar',
#   'wind',
#   'produced',
#   'electrolysis',
#   'negative',
#   'green',
#   'energy',
#   'natural',
#   'gas',
#   'called',
#   'feedstock',
#   'company',
#   'carbon',
#   'fuel',
#   'recently',
#   'plans'],
#  ['biofuels',
#   'energy',
#   'biofuel',
#   ' ',
#   'percent',
#   'future',
#   'green',
#   'global',
#   'fuel',
#   'world',
#   'consumption',
#   'economic',
#   'new',
#   'commercial',
#   'decade',
#   'Bloomberg',
#   'Green',
#   'oil',
#   'prices',
#   'renewable',
#   'havenrsquot'],
#  [' ',
#   'hydrogen',
#   'carbon',
#   'power',
#   'footprint',
#   'electrolysis',
#   'electricity',
#   'produced',
#   'production',
#   'produce',
#   'low',
#   'nuclear',
#   'dioxide',
#   'natural',
#   'gas',
#   'use',
#   'lower',
#   'water',
#   'energy',
#   'solar',
#   'source'],
#  ['hydrogen',
#   ' ',
#   'gas',
#   'green',
#   'natural',
#   'EU',
#   'produced',
#   'energy',
#   'industries',
#   'European',
#   'blue',
#   'sector',
#   'gigawatts',
#   'companies',
#   'currently',
#   'grey',
#   'decades',
#   'economy',
#   'countries',
#   'big',
#   'build'],
#  ['wind',
#   'power',
#   ' ',
#   'energy',
#   'new',
#   'year',
#   'capacity',
#   'electricity',
#   'according',
#   'solar',
#   'businesses',
#   'cost',
#   'percent',
#   'generation',
#   'renewable',
#   'Golden',
#   'half',
#   'companies',
#   'offshore',
#   'GW',
#   'Wind'],
#  [' ',
#   'hydrogen',
#   'fund',
#   'energy',
#   'clean',
#   'investment',
#   'fuel',
#   'power',
#   'Shell',
#   'executive',
#   'manager',
#   'Exxon',
#   'pandemic',
#   'Traynor',
#   'dollars',
#   'multiple',
#   'including',
#   'European',
#   'climate',
#   'decades',
#   'market'],
#  ['battery',
#   ' ',
#   'batteries',
#   'lithium',
#   'ion',
#   'production',
#   'safety',
#   'resin',
#   'mass',
#   'fire',
#   'APB',
#   'metal',
#   'material',
#   'instead',
#   'complex',
#   'process',
#   'undergo',
#   'fires',
#   'truck',
#   'raised',
#   'power'],
#  ['geothermal',
#   ' ',
#   'oil',
#   'energy',
#   'heat',
#   'gas',
#   'drilling',
#   'industry',
#   'drill',
#   'clean',
#   'extraction',
#   'solar',
#   'wind',
#   'deep',
#   'systems',
#   'system',
#   'Cook',
#   'costs',
#   'Oilprice.com',
#   'Geothermal',
#   'Earthrsquos'],
#  ['algae',
#   ' ',
#   'Exxon',
#   'biofuels',
#   'oil',
#   'biofuel',
#   '$',
#   'company',
#   'products',
#   'fuel',
#   'decade',
#   'Oil',
#   'BP',
#   'energy',
#   'later',
#   'dream',
#   'big',
#   'entered',
#   'M',
#   'barrels',
#   'compete'],
#  ['hydrogen',
#   ' ',
#   'strategy',
#   'production',
#   'EU',
#   'energy',
#   'Europersquos',
#   'leaked',
#   'European',
#   'important',
#   'ambitious',
#   'Europe',
#   'produced',
#   'electrolysis',
#   'ECrsquos',
#   'security',
#   'plan',
#   'Currently',
#   'needs',
#   'lsquogreenrsquo',
#   'billion'],
#  [' ',
#   'energy',
#   'California',
#   'forests',
#   'trees',
#   'biomass',
#   'dead',
#   'biofuel',
#   'Yale',
#   'million',
#   'projects',
#   'sector',
#   'like',
#   'economic',
#   'debate',
#   'burned',
#   'burn',
#   'devastating',
#   'climate',
#   'change',
#   'production'],
#  [' ',
#   'fossil',
#   'carbon',
#   'fuel',
#   'industry',
#   'emissions',
#   '2050',
#   'environmental',
#   'zero',
#   'years',
#   'CO2',
#   'investors',
#   'date',
#   'like',
#   'thirty',
#   'offset',
#   'certain',
#   'offsets',
#   'climate',
#   'energy',
#   'asset'],
#  ['energy',
#   'Tesla',
#   'solar',
#   ' ',
#   'Teslarsquos',
#   'average',
#   'Energy',
#   'system',
#   'new',
#   'panel',
#   'Musk',
#   'sustainable',
#   'electric',
#   'systems',
#   '$',
#   'year',
#   'EV',
#   'Electrek',
#   'reported',
#   'according',
#   'companyrsquos'],
#  [' ',
#   'energy',
#   'climate',
#   'global',
#   'United',
#   'change',
#   'agencies',
#   'opportunity',
#   'carbon',
#   'emissions',
#   'industry',
#   'World',
#   'NPR',
#   'international',
#   'States',
#   'Green',
#   'proposal',
#   'week',
#   'reported',
#   'case',
#   'data'],
#  [' ',
#   'plan',
#   'global',
#   'energy',
#   'IEA',
#   'economic',
#   'years',
#   'analysis',
#   'growth',
#   'year',
#   'jobs',
#   'investments',
#   'According',
#   'IMFrsquos',
#   'boost',
#   '1.1',
#   'percentage',
#   'points',
#   'save',
#   'create',
#   '9'],
#  [' ',
#   'energy',
#   'renewable',
#   'oil',
#   'renewables',
#   'investment',
#   'term',
#   'crisis',
#   'green',
#   'global',
#   'industry',
#   'fossil',
#   'capacity',
#   'demand',
#   'new',
#   'percent',
#   'ndash',
#   'clean',
#   'including',
#   '2019',
#   'Energy'],
#  ['hydrogen',
#   ' ',
#   'fuel',
#   'gas',
#   'energy',
#   'natural',
#   'Hydrogen',
#   'countries',
#   'cell',
#   'FCEVs',
#   'carbon',
#   'global',
#   'powered',
#   'like',
#   'IHS',
#   'Markit',
#   'Germany',
#   '2030',
#   'produced',
#   'industry',
#   'YTD'],
#  ['carbon',
#   'dioxide',
#   ' ',
#   'gas',
#   'CO2',
#   'use',
#   'emissions',
#   'device',
#   'way',
#   'fuel',
#   'problem',
#   'chemicals',
#   'capture',
#   'released',
#   'air',
#   'solution',
#   'University',
#   'solar',
#   'convert',
#   'layer',
#   'energy'],
#  [' ',
#   'MW',
#   'solar',
#   'report',
#   'power',
#   'capacity',
#   'COVID-19',
#   'new',
#   '2020',
#   'March',
#   'projects',
#   'Indian',
#   'India',
#   'quarter',
#   'total',
#   'energy',
#   'Q1',
#   'government',
#   'tenders',
#   'added',
#   'Energy'],
#  ['battery',
#   ' ',
#   'cathode',
#   'Roskill',
#   'states',
#   'lithium',
#   'ion',
#   'demand',
#   'expected',
#   'materials',
#   'market',
#   'technologies',
#   'report',
#   '20zwnj29',
#   'rdquo',
#   'document',
#   'automotive',
#   'dominant',
#   'share',
#   'analyst',
#   'Li'],
#  ['batteries',
#   ' ',
#   'sodium',
#   'lithium',
#   'ion',
#   'battery',
#   'cobalt',
#   'capacity',
#   'cathode',
#   'Sodium',
#   'technology',
#   'previous',
#   'electrolyte',
#   'interaction',
#   'viable',
# ...
#  ['energy',
#   'renewable',
#   'Germany',
#   'electricity',
#   'percent',
#   'generators',
#   'Chabot',
#   'wind',
#   'conventional',
#   'sources',
#   'power',
#   'coal',
#   'solar',
#   'according',
#   'generated',
#   'renewables',
#   'abundance',
#   '11',
#   'cost',
#   'hour',
#   'Germanyrsquos'],
#  ['energy',
#   '$',
#   'value',
#   'P',
#   'E',
#   'losses',
#   'potential',
#   'day',
#   'companies',
#   'doesnrsquot',
#   'solar',
#   'Solar',
#   'position',
#   'look',
#   'FSLR',
#   'alternative',
#   'hard',
#   'cheap',
#   'buy',
#   'market',
#   'forward'],
#  ['Africa',
#   'Energy',
#   'energy',
#   'U.S.',
#   'power',
#   'solar',
#   'South',
#   'percent',
#   'Power',
#   'Saharan',
#   'electricity',
#   'Africarsquos',
#   'potential',
#   'African',
#   'Renewable',
#   'sub',
#   'economic',
#   'investment',
#   'Droogfontein',
#   'development',
#   'PPD'],
#  ['energy',
#   'electricity',
#   'power',
#   'renewable',
#   'percent',
#   'solar',
#   'Germany',
#   'Germanyrsquos',
#   'mdash',
#   'renewables',
#   'demand',
#   'countryrsquos',
#   'prices',
#   'continued',
#   'year',
#   'rdquo',
#   'supply',
#   'country',
#   'PV',
#   'fact',
#   'retail'],
#  ['FAS',
#   'Energy',
#   'solar',
#   'Nigeria',
#   'Delta',
#   'State',
#   'energy',
#   'SkyPower',
#   'power',
#   'initiative',
#   'U.S.',
#   'renewable',
#   'Nigeriarsquos',
#   'state',
#   'Federal',
#   'Government',
#   'Foreign',
#   'Saudi',
#   'clean',
#   'companies',
#   'said'],
#  ['solar',
#   'Solar',
#   'SolarCity',
#   '$',
#   'costs',
#   'energy',
#   'year',
#   'industry',
#   'ndash',
#   'power',
#   'growth',
#   'megawatts',
#   'panels',
#   'share',
#   'million',
#   'company',
#   'like',
#   'years',
#   'capacity',
#   'cost',
#   'use'],
#  ['solar',
#   'site',
#   'Superfund',
#   'project',
#   'farm',
#   'energy',
#   'power',
#   'renewable',
#   'sites',
#   'landfill',
#   'EPA',
#   'landfills',
#   'land',
#   'Maywood',
#   'Solar',
#   'panels',
#   'mining',
#   'area',
#   'polluted',
#   'mdash',
#   'wind'],
#  ['Plug',
#   'PLUG',
#   'stock',
#   'short',
#   'company',
#   'ReliOn',
#   'cell',
#   'Power',
#   'end',
#   'Wal',
#   'year',
#   '$',
#   'volatility',
#   'interest',
#   'million',
#   'news',
#   'issuing',
#   'case',
#   'weeks',
#   'fuel',
#   'stocks'],
#  ['energy',
#   'wind',
#   'electricity',
#   'said',
#   'percent',
#   'global',
#   'sector',
#   'United',
#   'States',
#   'renewable',
#   'IPCC',
#   'Wind',
#   'generated',
#   'IKEA',
#   '2013',
#   '$',
#   'business',
#   'U.S.',
#   'emissions',
#   'capacity',
#   'onshore'],
#  ['waveguide',
#   'light',
#   'taper',
#   'tapers',
#   'absorb',
#   'multilayered',
#   'energy',
#   'cells',
#   'array',
#   'infrared',
#   'technology',
#   'solar',
#   'thermal',
#   'PhD',
#   'thin',
#   'film',
#   'wavelengths',
#   'new',
#   'stealth',
#   'waste',
#   'different'],
#  ['energy',
#   'renewable',
#   'report',
#   'Greenpeace',
#   'Amazon',
#   'Twitter',
#   'commitment',
#   'data',
#   'Internet',
#   'traffic',
#   'Inc.',
#   'companies',
#   'given',
#   'transparency',
#   'company',
#   'efficiency',
#   'said',
#   'powered',
#   'dirty',
#   'use',
#   'centers'],
#  ['Indonesia',
#   'energy',
#   'Indonesiarsquos',
#   'China',
#   'maritime',
#   'Indonesian',
#   'Sea',
#   'oil',
#   'production',
#   'world',
#   'renewable',
#   'domestic',
#   'populous',
#   'country',
#   'islands',
#   'percent',
#   'foreign',
#   'land',
#   'area',
#   'continue',
#   'South'],
#  ['power',
#   'geothermal',
#   'country',
#   'Japanrsquos',
#   'years',
#   'energy',
#   'nuclear',
#   'hot',
#   'generation',
#   'Fukushima',
#   'Electric',
#   'new',
#   'reactors',
#   'natural',
#   'springs',
#   'plants',
#   'Japan',
#   'Chuo',
#   'countryrsquos',
#   'project',
#   'plant'],
#  ['solar',
#   'utility',
#   'utilities',
#   'homes',
#   'electricity',
#   'needed',
#   'industry',
#   'electric',
#   'power',
#   'sun',
#   'said',
#   'technology',
#   'dream',
#   'Energy',
#   'market',
#   'generation',
#   'grid',
#   'big',
#   'profit',
#   'disruptive',
#   'rooftop'],
#  ['life',
#   'Earth',
#   'electrical',
#   'geological',
#   'energy',
#   'biological',
#   'early',
#   'rdquo',
#   'hydrothermal',
#   'minerals',
#   'fuel',
#   'processes',
#   'cell',
#   'says',
#   'Leeds',
#   'vents',
#   'cells',
#   'reactions',
#   'simulate',
#   'emergence',
#   'metabolism'],
#  ['power',
#   'storage',
#   'battery',
#   'batteries',
#   'solar',
#   'Japan',
#   'energy',
#   'large',
#   'renewable',
#   'scale',
#   'megawatt',
#   'Sumitomo',
#   'nuclear',
#   'system',
#   'electric',
#   'Corp.',
#   'EV',
#   'Nissan',
#   'project',
#   'systems',
#   'installed'],
#  ['hydrogen',
#   'fuel',
#   'vehicle',
#   'Birmingham',
#   'City',
#   'University',
#   'cell',
#   'Spencer',
#   'Ashley',
#   'India',
#   'Hydrogen',
#   'vehicles',
#   'Tuk',
#   'power',
#   'UK',
#   'manufacturer',
#   'DYPDC',
#   'research',
#   'set',
#   'concept',
#   'design'],
#  ['power',
#   'geothermal',
#   'Japan',
#   'nuclear',
#   'energy',
#   'Japanrsquos',
#   'largest',
#   'Fukushima',
#   'Daiichi',
#   'generation',
#   'sources',
#   'plant',
#   'Icelandrsquos',
#   '2011',
#   'country',
#   'reactors',
#   'remains',
#   'Iceland',
#   'world',
#   'global',
#   'LNG'],
#  ['geothermal',
#   'energy',
#   'power',
#   'Iceland',
#   'Icelandic',
#   'IDDP-1',
#   'magma',
#   'Icelandrsquos',
#   'Krafla',
#   'project',
#   'high',
#   'borehole',
#   'temperatures',
#   'Centigrade',
#   'heat',
#   'megawatt',
#   'plant',
#   'percent',
#   'IDDP',
#   'National',
#   'Energy'],
#  ['ethanol',
#   'corn',
#   'mandate',
#   'billion',
#   'biofuels',
#   'gallons',
#   'industry',
#   'letter',
#   'proposed',
#   'cuts',
#   'environmental',
#   'EPA',
#   'food',
#   'pressure',
#   'restaurant',
#   'chains',
#   'proposal',
#   'reduce',
#   'groups',
#   'NCCR',
#   'lawmakers'],
#  ['Aquion',
#   'battery',
#   'Energy',
#   'power',
#   'grid',
#   'batteries',
#   'energy',
#   'cost',
#   'Gates',
#   'lithium',
#   'storage',
#   'technology',
#   'market',
#   '$',
#   'scale',
#   'water',
#   'ion',
#   'low',
#   'renewable',
#   'like',
#   'Siemens'],
#  ['electricity',
#   'solar',
#   'intermittent',
#   'energy',
#   'renewables',
#   'wind',
#   'PV',
#   'fuel',
#   'costs',
#   'oil',
#   'high',
#   'world',
#   'need',
#   'fossil',
#   'problem',
#   'use',
#   'cost',
#   'emissions',
#   'CO2',
#   'Energy',
#   'grid'],
#  ['energy',
#   'report',
#   'clean',
#   'recommendations',
#   'President',
#   'gas',
#   'new',
#   'bullnbspnbsp',
#   'CNEE',
#   'Ritterrsquos',
#   'natural',
#   'grid',
#   'fuels',
#   'calls',
#   'White',
#   'House',
#   'group',
#   'released',
#   'action',
#   'need',
#   'Ritter'],
#  ['battery',
#   'flow',
#   'energy',
#   'batteries',
#   'based',
#   'metal',
#   'power',
#   'storage',
#   'store',
#   'Harvard',
#   'scale',
#   'Michael',
#   'molecules',
#   'technology',
#   'team',
#   'free',
#   'large',
#   'Professor',
#   'renewable',
#   'output',
#   'research'],
#  ['ethanol',
#   'production',
#   'fuel',
#   'RFS',
#   'Iowa',
#   'mandate',
#   'Renewable',
#   'corn',
#   'biofuels',
#   'billion',
#   'gallons',
#   'demand',
#   'like',
#   'new',
#   'producers',
#   'year',
#   'renewable',
#   'Fuel',
#   '2014',
#   'gas',
#   'rising'],
#  ['wind',
#   'energy',
#   'Maryland',
#   'tax',
#   'future',
#   'sector',
#   'year',
#   'offshore',
#   'credit',
#   'auction',
#   'development',
#   '2013',
#   '$',
#   'million',
#   'industry',
#   'faces',
#   'uncertain',
#   'renewable',
#   'said',
#   'power',
#   'fossil'],
#  ['utilities',
#   'generation',
#   'energy',
#   'electricity',
#   'report',
#   'distributed',
#   'ndash',
#   'solar',
#   'power',
#   'Energy',
#   'new',
#   'UBS',
#   'utility',
#   'model',
#   'U.S.',
#   'rdquo',
#   'customers',
#   'demand',
#   'latest',
#   'finds',
#   'renewable'],
#  ['crude',
#   'green',
#   'algae',
#   'Sapphire',
#   'oil',
#   'said',
#   'Phillips',
#   '66',
#   'deal',
#   'fuels',
#   'Energy',
#   'based',
#   'develop',
#   'new',
#   'barrels',
#   'commercial',
#   'alternative',
#   'million',
#   'production',
#   '2025',
#   'work'],
#  ['said',
#   'Chinese',
#   'government',
#   'energy',
#   'climate',
#   'change',
#   'world',
#   'renewable',
#   'Energy',
#   'power',
#   'gigawatts',
#   'year',
#   'work',
#   'China',
#   'economy',
#   'future',
#   'development',
#   'major',
#   'security',
#   'report',
#   'weak'],
#  ['climate',
#   'Australia',
#   'Tasmania',
#   'largest',
#   'coal',
#   'government',
#   'change',
#   'emissions',
#   'energy',
#   'Australiarsquos',
#   'Australian',
#   'Abbott',
#   'Climate',
#   'Change',
#   'electricity',
#   'Energy',
#   'uranium',
#   'world',
#   'exporter',
#   'fourth',
#   'year'],
#  ['mandate',
#   'order',
#   'energy',
#   'federal',
#   'agencies',
#   'executive',
#   'renewable',
#   'clean',
#   'Obama',
#   'President',
#   'use',
#   'sources',
#   '2020',
#   'electricity',
#   '2005',
#   'renewables',
#   'economy',
#   'EDF',
#   'cost',
#   'technologies',
#   'support'],
#  ['biofuels',
#   'Bauen',
#   'industry',
#   'Roadmap',
#   'transport',
#   'based',
#   '2030',
#   'fuel',
#   'target',
#   'biodiesel',
#   'EU',
#   'gas',
#   '2020',
#   'road',
#   'vision',
#   'land',
#   'ILUC',
#   'E4tech',
#   'European',
#   'time',
#   'policy'],
#  ['algae',
#   'production',
#   'biofuel',
#   'growth',
#   'researchers',
#   'Scripps',
#   'fuel',
#   'lipids',
#   'increase',
#   'said',
#   'research',
#   'future',
#   'marine',
#   'fat',
#   'implications',
#   'San',
#   'specific',
#   'inside',
#   'diatoms',
#   'engineering',
#   'potential'],
#  ['billion',
#   'gallons',
#   'biofuels',
#   'cut',
#   'gas',
#   'demand',
#   'like',
#   'lobbying',
#   'proposed',
#   '2014',
#   'renewable',
#   'fuel',
#   'RFS',
#   'corn',
#   'months',
#   'mandate',
#   '15.21',
#   'set',
#   'year',
#   'targets',
#   '2007'],
#  ['government',
#   'energy',
#   'protests',
#   'nuclear',
#   'mass',
#   'power',
#   'environmental',
#   'fossil',
#   'climate',
#   'like',
#   'governments',
#   'change',
#   'people',
#   'Fukushima',
#   'reactors',
#   'Chinese',
#   'reliance',
#   'protest',
#   'police',
#   'city',
#   'rdquo'],
#  ['kites',
#   'electricity',
#   'potential',
#   'power',
#   'ocean',
#   'Olinger',
#   'Professor',
#   'currents',
#   'tidal',
#   'flows',
#   'Gulf',
#   'million',
#   'underwater',
#   'turbines',
#   'generate',
#   'technology',
#   'research',
#   'energy',
#   'moving',
#   'Florida',
#   'scale'],
#  ['solar',
#   'material',
#   'materials',
#   'light',
#   'bandgap',
#   'energy',
#   'visible',
#   'catch',
#   'cells',
#   'rdquo',
#   'photovoltaic',
#   'crystal',
#   'says',
#   'effect',
#   'polar',
#   'structure',
#   'photons',
#   'direction',
#   'bulk',
#   'limit',
#   'new'],
#  ['geothermal',
#   'energy',
#   'power',
#   'Hawaii',
#   'use',
#   'megawatts',
#   'renewable',
#   'U.S.',
#   'H2S',
#   'wind',
#   'electricity',
#   'Energy',
#   'Puna',
#   'ndash',
#   'doesnrsquot',
#   'resources',
#   'percent',
#   'states',
#   'people',
#   'renewables',
#   'solar'],
#  ['energy',
#   'exemptions',
#   'government',
#   'companies',
#   'renewable',
#   'electricity',
#   'consumers',
#   'Germany',
#   'year',
#   'EU',
#   'Energy',
#   'German',
#   'cut',
#   'average',
#   'emissions',
#   'renewables',
#   'surcharges',
#   'prices',
#   'cost',
#   'subsidies',
#   'intensive'],
#  ['biodiesel',
#   'Brazil',
#   'increase',
#   '7',
#   'billion',
#   'requirements',
#   'blend',
#   'diesel',
#   'year',
#   'liters',
#   'mandate',
#   '10',
#   '2020',
#   'rate',
#   '2013',
#   'production',
#   'new',
#   'plants',
#   '5',
#   'January',
#   '2014'],
#  ['beetle',
#   'trees',
#   'biomass',
#   'research',
#   'bark',
#   'potential',
#   'wood',
#   'environmental',
#   'killed',
#   'acres',
#   'high',
#   'Agriculture',
#   'USDA',
#   'million',
#   'infestations',
#   'forest',
#   'Related',
#   'article',
#   'rdquo',
#   'benefits',
#   'conversion'],
#  ['Argentina',
#   'US$',
#   'Repsol',
#   'Argentine',
#   'duties',
#   'bio',
#   'diesel',
#   '2013',
#   'billion',
#   'trade',
#   'European',
#   'Union',
#   'YPF',
#   'higher',
#   'cost',
#   'industry',
#   'EU',
#   'decision',
#   'current',
#   'Argentinarsquos',
#   '2012'],
#  ['mold',
#   'research',
#   'fuel',
#   'crassa',
#   'plant',
#   'genetic',
#   'studies',
#   '$',
#   '1.3',
#   'million',
#   'turning',
#   'conduct',
#   'DNA',
#   'sequencing',
#   'strains',
#   'Neurospora',
#   'model',
#   'new',
#   'break',
#   'complex',
#   'grows'],
#  ['straw',
#   'million',
#   'energy',
#   'researchers',
#   'Germany',
#   'power',
#   '2.8',
#   'biomass',
#   'applications',
#   'provide',
#   'homes',
#   'heat',
#   '4.5',
#   'gold',
#   'waste',
#   '30',
#   'tons',
#   'cereal',
#   'produced',
#   'annually',
#   'fuel'],
#  ['energy',
#   'Walmart',
#   'renewable',
#   'solar',
#   'Walmartrsquos',
#   'position',
#   'key',
#   'makes',
#   'clean',
#   'status',
#   'adoption',
#   'leader',
#   'power',
#   'Related',
#   'article',
#   'work',
#   'ambitious',
#   'goal',
#   '100',
#   'powering',
#   'American'],
#  ['proposal',
#   'EU',
#   'new',
#   'policy',
#   'limit',
#   'use',
#   'based',
#   'fuel',
#   'crops',
#   'transport',
#   'vote',
#   'ILUC',
#   'year',
#   'destroy',
#   'European',
#   'Parliamentrsquos',
#   'food',
#   'LePage',
#   '6',
#   'share',
#   '2020'],
#  ['charging',
#   'manhole',
#   'electric',
#   'vehicle',
#   'car',
#   'HEVO',
#   'wireless',
#   'charge',
#   'year',
#   'company',
#   'cover',
#   'New',
#   'York',
#   'Power',
#   'gets',
#   'early',
#   'big',
#   'runs',
#   'technology',
#   'system',
#   'provides'],
#  ['solar',
#   'light',
#   'heat',
#   'temperatures',
#   'F',
#   'rdquo',
#   'emitters',
#   'cell',
#   'infrared',
#   'thermal',
#   'ceramic',
#   'says',
#   'Fan',
#   'Illinois',
#   'energy',
#   'Braun',
#   'component',
#   'efficiency',
#   'thermophotovoltaics',
#   'emitter',
#   'coated'],
#  ['Lockheed',
#   'Martin',
#   'waste',
#   'Concord',
#   'Blue',
#   'technology',
#   'energy',
#   'fuel',
#   'generate',
#   'deal',
#   'uses',
#   'heat',
#   'environmental',
#   'management',
#   'commercial',
#   'proven',
#   'complex',
#   'project',
#   'global',
#   'facilities',
#   'said'],
#  ['Scotland',
#   'energy',
#   'renewable',
#   'Scotlandrsquos',
#   'tidal',
#   'world',
#   'Scottish',
#   'renewables',
#   'ndash',
#   'carbon',
#   'year',
#   'electricity',
#   'industry',
#   'economic',
#   'development',
#   'area',
#   '40',
#   'country',
#   'Energy',
#   'equivalent',
#   'percent'],
#  ['new',
#   'pathway',
#   'carbon',
#   'biofuel',
#   'increase',
#   'biofuels',
#   'production',
#   'bio',
#   'research',
#   'biomass',
#   'glycolysis',
#   'process',
#   'Biofuels',
#   'synthetic',
#   'metabolic',
#   'glucose',
#   '50',
#   'sources',
#   'ethanol',
#   'Related',
#   'article'],
#  ['geothermal',
#   'Ethiopian',
#   'power',
#   'Ethiopia',
#   'energy',
#   'project',
#   '$',
#   'Ethiopiarsquos',
#   'government',
#   'megawatt',
#   'Geothermal',
#   'currently',
#   'EEPCo',
#   'Corbetti',
#   'plant',
#   'plans',
#   'percent',
#   'electricity',
#   'potential',
#   'hydroelectric',
#   'Aluto'],
#  ['ethanol',
#   'API',
#   'mandate',
#   '2013',
#   'year',
#   'lawsuit',
#   'requirements',
#   'targets',
#   'billion',
#   'gallons',
#   'largest',
#   'challenging',
#   'bad',
#   'policy',
#   'unrealistic',
#   'blended',
#   'fuel',
#   'EPA',
#   'volume',
#   'cellulosic',
#   'biofuel'],
#  ['solar',
#   'panels',
#   'company',
#   'IKEA',
#   'UK',
#   'energy',
#   'Solar',
#   'sustainable',
#   'customers',
#   'buy',
#   'years',
#   'article',
#   'want',
#   'life',
#   'year',
#   'British',
#   'panel',
#   'owners',
#   'cents',
#   'market',
#   'products'],
#  ['Tesla',
#   'Teslarsquos',
#   'GM',
#   'Model',
#   'S',
#   'small',
#   '$',
#   'range',
#   'end',
#   'year',
#   'looking',
#   'vehicle',
#   'fire',
#   'Motors',
#   'whatrsquos',
#   'likely',
#   'different',
#   'stock',
#   'market',
#   'miles',
#   'new'],
#  ['energy',
#   'power',
#   'nuclear',
#   'largest',
#   'electricity',
#   'world',
#   'Merkel',
#   'renewable',
#   'Germany',
#   'Fukushima',
#   'plants',
#   'BDEW',
#   'subsidies',
#   'Europe',
#   '2011',
#   'government',
#   'produced',
#   'green',
#   'conventional',
#   'political',
#   'newsGermany'],
#  ['waste',
#   'Sweden',
#   'energy',
#   'garbage',
#   'million',
#   'tons',
#   'trash',
#   'countries',
#   'generate',
#   'feed',
#   'half',
#   'household',
#   'ends',
#   'Related',
#   'article',
#   'needs',
#   'heat',
#   'Swedenrsquos',
#   'incineration',
#   'homes',
#   'Norway'],
#  ['energy',
#   'eBay',
#   'Ormat',
#   'power',
#   'REG',
#   'heat',
#   'waste',
#   'data',
#   'new',
#   'plant',
#   'eBayrsquos',
#   'facility',
#   'Energy',
#   'operating',
#   'Utah',
#   'online',
#   'Israeli',
#   'renewable',
#   'firm',
#   'Technologies',
#   'capture'],
#  ['wind',
#   'farm',
#   'Wind',
#   'Tri',
#   'Global',
#   'Energy',
#   'years',
#   'turbines',
#   'Texas',
#   'permits',
#   'birds',
#   'project',
#   'said',
#   '85',
#   'died',
#   '1997',
#   'federal',
#   'government',
#   '1,100',
#   'largest',
#   'Related'],
#  ['corn',
#   'soil',
#   'stover',
#   'residue',
#   'fields',
#   'cellulosic',
#   'production',
#   'million',
#   'researchers',
#   'post',
#   'harvest',
#   'quality',
#   'ethanol',
#   'use',
#   'biofuels',
#   'biofuel',
#   'source',
#   'crop',
#   'harvested',
#   'protect',
#   'USDA'],
#  ['energy',
#   'Energy',
#   'SustainX',
#   'storage',
#   'power',
#   'system',
#   'air',
#   'ICAES',
#   'renewable',
#   'electricity',
#   'technology',
#   'Program',
#   'compressed',
#   'Partners',
#   'systems',
#   'cost',
#   'scale',
#   'promising',
#   'Office',
#   'Electricity',
#   'Delivery'],
#  ...]

# %%
corpus_crude_oil['content'] = corpus_crude_oil['content'].str.replace('"','')
corpus_crude_oil['content'] = corpus_crude_oil['content'].str.replace('&','')
corpus_crude_oil['content'] = corpus_crude_oil['content'].str.replace(';','')
col_one_list_3 = corpus_crude_oil['content'].tolist()

# %%
common_words_list_3 = []
for a in col_one_list_3:
    complete_doc = nlp(a)
    # Remove stop words and punctuation symbols
    words = [token.text for token in complete_doc
         if not token.is_stop and not token.is_punct]
    word_freq = Counter(words)
    # 5 commonly occurring words with their frequencies
    common_words = word_freq.most_common(21)
    # Unique words
    common_words_list_3.append(common_words)

# %%
common_words_list_edited_3 = []
for c in common_words_list_3:
    intermediary_list = []
    for a in c:
        a_edited = a[0]
        intermediary_list.append(a_edited)
    common_words_list_edited_3.append(intermediary_list)
common_words_list_edited_3
# Out:
# [['oil',
#   'prices',
#   'OPEC',
#   'Bidenrsquos',
#   'release',
#   'crude',
#   'markets',
#   'producers',
#   'plan',
#   'SPR',
#   'market',
#   'China',
#   'production',
#   'Saudi',
#   'demand',
#   'energy',
#   'U.S.',
#   'increase',
#   'push',
#   'price',
#   'strategy'],
#  [' ',
#   'OPEC',
#   'bpd',
#   'January',
#   '400,000',
#   'meeting',
#   'production',
#   'expected',
#   'group',
#   'cuts',
#   'policy',
#   'sources',
#   'said',
#   'Russia',
#   'need',
#   'oil',
#   'surplus',
#   'alliance',
#   'ministers',
#   'Bakr',
#   'Deputy'],
#  ['oil',
#   'UAErsquos',
#   'billion',
#   'UAE',
#   'US$',
#   'key',
#   'million',
#   'deal',
#   'Abu',
#   'Dhabi',
#   'ADNOC',
#   'crude',
#   'U.S.',
#   'ndash',
#   'Israel',
#   ' ',
#   'Murban',
#   'bpd',
#   'ICE',
#   'East',
#   'announced'],
#  ['oil',
#   ' ',
#   'release',
#   'crude',
#   'reserves',
#   'China',
#   'prices',
#   'said',
#   'Chinese',
#   'releasing',
#   'coordinated',
#   'Reuters',
#   'consuming',
#   'nations',
#   'major',
#   'strategic',
#   'state',
#   'according',
#   'country',
#   'actual',
#   'needs'],
#  ['million',
#   ' ',
#   'barrels',
#   'week',
#   'bpd',
#   'crude',
#   'draw',
#   '$',
#   'oil',
#   'inventories',
#   'previous',
#   'gasoline',
#   'EIA',
#   'reported',
#   'November',
#   '19',
#   'compared',
#   'production',
#   'data',
#   'release',
#   'trading'],
#  ['release',
#   'oil',
#   ' ',
#   'reserve',
#   'barrels',
#   'OPEC',
#   'crude',
#   'according',
#   'million',
#   'prices',
#   'strategic',
#   'large',
#   'China',
#   'Japan',
#   'week',
#   'supply',
#   'response',
#   'consumers',
#   'demand',
#   'reports',
#   'selloff'],
#  ['oil',
#   'ban',
#   'crude',
#   'exports',
#   ' ',
#   'House',
#   'U.S.',
#   'prices',
#   'White',
#   'Khanna',
#   'potential',
#   'Democratic',
#   'Bloomberg',
#   'higher',
#   'wrote',
#   'American',
#   'likely',
#   'production',
#   'mdash',
#   'global',
#   'supply'],
#  [' ',
#   'oil',
#   'release',
#   'million',
#   'barrels',
#   'SPR',
#   'coordinated',
#   'said',
#   'OPEC',
#   'Tuesday',
#   'prices',
#   'major',
#   'rdquo',
#   'production',
#   'President',
#   'Department',
#   'Energy',
#   '50',
#   'Strategic',
#   'Petroleum',
#   'Reserve'],
#  ['quarter',
#   '$',
#   'billion',
#   'peer',
#   'shale',
#   '2021',
#   'group',
#   ' ',
#   'reinvestment',
#   'yearrsquos',
#   'debt',
#   'oil',
#   'cash',
#   'year',
#   'Rystad',
#   'Energy',
#   'expected',
#   'capex',
#   'CFO',
#   'leverage',
#   'producers'],
#  ['oil',
#   ' ',
#   'prices',
#   'release',
#   'crude',
#   'reserves',
#   'Japan',
#   'India',
#   'consumers',
#   'United',
#   'States',
#   'reduce',
#   'strategic',
#   'Reuters',
#   'reserve',
#   'global',
#   'major',
#   'coordinated',
#   'effort',
#   'told',
#   'China'],
#  ['oil',
#   'gas',
#   'prices',
#   ' ',
#   '$',
#   'pump',
#   'average',
#   'production',
#   'Biden',
#   'U.S.',
#   'week',
#   'gasoline',
#   'energy',
#   'President',
#   'companies',
#   'station',
#   'year',
#   'global',
#   'pandemic',
#   'United',
#   'States'],
#  [' ',
#   'prices',
#   'gas',
#   'SPR',
#   'release',
#   'oil',
#   'crude',
#   'China',
#   'million',
#   'India',
#   'USD',
#   'time',
#   'market',
#   'w',
#   'November',
#   'According',
#   'Biden',
#   'price',
#   'bpd',
#   '$',
#   'month'],
#  [' ',
#   'oil',
#   'said',
#   'year',
#   'stocks',
#   'OECD',
#   'prices',
#   'build',
#   'barrels',
#   'stock',
#   'IEA',
#   'Crude',
#   '$',
#   'barrel',
#   'global',
#   'Energy',
#   'crude',
#   'million',
#   'October',
#   'September',
#   'set'],
#  [' ',
#   'oil',
#   'China',
#   'release',
#   'Reuters',
#   'crude',
#   'Biden',
#   'prices',
#   'strategic',
#   'National',
#   'Food',
#   'Strategic',
#   'Reserves',
#   'Administration',
#   'told',
#   'reserve',
#   'reported',
#   'citing',
#   'news',
#   'reports',
#   'President'],
#  ['oil',
#   ' ',
#   'Iraq',
#   'field',
#   'Oil',
#   'US$',
#   'barrel',
#   'development',
#   'contract',
#   'Chinese',
#   'rdquo',
#   'U.S.',
#   'develop',
#   'billion',
#   'international',
#   'construction',
#   'NIP',
#   'project',
#   'production',
#   'previous',
#   'Iraqrsquos'],
#  ['oil',
#   'supply',
#   'potential',
#   'price',
#   'breakeven',
#   '$',
#   'barrel',
#   'million',
#   'bpd',
#   'new',
#   'average',
#   ' ',
#   'tight',
#   '2014',
#   '2030',
#   '2018',
#   'offshore',
#   'cost',
#   'year',
#   'deepwater',
#   '100'],
#  ['million',
#   ' ',
#   'barrels',
#   'week',
#   'bpd',
#   'draw',
#   'compared',
#   'oil',
#   'prices',
#   'crude',
#   'average',
#   'previous',
#   'production',
#   'reported',
#   'inventory',
#   'year',
#   'time',
#   '$',
#   'barrel',
#   'Energy',
#   'November'],
#  [' ',
#   'oil',
#   'crude',
#   'China',
#   'Biden',
#   'release',
#   'reserves',
#   'prices',
#   'source',
#   'earlier',
#   'President',
#   'Xi',
#   'according',
#   'South',
#   'Morning',
#   'Post',
#   'month',
#   'price',
#   'auction',
#   'national',
#   'reserve'],
#  [' ',
#   'energy',
#   'oil',
#   'financial',
#   '$',
#   'capital',
#   'crisis',
#   'global',
#   'prices',
#   '2008',
#   'year',
#   '   ',
#   'investment',
#   'market',
#   'demand',
#   'companies',
#   'wind',
#   'carbon',
#   'petroleum',
#   'result',
#   'things'],
#  ['bpd',
#   'OPEC',
#   ' ',
#   'production',
#   'million',
#   'October',
#   'output',
#   'OPECrsquos',
#   'oil',
#   'percent',
#   'members',
#   'Saudi',
#   'group',
#   'monthly',
#   'September',
#   'complying',
#   'compliance',
#   'month',
#   'quotas',
#   'crude',
#   'fell'],
#  ['climate',
#   'countries',
#   ' ',
#   'nations',
#   'leaders',
#   'fossil',
#   'Africa',
#   'gas',
#   'developed',
#   'African',
#   'fuels',
#   'emissions',
#   'COP26',
#   'developing',
#   'greenhouse',
#   'change',
#   'itrsquos',
#   'pushed',
#   'poorer',
#   'development',
#   'coal'],
#  [' ',
#   'energy',
#   'Biden',
#   'U.S.',
#   'oil',
#   'administration',
#   'production',
#   'fossil',
#   'year',
#   'demand',
#   'prices',
#   'crunch',
#   'transition',
#   'Kerry',
#   'fuels',
#   'rise',
#   'planned',
#   'gas',
#   'supply',
#   'rising',
#   'lower'],
#  ['million',
#   ' ',
#   'barrels',
#   'week',
#   'middle',
#   'prices',
#   'oil',
#   'build',
#   'gasoline',
#   'production',
#   'bpd',
#   'previous',
#   'crude',
#   'inventories',
#   'distillate',
#   'fell',
#   'today',
#   'Energy',
#   'inventory',
#   'November',
#   '5'],
#  ['oil',
#   ' ',
#   'California',
#   'Ecuador',
#   'Amazon',
#   'percent',
#   'world',
#   'NBC',
#   'Yasuni',
#   'government',
#   'future',
#   'country',
#   'accounted',
#   'Californiarsquos',
#   'imports',
#   'according',
#   'year',
#   'National',
#   'Park',
#   'tribes',
#   'gas'],
#  [' ',
#   'oil',
#   'energy',
#   'gas',
#   'Looney',
#   'decades',
#   'said',
#   'hydrocarbons',
#   'scenario',
#   '2050',
#   'told',
#   'CNBC',
#   'million',
#   'bpd',
#   'rdquo',
#   'role',
#   'play',
#   'system',
#   'come',
#   'BPrsquos',
#   'executive'],
#  [' ',
#   'production',
#   'oil',
#   'shale',
#   'Permian',
#   'U.S.',
#   'bpd',
#   'said',
#   'growth',
#   'rigs',
#   'discipline',
#   'million',
#   'crude',
#   'capital',
#   'labor',
#   'drilling',
#   'increase',
#   'Energy',
#   '2022',
#   'continue',
#   'add'],
#  [' ',
#   'Europe',
#   'gas',
#   'energy',
#   'weather',
#   'demand',
#   'temperatures',
#   'week',
#   '$',
#   'European',
#   'prices',
#   'winter',
#   'supplies',
#   'normal',
#   'colder',
#   '   ',
#   'said',
#   'higher',
#   'levels',
#   'mmBtu',
#   'months'],
#  [' ',
#   'oil',
#   'Sorokin',
#   'industry',
#   'OPEC',
#   'rdquo',
#   'production',
#   'gas',
#   'said',
#   'surplus',
#   'supply',
#   'Energy',
#   'Minister',
#   'U.S.',
#   'prices',
#   'According',
#   'Adipec',
#   'plans',
#   '400,000',
#   'bpd',
#   'bin'],
#  ['oil',
#   ' ',
#   'demand',
#   'said',
#   'industry',
#   'energy',
#   'supply',
#   'growing',
#   'crunches',
#   'expert',
#   'Yergin',
#   'gas',
#   'end',
#   'investing',
#   'meet',
#   'crude',
#   'lead',
#   'series',
#   'told',
#   'CNBC',
#   'rdquo'],
#  [' ',
#   'prices',
#   'oil',
#   'pump',
#   'Schumer',
#   'release',
#   'Petroleum',
#   'crude',
#   'letter',
#   'Sen.',
#   'President',
#   'Biden',
#   'bring',
#   'immediate',
#   'gas',
#   'Strategic',
#   'Reserve',
#   'SPR',
#   'way',
#   'production',
#   'wrote'],
#  ['Cambo',
#   'oil',
#   ' ',
#   'energy',
#   'development',
#   'project',
#   'COP26',
#   'oilfield',
#   'U.K.rsquos',
#   'ahead',
#   'years',
#   'gas',
#   'Johnson',
#   'transition',
#   'exploration',
#   'activists',
#   'U.K.',
#   'pressure',
#   'clean',
#   'new',
#   'climate'],
#  ['oil',
#   'energy',
#   ' ',
#   'fossil',
#   'transition',
#   'renewable',
#   'Oil',
#   '$',
#   'year',
#   'fuels',
#   'Big',
#   'global',
#   'fuel',
#   'demand',
#   'production',
#   'companies',
#   'continue',
#   'renewables',
#   'investment',
#   'economy',
#   'assets'],
#  ['$',
#   ' ',
#   'options',
#   'oil',
#   'traders',
#   'barrel',
#   'year',
#   'prices',
#   '250',
#   'bets',
#   'data',
#   '200',
#   '100',
#   '300',
#   'betting',
#   'exceed',
#   'Bloomberg',
#   'showed',
#   'traded',
#   'Brent',
#   'certain'],
#  ['prices',
#   ' ',
#   'oil',
#   'U.S.',
#   'lower',
#   'crude',
#   'ban',
#   'Ingham',
#   'exports',
#   'Energy',
#   'proposal',
#   'group',
#   'Democratic',
#   'Senators',
#   'retail',
#   'fuel',
#   'absolutely',
#   'higher',
#   'Texas',
#   'Petroleum',
#   'told'],
#  ['oil',
#   ' ',
#   'said',
#   'demand',
#   'gas',
#   'new',
#   'executive',
#   'global',
#   'supply',
#   'rdquo',
#   'capacity',
#   'chief',
#   'Sechin',
#   'Rosneftrsquos',
#   'energy',
#   'Nasser',
#   'production',
#   'increase',
#   'Igor',
#   'rebound',
#   'gap'],
#  [' ',
#   'oil',
#   'carbon',
#   'world',
#   'emissions',
#   'demand',
#   'lower',
#   'gas',
#   'global',
#   'energy',
#   'industry',
#   'intensity',
#   'crude',
#   'future',
#   'year',
#   'CEO',
#   'said',
#   'need',
#   'companies',
#   'CO2',
#   'pandemic'],
#  [' ',
#   'demand',
#   'prices',
#   'oil',
#   'Biden',
#   '$',
#   'increase',
#   'options',
#   'Granholm',
#   'energy',
#   'administration',
#   'fuel',
#   'quoted',
#   'Reuters',
#   'billion',
#   'said',
#   'fossil',
#   'fuels',
#   'pump',
#   'OPEC',
#   'Secretary'],
#  ['oil',
#   'Iran',
#   ' ',
#   'crude',
#   'China',
#   'Iranian',
#   'bpd',
#   'data',
#   'refiners',
#   'August',
#   'October',
#   'sanctions',
#   'Chinese',
#   'imported',
#   'Vortexa',
#   'Independent',
#   'imports',
#   'cheaper',
#   'risk',
#   'U.S.',
#   'Reuters'],
#  [' ',
#   'million',
#   'bpd',
#   'year',
#   'demand',
#   'oil',
#   'prices',
#   'higher',
#   'crude',
#   'average',
#   'supply',
#   'said',
#   'inventories',
#   'output',
#   'production',
#   'travel',
#   'faster',
#   'Energy',
#   'Information',
#   'Administration',
#   'agency'],
#  [' ',
#   'gasoline',
#   'prices',
#   'SPR',
#   'U.S.',
#   'rdquo',
#   'Biden',
#   'barrels',
#   'President',
#   'crude',
#   'oil',
#   'million',
#   'Administration',
#   'pump',
#   'release',
#   'told',
#   'tools',
#   'sale',
#   'said',
#   'OPEC',
#   'Granholm'],
#  ['oil',
#   'barrels',
#   'Iran',
#   'fields',
#   'billion',
#   'ndash',
#   'Mansouri',
#   'production',
#   'Petroleum',
#   'field',
#   'crude',
#   'Iraq',
#   'bpd',
#   'Ministry',
#   'cent',
#   'development',
#   'Lukoil',
#   'Iranian',
#   'million',
#   'km',
#   'gas'],
#  ['oil',
#   'Biden',
#   ' ',
#   'boost',
#   'climate',
#   'fossil',
#   'U.S.',
#   'infrastructure',
#   'Infrastructure',
#   'Bill',
#   'fuels',
#   'bill',
#   'demand',
#   'global',
#   'world',
#   'OPEC',
#   'administrationrsquos',
#   'landmark',
#   'long',
#   'markets',
#   'package'],
#  ['oil',
#   'Stabroek',
#   'Block',
#   'Exxon',
#   'barrels',
#   'Guyana',
#   'energy',
#   'day',
#   'Guyanarsquos',
#   'crude',
#   'production',
#   'Georgetown',
#   'million',
#   'partners',
#   'considerable',
#   ' ',
#   'government',
#   'South',
#   'offshore',
#   'companies',
#   'favorable'],
#  [' ',
#   'oil',
#   'Saudi',
#   'percent',
#   'quarter',
#   'result',
#   'demand',
#   'growth',
#   'year',
#   'quarterly',
#   'production',
#   '$',
#   'Nasser',
#   'economic',
#   'prices',
#   'Kingdom',
#   'noted',
#   'increase',
#   'activities',
#   'crude',
#   'said'],
#  ['prices',
#   ' ',
#   'crude',
#   'oil',
#   'supply',
#   'Sen.',
#   'gas',
#   'Democratic',
#   'called',
#   'President',
#   'Biden',
#   'ban',
#   'exports',
#   'administration',
#   'retail',
#   'fuel',
#   'gasoline',
#   'said',
#   'letter',
#   'cited',
#   'senators'],
#  [' ',
#   'capacity',
#   'oil',
#   'Nasser',
#   'spare',
#   'demand',
#   'said',
#   'world',
#   'production',
#   'year',
#   'million',
#   'bpd',
#   'concern',
#   'Aramco',
#   'huge',
#   'jet',
#   'fuel',
#   'executive',
#   'industry',
#   'market',
#   'expected'],
#  ['oil',
#   'Petrobras',
#   'Brazilrsquos',
#   'largest',
#   'crude',
#   '2021',
#   'prices',
#   ' ',
#   'barrels',
#   'Buzios',
#   'Latin',
#   'fuel',
#   'September',
#   'worldrsquos',
#   'million',
#   'Americarsquos',
#   'economy',
#   'political',
#   'Bolsonaro',
#   'company',
#   'Bolsonarorsquos'],
#  ['gas',
#   'prices',
#   ' ',
#   'natural',
#   'U.S.',
#   'percent',
#   'higher',
#   'energy',
#   'winter',
#   'record',
#   'exports',
#   'year',
#   'heating',
#   'LNG',
#   'American',
#   'amid',
#   'domestic',
#   'lower',
#   'bills',
#   'EIA',
#   'benchmark'],
#  ['oil',
#   'prices',
#   ' ',
#   'OPEC',
#   'Russia',
#   'U.S.',
#   'production',
#   'look',
#   'pump',
#   'gas',
#   'refusal',
#   'million',
#   'BPD',
#   'pandemic',
#   'ahead',
#   'President',
#   'cause',
#   'OPECrsquos',
#   'virtual',
#   'meeting',
#   'Joe'],
#  [' ',
#   'Saudi',
#   'price',
#   '$',
#   'prices',
#   'crude',
#   'oil',
#   'Asia',
#   'barrel',
#   'December',
#   'market',
#   'Light',
#   'Arabia',
#   'expected',
#   'Arab',
#   'hike',
#   'increase',
#   'raised',
#   'traders',
#   'refiners',
#   'world'],
#  ['oil',
#   ' ',
#   'Egypt',
#   'gas',
#   'energy',
#   'production',
#   'new',
#   'percent',
#   'Egyptrsquos',
#   'Eni',
#   'discoveries',
#   'operations',
#   'discovery',
#   'refineries',
#   'self',
#   'sufficient',
#   'major',
#   'region',
#   'million',
#   'Petroleum',
#   'years'],
#  [' ',
#   'gasoline',
#   'oil',
#   'U.S.',
#   'OPEC',
#   'price',
#   'President',
#   'Biden',
#   'SPR',
#   'prices',
#   'barrels',
#   'Granholm',
#   'crude',
#   'mdash',
#   'reduce',
#   'United',
#   'States',
#   'Thursday',
#   'calls',
#   'market',
#   'Secretary'],
#  [' ',
#   'week',
#   'oil',
#   'rigs',
#   'rig',
#   'count',
#   'year',
#   'gas',
#   'number',
#   'United',
#   'States',
#   'rose',
#   '$',
#   '6',
#   'total',
#   'production',
#   'day',
#   'time',
#   'U.S.',
#   'increase',
#   'stayed'],
#  ['oil',
#   'West',
#   'Qurna',
#   '1',
#   'Iraq',
#   'U.S.',
#   'China',
#   'field',
#   'ndash',
#   'bpd',
#   'fields',
#   'CSSP',
#   'US$',
#   'million',
#   ' ',
#   'Iraqrsquos',
#   'barrels',
#   'production',
#   'gas',
#   'wells',
#   'supergiant'],
#  [' ',
#   'oil',
#   'Recon',
#   'company',
#   'gas',
#   'exploration',
#   'shares',
#   'price',
#   'production',
#   'Kavango',
#   'natural',
#   'potential',
#   'Energy',
#   'Africa',
#   'results',
#   '$',
#   'companies',
#   'seismic',
#   'drilling',
#   'time',
#   'world'],
#  ['Basrah',
#   'Light',
#   'Medium',
#   'SOMO',
#   'stream',
#   'Iraq',
#   'quality',
#   'crude',
#   'grades',
#   ' ',
#   'API',
#   'end',
#   'domestic',
#   'market',
#   'introduced',
#   'qualities',
#   'Iraqi',
#   'coming',
#   '2021',
#   'barrels',
#   'density'],
#  ['OPEC',
#   ' ',
#   'production',
#   'bpd',
#   'oil',
#   'million',
#   'market',
#   '400,000',
#   'meeting',
#   'supply',
#   'nbsp',
#   'group',
#   'continue',
#   'easing',
#   'collective',
#   'cuts',
#   'consuming',
#   'nations',
#   'rally',
#   'increase',
#   'energy'],
#  ['OPEC',
#   ' ',
#   'b',
#   'd',
#   'increase',
#   'oil',
#   'nations',
#   '400k',
#   'U.S.',
#   'plan',
#   'raise',
#   'production',
#   'consuming',
#   'prices',
#   'output',
#   'December',
#   'm',
#   'Nov.',
#   'Bloomberg',
#   'today',
#   'planned'],
#  [' ',
#   'million',
#   'barrels',
#   'week',
#   'oil',
#   'inventory',
#   'build',
#   'bpd',
#   'compared',
#   'production',
#   'reported',
#   'October',
#   '29',
#   'middle',
#   'distillates',
#   'estimated',
#   'OPEC',
#   'supply',
#   'prices',
#   'gasoline',
#   'EIA'],
#  [' ',
#   'said',
#   'oil',
#   'Diamondback',
#   'production',
#   'quarter',
#   '2021',
#   'capital',
#   'shale',
#   'approach',
#   'cash',
#   'shareholders',
#   '$',
#   'increase',
#   'crude',
#   'year',
#   'prices',
#   'results',
#   'excess',
#   'remain',
#   'discipline'],
#  [' ',
#   'oil',
#   'OPEC',
#   'President',
#   'said',
#   'going',
#   'cartel',
#   'prices',
#   'production',
#   'Biden',
#   'U.S.',
#   'Granholm',
#   'country',
#   'percent',
#   'working',
#   'class',
#   'news',
#   'conference',
#   'idea',
#   'pump',
#   'work'],
#  ['$',
#   'billion',
#   'y',
#   ' ',
#   '   ',
#   'earnings',
#   'estimate',
#   'oil',
#   'Exxon',
#   'company',
#   'prices',
#   'year',
#   'vs.',
#   'energy',
#   'Q3',
#   'spending',
#   'cash',
#   'flow',
#   'million',
#   'quarter',
#   'Chevron'],
#  [' ',
#   'October',
#   'prices',
#   '$',
#   'oil',
#   'supply',
#   'WTI',
#   'Crude',
#   'Friday',
#   'global',
#   'inventories',
#   'barrel',
#   'year',
#   'price',
#   'stocks',
#   'million',
#   'barrels',
#   'month',
#   'energy',
#   'rebounding',
#   'demand'],
#  [' ',
#   'shale',
#   'Energy',
#   'quarter',
#   'year',
#   'DUC',
#   'wells',
#   'U.S.',
#   'activity',
#   'DUCs',
#   'cash',
#   'producers',
#   'Rystad',
#   'patch',
#   'largely',
#   'inventory',
#   'spending',
#   'discipline',
#   'record',
#   'said',
#   'production'],
#  [' ',
#   'oil',
#   'OPEC',
#   'market',
#   'deficit',
#   'supply',
#   'bpd',
#   'production',
#   'expected',
#   'group',
#   'fourth',
#   'quarter',
#   'expectations',
#   'told',
#   'Bloomberg',
#   'meeting',
#   'November',
#   'easing',
#   'cuts',
#   'justify',
#   'cautious'],
#  ['oil',
#   'California',
#   'state',
#   ' ',
#   'gas',
#   'energy',
#   'Californiarsquos',
#   'Newsom',
#   'producing',
#   'away',
#   'climate',
#   'drilling',
#   'government',
#   'Big',
#   'Oil',
#   'future',
#   'major',
#   'industry',
#   'end',
#   'renewable',
#   'environmental'],
#  [' ',
#   'oil',
#   'Gulf',
#   'Coast',
#   'Bloomberg',
#   'supply',
#   'inventories',
#   'barrels',
#   'demand',
#   'Cushing',
#   'OPEC',
#   'markets',
#   'years',
#   'million',
#   'increase',
#   'export',
#   'refiners',
#   'reported',
#   'crude',
#   'imports',
#   'lower'],
#  [' ',
#   'oil',
#   '$',
#   'company',
#   'gas',
#   'shares',
#   'oilsands',
#   'energy',
#   'natural',
#   'expected',
#   'prices',
#   'Energy',
#   'United',
#   'price',
#   'year',
#   'cash',
#   'ConocoPhillips',
#   'LNG',
#   'barrel',
#   'global',
#   'Petroteq'],
#  [' ',
#   'prices',
#   'Iran',
#   'barrels',
#   'talks',
#   'November',
#   'gas',
#   'Thursday',
#   'nuclear',
#   'end',
#   'Wednesday',
#   'oil',
#   'million',
#   'week',
#   'rdquo',
#   'Oil',
#   'early',
#   'U.S.',
#   'crude',
#   'stocks',
#   'said'],
#  ['oil',
#   'Stabroek',
#   'Exxon',
#   'Block',
#   'Liza',
#   'energy',
#   'crude',
#   'barrels',
#   'operations',
#   '2020',
#   'Guyana',
#   'petroleum',
#   'production',
#   'carbon',
#   'gas',
#   'supermajor',
#   'Guyanarsquos',
#   'discovery',
#   'global',
#   ' ',
#   'day'],
#  ['oil',
#   'Alaskan',
#   ' ',
#   'pandemic',
#   'jobs',
#   'Alaska',
#   'year',
#   'low',
#   'states',
#   'global',
#   '2020',
#   'Texas',
#   'production',
#   'drilling',
#   'agenda',
#   'United',
#   'left',
#   'Hawaii',
#   'gas',
#   'took',
#   'demand'],
#  [' ',
#   'NOC',
#   'oil',
#   'Libyarsquos',
#   'Libyan',
#   'security',
#   'sites',
#   'Es',
#   'Sider',
#   'pipeline',
#   'leak',
#   'shutdown',
#   'maintenance',
#   'reported',
#   'Tuesdayrsquos',
#   'damaged',
#   'Oil',
#   'said',
#   'crude',
#   'production',
#   'damage'],
#  [' ',
#   'million',
#   'week',
#   'barrels',
#   'bpd',
#   'inventory',
#   'compared',
#   'said',
#   'earlier',
#   '$',
#   'prices',
#   'previous',
#   'production',
#   'middle',
#   'averaged',
#   'crude',
#   'year',
#   'supply',
#   'Brent',
#   'barrel',
#   'end'],
#  [' ',
#   'prices',
#   'oil',
#   'shale',
#   'rdquo',
#   'OPEC',
#   'demand',
#   'week',
#   'said',
#   'ldquoWe',
#   'wersquore',
#   'higher',
#   'supply',
#   'Kemp',
#   'U.S.',
#   'drillers',
#   'risks',
#   'production',
#   'granted',
#   'fuel',
#   'Sylva'],
#  ['oil',
#   ' ',
#   'demand',
#   'supply',
#   'new',
#   'global',
#   'peak',
#   'rdquo',
#   '$',
#   'underinvestment',
#   'earlier',
#   'years',
#   'investment',
#   'year',
#   'industry',
#   'analysts',
#   'energy',
#   'net',
#   'zero',
#   'prices',
#   'OPEC'],
#  ['oil',
#   ' ',
#   'prices',
#   'million',
#   'said',
#   'gas',
#   'crude',
#   'market',
#   'funds',
#   'barrels',
#   'week',
#   'demand',
#   'weather',
#   'Kemp',
#   'higher',
#   'supply',
#   'fuel',
#   'cold',
#   'Goldman',
#   'OPEC',
#   'Brent'],
#  ['oil',
#   'production',
#   ' ',
#   'capacity',
#   'gas',
#   'term',
#   'new',
#   'spare',
#   'year',
#   'million',
#   'bpd',
#   'long',
#   'report',
#   'Aramco',
#   'Bloomberg',
#   'Nasser',
#   'said',
#   'declining',
#   'Energy',
#   'days',
#   'years'],
#  [' ',
#   'oil',
#   'production',
#   'said',
#   'rdquo',
#   'OPEC',
#   'minister',
#   'Salman',
#   'supply',
#   'ldquoWe',
#   'wersquore',
#   'cautious',
#   'Saudi',
#   'bin',
#   'told',
#   'Bloomberg',
#   'interview',
#   'combined',
#   'official',
#   'Covid',
#   'output'],
#  ['energy',
#   ' ',
#   'oil',
#   'companies',
#   'economy',
#   'production',
#   'costs',
#   'economic',
#   '$',
#   'gas',
#   'prices',
#   'United',
#   'global',
#   'pandemic',
#   'services',
#   'supply',
#   'crunch',
#   'barrel',
#   'inflation',
#   'U.S.',
#   'rise'],
#  ['production',
#   'OPEC',
#   ' ',
#   'oil',
#   'members',
#   'compliance',
#   'alliance',
#   'group',
#   'quickly',
#   'Russian',
#   'overall',
#   'September',
#   'collective',
#   'slightly',
#   'agreed',
#   'raise',
#   'Putin',
#   'said',
#   'Thursday',
#   'countries',
#   'increasing'],
#  ['oil',
#   ' ',
#   'Canada',
#   'Canadian',
#   'Enbridge',
#   'pipeline',
#   'industry',
#   'bpd',
#   'demand',
#   'gas',
#   'remains',
#   'U.S.',
#   'Line',
#   'decline',
#   'Canadarsquos',
#   'fossil',
#   'fuels',
#   'ensure',
#   'Oil',
#   'following',
#   'OPEC'],
#  ['oil',
#   'Venezuelarsquos',
#   'petroleum',
#   'industry',
#   'infrastructure',
#   'spills',
#   'barrels',
#   '2021',
#   ' ',
#   'environmental',
#   'Venezuela',
#   'Caracas',
#   'U.S.',
#   'worldrsquos',
#   'state',
#   'largest',
#   'OPEC',
#   'September',
#   'including',
#   'maintenance',
#   'heavily'],
#  [' ',
#   'week',
#   'oil',
#   'million',
#   'crude',
#   'barrels',
#   'inventory',
#   'prices',
#   'compared',
#   'bpd',
#   'year',
#   'production',
#   'demand',
#   'sizeable',
#   'EIA',
#   'inventories',
#   'time',
#   'Gasoline',
#   'previous',
#   'averaged',
#   'earlier'],
#  ['$',
#   ' ',
#   'year',
#   'earnings',
#   'oil',
#   'quarter',
#   '2021',
#   'report',
#   'expected',
#   'prices',
#   'gas',
#   'ago',
#   'company',
#   'revenue',
#   'EPS',
#   'vs.',
#   'COP',
#   'billion',
#   '2020',
#   'consensus',
#   'companies'],
#  ['cobalt',
#   ' ',
#   'batteries',
#   'LFP',
#   'battery',
#   'EV',
#   'energy',
#   'lithium',
#   'cost',
#   '$',
#   'metals',
#   'nickel',
#   'electric',
#   'price',
#   'Tesla',
#   'cells',
#   '100',
#   'kWh',
#   'vehicles',
#   'chemistry',
#   'China'],
#  ['oil',
#   'b',
#   'd',
#   'new',
#   'exports',
#   ' ',
#   'Nigeria',
#   'Nigeriarsquos',
#   'Nigerian',
#   'production',
#   'month',
#   'regulatory',
#   'November',
#   'spill',
#   'million',
#   'months',
#   'i.e.',
#   'reported',
#   'leaking',
#   'seen',
#   'produced'],
#  [' ',
#   'OPEC',
#   'prices',
#   'address',
#   'oil',
#   'member',
#   'mdash',
#   'rdquo',
#   'production',
#   'administration',
#   'pump',
#   'retail',
#   'fuel',
#   'remain',
#   'press',
#   'countries',
#   'supply',
#   'issue',
#   'Secretary',
#   'Psaki',
#   'wersquore'],
#  ['production',
#   'oil',
#   ' ',
#   'bpd',
#   'million',
#   'U.S.',
#   'Permian',
#   'month',
#   'average',
#   'higher',
#   '$',
#   'barrel',
#   'growth',
#   'pandemic',
#   'report',
#   'stood',
#   'February',
#   '2020',
#   'crude',
#   'output',
#   'private'],
#  ['OPEC',
#   ' ',
#   'production',
#   'oil',
#   'group',
#   'overall',
#   'compliance',
#   'percent',
#   'September',
#   'bpd',
#   'cuts',
#   'members',
#   'November',
#   'collective',
#   '115',
#   'told',
#   'Monday',
#   'higher',
#   'market',
#   'alliance',
#   'quotas'],
#  [' ',
#   'oil',
#   'production',
#   'bpd',
#   'drilling',
#   'OPEC',
#   'million',
#   'new',
#   'companies',
#   'ESG',
#   'gas',
#   'July',
#   'According',
#   'years',
#   'Angola',
#   'fields',
#   'wells',
#   'shale',
#   'boost',
#   'output',
#   'clip'],
#  [' ',
#   'import',
#   'oil',
#   'Beijing',
#   'quotas',
#   'refiners',
#   'year',
#   'energy',
#   'crude',
#   'independent',
#   'million',
#   'tons',
#   'imports',
#   'private',
#   'latest',
#   'industry',
#   'total',
#   '2020',
#   'decline',
#   'granted',
#   'largest'],
#  [' ',
#   'OPEC',
#   'capacity',
#   'production',
#   'spare',
#   'energy',
#   'prices',
#   'HRH',
#   'markets',
#   'market',
#   'Prince',
#   'end',
#   'year',
#   'oil',
#   'barrels',
#   'Energy',
#   'Saudi',
#   'climate',
#   'security',
#   'job',
#   'add'],
#  ['demand',
#   'oil',
#   ' ',
#   'OPEC',
#   'bpd',
#   'million',
#   'gas',
#   'global',
#   'growth',
#   'cartel',
#   '2022',
#   'year',
#   'fuel',
#   '2021',
#   'heating',
#   'monthrsquos',
#   'estimate',
#   'forecast',
#   'average',
#   'recovery',
#   'economic'],
#  [' ',
#   'OPEC',
#   'bpd',
#   'production',
#   'million',
#   'oil',
#   'barrels',
#   'according',
#   'recovery',
#   'output',
#   'supposed',
#   'survey',
#   'Platts',
#   'cartel',
#   'pump',
#   'combined',
#   'September',
#   'quotas',
#   'Argus',
#   'total',
#   'higher'],
#  [' ',
#   'demand',
#   'oil',
#   '$',
#   'prices',
#   'gas',
#   'global',
#   'recovery',
#   'continues',
#   'countries',
#   'energy',
#   'barrel',
#   'natural',
#   'levels',
#   'globally',
#   'supply',
#   'Wood',
#   'quarter',
#   'bpd',
#   'Oil',
#   '80'],
#  ['energy',
#   ' ',
#   'transition',
#   'demand',
#   'fuel',
#   'consumption',
#   'Europe',
#   'increase',
#   'power',
#   'gas',
#   'people',
#   'change',
#   'supply',
#   'Asia',
#   'fossil',
#   'wind',
#   'coal',
#   'oil',
#   'things',
#   'protests',
#   'itrsquos'],
#  ['nbsp',
#   ' ',
#   'supply',
#   'said',
#   'oil',
#   'new',
#   'demand',
#   'industry',
#   'Energy',
#   'meet',
#   'projects',
#   'Intelligence',
#   'Global',
#   'medium',
#   'term',
#   'world',
#   'shortage',
#   'investment',
#   'Forum',
#   'future',
#   'need'],
#  ['oil',
#   ' ',
#   'Iran',
#   'industry',
#   'Owji',
#   'said',
#   'foreign',
#   'investments',
#   'minister',
#   'Iranian',
#   'quoted',
#   'plan',
#   '$',
#   'U.S.',
#   'sanctions',
#   'crude',
#   'exchange',
#   'told',
#   'local',
#   'investors',
#   'gas'],
#  [' ',
#   'prices',
#   'gas',
#   'oil',
#   'natural',
#   'demand',
#   '$',
#   'year',
#   'producers',
#   'b',
#   'd',
#   'markets',
#   'saying',
#   'power',
#   'high',
#   'OPEC',
#   'surged',
#   'global',
#   'crude',
#   'cheaper',
#   'switching'],
#  ['Lebanonrsquos',
#   'civil',
#   'economic',
#   'Hezbollah',
#   'Lebanon',
#   'war',
#   'crisis',
#   'political',
#   'organization',
#   ' ',
#   'Lebanese',
#   'Middle',
#   'oil',
#   'causing',
#   'domestic',
#   '2020',
#   '2021',
#   'collapse',
#   'country',
#   '  ',
#   'economy'],
#  [' ',
#   'rigs',
#   'rose',
#   'rig',
#   'count',
#   'number',
#   'oil',
#   'week',
#   '5',
#   '$',
#   'gas',
#   'total',
#   'year',
#   'day',
#   'United',
#   'States',
#   'time',
#   'lost',
#   'production',
#   'ending',
#   'October'],
#  [' ',
#   'energy',
#   'coal',
#   'production',
#   'China',
#   'million',
#   'tons',
#   'imports',
#   'Chinese',
#   'authorities',
#   '72',
#   'mines',
#   'boost',
#   'amid',
#   'crunch',
#   'seen',
#   'economy',
#   'local',
#   'told',
#   'Europe',
#   'quickly'],
#  ['oil',
#   'Saudi',
#   ' ',
#   'Arabia',
#   'production',
#   'demand',
#   'million',
#   'bpd',
#   'year',
#   'export',
#   'prices',
#   'countryrsquos',
#   'remains',
#   'crude',
#   'position',
#   'market',
#   'China',
#   'gas',
#   'global',
#   'revenue',
#   'OPEC'],
#  [' ',
#   'oil',
#   'Moodyrsquos',
#   'upstream',
#   '$',
#   'billion',
#   'year',
#   'Global',
#   'spending',
#   'supply',
#   'said',
#   'investment',
#   'according',
#   'analysts',
#   'demand',
#   'pandemic',
#   'industry',
#   'annual',
#   'increase',
#   'percent',
#   '542'],
#  [' ',
#   'oil',
#   'SPR',
#   'OPEC',
#   'prices',
#   'Psaki',
#   'U.S.',
#   'Energy',
#   'crude',
#   'gasoline',
#   'said',
#   'considering',
#   '$',
#   'climate',
#   'crisis',
#   'going',
#   'steps',
#   'mdash',
#   'rdquo',
#   'price',
#   'release'],
#  ['oil',
#   'OPEC',
#   ' ',
#   'Reuters',
#   'sources',
#   'said',
#   'bpd',
#   'price',
#   'prices',
#   '$',
#   'original',
#   '400,000',
#   'supply',
#   'production',
#   'happy',
#   'adding',
#   'decision',
#   'United',
#   'States',
#   'memory',
#   'makes'],
#  [' ',
#   'week',
#   'million',
#   'barrels',
#   'inventory',
#   'oil',
#   'build',
#   'crude',
#   'previous',
#   'production',
#   'bpd',
#   'reported',
#   'EIA',
#   'said',
#   'compared',
#   'averaging',
#   '400,000',
#   'Crude',
#   'Energy',
#   'October',
#   '1'],
#  [' ',
#   'oil',
#   'barrels',
#   'energy',
#   'million',
#   '$',
#   'prices',
#   'Oil',
#   'week',
#   'OPEC',
#   'Brent',
#   'crunch',
#   'Energy',
#   'Kemp',
#   'continue',
#   'production',
#   'gas',
#   'U.S.',
#   'rdquo',
#   'bearish',
#   'price'],
#  [' ',
#   'U.S.',
#   'oil',
#   'shale',
#   'production',
#   'prices',
#   'supply',
#   'rdquo',
#   'producers',
#   'said',
#   'OPEC',
#   'discipline',
#   'Natural',
#   '$',
#   'Oil',
#   'patch',
#   'going',
#   'control',
#   'hands',
#   'spending',
#   'largest'],
#  ['bpd',
#   ' ',
#   'million',
#   'oil',
#   'said',
#   'demand',
#   'year',
#   'Aramco',
#   'quoted',
#   'capacity',
#   '13',
#   '$',
#   'barrel',
#   'energy',
#   'gas',
#   'crunch',
#   'executive',
#   'Energy',
#   'Intelligence',
#   'Nasser',
#   'reach'],
#  ['oil',
#   'bpd',
#   'NOC',
#   'ndash',
#   'Libyarsquos',
#   'million',
#   'production',
#   ' ',
#   'crude',
#   'agreement',
#   'Sanalla',
#   'Libya',
#   'fields',
#   'September',
#   'ministry',
#   'countryrsquos',
#   'country',
#   'increase',
#   'gas',
#   'Abbar',
#   'sector'],
#  [' ',
#   'oil',
#   'production',
#   'U.S.',
#   'prices',
#   'growth',
#   'producers',
#   'Dallas',
#   'Fed',
#   'OPEC',
#   '$',
#   'costs',
#   'September',
#   'month',
#   'bpd',
#   'shale',
#   'industry',
#   'gas',
#   'said',
#   'news',
#   'higher'],
#  [' ',
#   '$',
#   'OPEC',
#   'increase',
#   'bpd',
#   'ended',
#   'production',
#   'group',
#   'November',
#   'market',
#   'meeting',
#   'news',
#   'oil',
#   'agreed',
#   '400,000',
#   'prices',
#   'adding',
#   'month',
#   'trading',
#   'day',
#   'barrel'],
#  [' ',
#   'OPEC',
#   'bpd',
#   'meeting',
#   'cuts',
#   'group',
#   '400,000',
#   'November',
#   'oil',
#   'production',
#   'monthly',
#   'December',
#   'increase',
#   'rdquo',
#   'said',
#   'expected',
#   'plans',
#   'today',
#   'month',
#   'demand',
#   'reports'],
#  [' ',
#   'production',
#   'OPEC',
#   'bpd',
#   'oil',
#   'prices',
#   'Reuters',
#   'said',
#   'boost',
#   '400,000',
#   'earlier',
#   'sources',
#   'month',
#   'strongly',
#   'week',
#   'cartel',
#   'agreed',
#   'growing',
#   'pressure',
#   'Brent',
#   'moved'],
#  ['OPEC',
#   ' ',
#   'bpd',
#   'production',
#   'September',
#   'oil',
#   'Reuters',
#   'survey',
#   'OPECrsquos',
#   'members',
#   'August',
#   'April',
#   'supply',
#   'month',
#   'increase',
#   'according',
#   '420,000',
#   'highest',
#   'cartel',
#   'cuts',
#   'Nigeria'],
#  ['nbsp',
#   'oil',
#   'shale',
#   ' ',
#   'production',
#   'gas',
#   'China',
#   'Daqing',
#   'PetroChina',
#   'major',
#   'oilfield',
#   'Reuters',
#   'Gulong',
#   'resources',
#   'Chinese',
#   'giant',
#   'start',
#   'cluster',
#   '2025',
#   'analysts',
#   'tell'],
#  ['oil',
#   ' ',
#   'demand',
#   'prices',
#   '$',
#   'supply',
#   'Oil',
#   'OPEC',
#   'year',
#   'barrel',
#   'early',
#   'global',
#   'gas',
#   '2022',
#   'pre',
#   'said',
#   'Brent',
#   'crisis',
#   'U.S.',
#   'trading',
#   'recovery'],
#  [' ',
#   'commodity',
#   'oil',
#   'banks',
#   'traders',
#   'energy',
#   '$',
#   'gas',
#   'financial',
#   'lending',
#   'shadow',
#   'year',
#   'investment',
#   'markets',
#   'funds',
#   'world',
#   'half',
#   'crisis',
#   'smaller',
#   'capital',
#   'lenders'],
#  ['Vaca',
#   'oil',
#   'Muerta',
#   'production',
#   'wells',
#   ' ',
#   'August',
#   'activity',
#   'POP',
#   'bpd',
#   'gas',
#   'record',
#   'quarter',
#   'months',
#   'Rystad',
#   'Energy',
#   'output',
#   'July',
#   'ndash',
#   'Permian',
#   'year'],
#  [' ',
#   'prices',
#   'OPEC',
#   'oil',
#   'Psaki',
#   'said',
#   'recovery',
#   'rdquo',
#   'White',
#   'House',
#   'Tuesday',
#   '$',
#   'barrel',
#   'time',
#   'plans',
#   'gasoline',
#   'global',
#   'cuts',
#   'Biden',
#   'speak',
#   'importance'],
#  [' ',
#   'million',
#   'week',
#   'barrels',
#   'production',
#   'inventory',
#   'oil',
#   'build',
#   'compared',
#   'bpd',
#   'reported',
#   'September',
#   '24',
#   'draw',
#   'previous',
#   'price',
#   '4.6',
#   '3.5',
#   'EIA',
#   'Gasoline',
#   'earlier'],
#  [' ',
#   'oil',
#   'prices',
#   'OPEC',
#   '$',
#   '80',
#   'week',
#   '400,000',
#   'bpd',
#   'crude',
#   'energy',
#   'rally',
#   'sources',
#   'told',
#   'Despite',
#   'recent',
#   'November',
#   'Reuters',
#   'nbsp',
#   'Brent',
#   'hit'],
#  ['oil',
#   ' ',
#   'demand',
#   'analysts',
#   'year',
#   'production',
#   'Goldman',
#   'market',
#   'supply',
#   'bull',
#   'prices',
#   'commodity',
#   'gas',
#   'Europe',
#   'bullish',
#   '$',
#   'Covid-19',
#   'structural',
#   'earlier',
#   'noted',
#   'Ida'],
#  ['demand',
#   'oil',
#   'OPEC',
#   ' ',
#   'energy',
#   '2045',
#   'outlook',
#   'term',
#   'expected',
#   'grow',
#   'said',
#   '2021',
#   '   ',
#   'continue',
#   'million',
#   'bpd',
#   'set',
#   'plateau',
#   'Oil',
#   'WOO',
#   'OPECrsquos'],
#  [' ',
#   'oil',
#   'demand',
#   'year',
#   'supply',
#   'Hill',
#   'said',
#   'levels',
#   '2022',
#   'Hess',
#   'pandemic',
#   'pre',
#   'end',
#   'early',
#   'million',
#   'market',
#   'rdquo',
#   'industry',
#   'meet',
#   'set',
#   'return'],
#  ['oil',
#   ' ',
#   'Nigeria',
#   'percent',
#   'industry',
#   '$',
#   'Suncor',
#   'time',
#   'Nigerian',
#   'government',
#   'new',
#   'PIA',
#   'production',
#   'billion',
#   'investors',
#   'Nigeriarsquos',
#   'gas',
#   'region',
#   'Delta',
#   'Shell',
#   'funds'],
#  [' ',
#   'rigs',
#   'rig',
#   'count',
#   'oil',
#   'rose',
#   'week',
#   'number',
#   'year',
#   'day',
#   '$',
#   'gas',
#   'time',
#   'United',
#   'States',
#   'total',
#   '1',
#   'production',
#   'ending',
#   'September',
#   '17'],
#  ['oil',
#   ' ',
#   'Venezuela',
#   'China',
#   'sanctions',
#   'U.S.',
#   'crude',
#   'industry',
#   'Venezuelan',
#   'country',
#   'countryrsquos',
#   'state',
#   'international',
#   'new',
#   'fuel',
#   'Venezuelarsquos',
#   'majors',
#   'energy',
#   'PDVSA',
#   'economy',
#   'barrels'],
#  ['oil',
#   'Colombiarsquos',
#   'Colombia',
#   'petroleum',
#   'barrels',
#   'coca',
#   'investment',
#   'crude',
#   'year',
#   ' ',
#   'billion',
#   'cocaine',
#   'Andean',
#   'largest',
#   'day',
#   'industry',
#   'production',
#   'countryrsquos',
#   'long',
#   'violence',
#   '2021'],
#  [' ',
#   'oil',
#   'prices',
#   'Thursday',
#   'crude',
#   'market',
#   '$',
#   'U.S.',
#   'said',
#   'highest',
#   'July',
#   'lowest',
#   'Crude',
#   'barrel',
#   'Brent',
#   'Wednesday',
#   'soon',
#   'inventories',
#   'markets',
#   'nbsp',
#   'strategists'],
#  ['Arctic',
#   'oil',
#   'gas',
#   ' ',
#   '$',
#   'billion',
#   'companies',
#   'report',
#   'commitments',
#   'financing',
#   'rdquo',
#   'said',
#   'industry',
#   'holdings',
#   'BlackRock',
#   'climate',
#   'drilling',
#   'energy',
#   'fossil',
#   'new',
#   'Reclaim'],
#  ['oil',
#   ' ',
#   'Canadian',
#   'crude',
#   'industry',
#   'Syncrude',
#   'bitumen',
#   'production',
#   'cut',
#   'month',
#   'likely',
#   'Gulf',
#   'remains',
#   'output',
#   'bpd',
#   'according',
#   'year',
#   'government',
#   'mechanical',
#   'disruption',
#   'Bloomberg'],
#  ['gas',
#   'oil',
#   ' ',
#   'prices',
#   'demand',
#   'natural',
#   'OPEC',
#   'year',
#   'winter',
#   '$',
#   'shortage',
#   'higher',
#   'fuels',
#   'Europe',
#   'producer',
#   'soaring',
#   'Kyari',
#   'told',
#   'Bloomberg',
#   'Wednesday',
#   '1'],
#  ['week',
#   'million',
#   ' ',
#   'barrels',
#   'compared',
#   'bpd',
#   'prices',
#   'inventory',
#   'September',
#   '17',
#   'production',
#   'oil',
#   'reported',
#   'draw',
#   'previous',
#   'barrel',
#   'time',
#   '3.5',
#   'decline',
#   'Hurricane',
#   'Ida'],
#  ['oil',
#   'Fujairah',
#   'crude',
#   'ndash',
#   'storage',
#   'Strait',
#   ' ',
#   'capacity',
#   'million',
#   'Oman',
#   'UAErsquos',
#   'Hormuz',
#   'hub',
#   'cu',
#   'm',
#   'Iran',
#   'position',
#   'Abu',
#   'Dhabi',
#   'ICE',
#   'Murban'],
#  ['oil',
#   'crude',
#   ' ',
#   'Cushing',
#   'U.S.',
#   'year',
#   'inventories',
#   'percent',
#   'stocks',
#   'EIA',
#   'million',
#   'barrels',
#   '2018',
#   'consumption',
#   '42',
#   'said',
#   'week',
#   '2021',
#   'time',
#   'Storage',
#   'withdrawals'],
#  ['Russia',
#   'energy',
#   ' ',
#   'oil',
#   'gas',
#   'carbon',
#   'parameters',
#   'world',
#   'lower',
#   'coal',
#   'use',
#   'Russian',
#   'economy',
#   'global',
#   'transition',
#   'year',
#   'necessary',
#   'step',
#   'term',
#   'forecast',
#   'decision'],
#  ['Shell',
#   'Permian',
#   ' ',
#   'Dutch',
#   'said',
#   'assets',
#   '$',
#   'court',
#   'oil',
#   'billion',
#   'ConocoPhillips',
#   'price',
#   'value',
#   'cash',
#   'additional',
#   'deal',
#   'Anglo',
#   'close',
#   'company',
#   'shale',
#   'transaction'],
#  ['Venezuela',
#   ' ',
#   'Guyana',
#   'Venezuelan',
#   'oil',
#   'barrels',
#   'contested',
#   'Venezuelarsquos',
#   'state',
#   'region',
#   'Essequibo',
#   'Maduro',
#   'economic',
#   'million',
#   'Stabroek',
#   'Block',
#   '2021',
#   'border',
#   'means',
#   'opposition',
#   'petrostatersquos'],
#  ['oil',
#   'demand',
#   'energy',
#   ' ',
#   'said',
#   'need',
#   '2050',
#   'global',
#   'set',
#   'Alhajji',
#   'impact',
#   'transition',
#   'peak',
#   'net',
#   'zero',
#   'renewables',
#   'expert',
#   'climate',
#   'change',
#   'Energy',
#   'countries'],
#  ['oil',
#   ' ',
#   'Canadian',
#   'industry',
#   'Canada',
#   'sands',
#   'private',
#   'equity',
#   'reduction',
#   'companies',
#   'government',
#   'production',
#   'Oil',
#   'consolidation',
#   'emission',
#   'Reuters',
#   'crude',
#   'year',
#   'exports',
#   'energy',
#   'high'],
#  [' ',
#   'oil',
#   'prices',
#   'production',
#   '$',
#   'market',
#   'worldrsquos',
#   'UK',
#   'month',
#   'supply',
#   'pushing',
#   'Chinarsquos',
#   'year',
#   'Dangote',
#   'firms',
#   'Vitol',
#   'Energy',
#   'contract',
#   'Ida',
#   'September',
#   'Friday'],
#  [' ',
#   'crude',
#   '$',
#   'break',
#   'CL',
#   'things',
#   'channel',
#   'right',
#   'chart',
#   'markets',
#   'risk',
#   'watching',
#   'week',
#   'long',
#   '70',
#   'money',
#   'market',
#   'demand',
#   'output',
#   'global',
#   'pandemic'],
#  ['crude',
#   'oil',
#   'bpd',
#   'strategic',
#   ' ',
#   'China',
#   'million',
#   'estimated',
#   'reserves',
#   'refinery',
#   'August',
#   'months',
#   'Chinese',
#   'fuel',
#   '760,000',
#   'worldrsquos',
#   'importer',
#   'lowest',
#   '15',
#   'inventories',
#   'Russell'],
#  ['bpd',
#   'oil',
#   'million',
#   ' ',
#   'crude',
#   'July',
#   'OPEC',
#   'cuts',
#   'Saudi',
#   'exports',
#   'JODI',
#   'month',
#   'ease',
#   'data',
#   'January',
#   'group',
#   '6',
#   'highest',
#   'continued',
#   'supply',
#   'worldrsquos'],
#  [' ',
#   'oil',
#   'OPEC',
#   'production',
#   '$',
#   'Goldman',
#   'analysts',
#   'price',
#   'barrel',
#   'Sachs',
#   'prices',
#   'yesterdayrsquos',
#   'bpd',
#   'said',
#   'adding',
#   'Brent',
#   'time',
#   'output',
#   'news',
#   'variant',
#   'excessive'],
#  ['Iran',
#   'oil',
#   ' ',
#   'U.S.',
#   'sanctions',
#   'exports',
#   'energy',
#   'output',
#   'export',
#   'Iranrsquos',
#   'ongoing',
#   '2021',
#   'state',
#   'Taliban',
#   'fuel',
#   'Iranian',
#   'increase',
#   'bpd',
#   'Afghanistan',
#   'despite',
#   'increased'],
#  [' ',
#   'gas',
#   'oil',
#   'Vaca',
#   'production',
#   'Fernaacutendez',
#   'Muerta',
#   'bill',
#   'investment',
#   'country',
#   'shale',
#   'export',
#   'potential',
#   'incentivize',
#   'rdquo',
#   'Argentina',
#   'Argentinarsquos',
#   'government',
#   'boost',
#   'play',
#   'surplus'],
#  [' ',
#   'Urals',
#   'price',
#   'crude',
#   'discount',
#   'Russian',
#   'Russiarsquos',
#   'supply',
#   '$',
#   'barrel',
#   'Bloomberg',
#   'grade',
#   'week',
#   'Europe',
#   'Brent',
#   'prices',
#   'according',
#   'Ida',
#   'flagship',
#   'Iraq',
#   'offered'],
#  ['million',
#   ' ',
#   'week',
#   'oil',
#   'draw',
#   'prices',
#   'inventories',
#   'barrels',
#   'bpd',
#   'U.S.',
#   'crude',
#   'compared',
#   'reported',
#   'earlier',
#   'EIA',
#   'gasoline',
#   'demand',
#   'stocks',
#   'year',
#   'Energy',
#   'barrel'],
#  ['oil',
#   ' ',
#   'China',
#   'prices',
#   'strategic',
#   'reserve',
#   'OPEC',
#   'sale',
#   'time',
#   'report',
#   'world',
#   'release',
#   'crude',
#   'price',
#   'inflation',
#   'year',
#   'pandemic',
#   'India',
#   'news',
#   'announced',
#   'government'],
#  ['demand',
#   'bpd',
#   'oil',
#   ' ',
#   'million',
#   'IEA',
#   '2021',
#   'global',
#   'year',
#   'said',
#   'growth',
#   'Oil',
#   'agency',
#   'expected',
#   'robust',
#   'monthrsquos',
#   '2022',
#   'Delta',
#   'variant',
#   'set',
#   'rebound'],
#  [' ',
#   'hurricane',
#   'oil',
#   'Nicholas',
#   'landfall',
#   'Texas',
#   'shut',
#   'production',
#   'early',
#   'hours',
#   'Tuesday',
#   'dangerous',
#   'U.S.',
#   'Ida',
#   'offshore',
#   'Gulf',
#   'Coast',
#   'prices',
#   'percent',
#   'extreme',
#   'center'],
#  ['oil',
#   'Liza',
#   'Stabroek',
#   'Block',
#   'Exxon',
#   ' ',
#   'barrels',
#   'Guyana',
#   'crude',
#   'breakeven',
#   'offshore',
#   'discoveries',
#   'phase',
#   'day',
#   'production',
#   'petroleum',
#   '$',
#   '1',
#   'Hess',
#   'Exxonrsquos',
#   '2'],
#  ['demand',
#   ' ',
#   'million',
#   'week',
#   'gasoline',
#   'oil',
#   'inventories',
#   'data',
#   'barrels',
#   'average',
#   'bpd',
#   'U.S.',
#   'year',
#   'EIA',
#   'compared',
#   'implied',
#   'prices',
#   'September',
#   'said',
#   'draw',
#   'rdquo'],
#  ['oil',
#   ' ',
#   'Ida',
#   'Gulf',
#   'Coast',
#   'Hurricane',
#   'gas',
#   'spills',
#   'storm',
#   'Louisiana',
#   'caused',
#   'Guard',
#   'reports',
#   'far',
#   'New',
#   'United',
#   'States',
#   'production',
#   'pollution',
#   'report',
#   'environmental'],
#  [' ',
#   'oil',
#   'pipeline',
#   'offshore',
#   'Hurricane',
#   'U.S.',
#   'Gulf',
#   'Mexico',
#   'gas',
#   'Ida',
#   'production',
#   'damage',
#   'GAO',
#   'said',
#   'infrastructure',
#   'pipelines',
#   'BSEE',
#   'decommissioning',
#   'spills',
#   'report',
#   'process'],
#  ['oil',
#   ' ',
#   'Iraq',
#   'energy',
#   'gas',
#   'million',
#   'renewable',
#   'production',
#   'bpd',
#   'Iraqrsquos',
#   'BP',
#   'country',
#   'projects',
#   'oilfield',
#   'months',
#   'OPEC',
#   'foreign',
#   'new',
#   'pandemic',
#   'announced',
#   '$'],
#  ['OPEC',
#   ' ',
#   'oil',
#   'demand',
#   'year',
#   'global',
#   '2022',
#   'said',
#   'million',
#   'bpd',
#   'sources',
#   'MOMR',
#   'estimates',
#   'unchanged',
#   'report',
#   'August',
#   'second',
#   'half',
#   'growth',
#   'September',
#   'surplus'],
#  ['oil',
#   'crude',
#   'largest',
#   'barrels',
#   'Brazilrsquos',
#   'million',
#   'production',
#   '2021',
#   'worldrsquos',
#   'day',
#   ' ',
#   'Buzios',
#   'quality',
#   'Latin',
#   'year',
#   'low',
#   'Americarsquos',
#   'Brazil',
#   'producer',
#   'average',
#   'petroleum'],
#  ['Bitcoin',
#   'energy',
#   'gas',
#   ' ',
#   'power',
#   'potential',
#   'public',
#   'puzzles',
#   'oil',
#   'world',
#   'cryptocurrency',
#   'disrupt',
#   'global',
#   'scrutiny',
#   'cryptocurrencies',
#   'market',
#   'case',
#   'Elon',
#   'consumption',
#   'ledger',
#   'blockchain'],
#  ['million',
#   ' ',
#   'week',
#   'barrels',
#   'bpd',
#   'oil',
#   'compared',
#   'inventory',
#   'draw',
#   'production',
#   'decline',
#   'crude',
#   'previous',
#   'averaged',
#   '$',
#   'barrel',
#   'demand',
#   'Gulf',
#   'Oil',
#   'prices',
#   'reported'],
#  ['demand',
#   'oil',
#   ' ',
#   'percent',
#   'year',
#   'pandemic',
#   'Bloomberg',
#   'SIA',
#   'Energy',
#   'higher',
#   'India',
#   'worldrsquos',
#   'consumers',
#   'pre',
#   'consumption',
#   'levels',
#   'fuel',
#   'recovery',
#   'analyst',
#   '13',
#   'fourth'],
#  ['oil',
#   'Venezuelarsquos',
#   'barrels',
#   'U.S.',
#   'sanctions',
#   'production',
#   'petroleum',
#   ' ',
#   'Beijing',
#   'investment',
#   'China',
#   'Venezuela',
#   'crude',
#   'energy',
#   '$',
#   'billion',
#   'industry',
#   'million',
#   'regime',
#   'largest',
#   'greater'],
#  ['energy',
#   ' ',
#   'price',
#   'fuels',
#   'prices',
#   'gasoline',
#   'fossil',
#   'oil',
#   'gas',
#   'U.S.',
#   'Tomlinson',
#   'world',
#   'transition',
#   'Biden',
#   'pump',
#   'people',
#   'running',
#   'politicians',
#   'Americans',
#   'Nordhaus',
#   'Bazilian'],
#  ['oil',
#   ' ',
#   'North',
#   'industry',
#   'statersquos',
#   'energy',
#   'production',
#   'Dakota',
#   'new',
#   'U.S.',
#   'workers',
#   'gas',
#   'state',
#   'jobs',
#   'year',
#   'pandemic',
#   'output',
#   '$',
#   'demand',
#   'producers',
#   'Dakotarsquos'],
#  ['OPEC',
#   ' ',
#   'market',
#   'January',
#   'oil',
#   'production',
#   'add',
#   'monthly',
#   'said',
#   'meeting',
#   'group',
#   'Omicron',
#   'variant',
#   'Thursday',
#   'policy',
#   '400,000',
#   'bpd',
#   'Crude',
#   '$',
#   'session',
#   'remain'],
#  ['oil',
#   ' ',
#   'ban',
#   'crude',
#   'U.S.',
#   'exports',
#   'industry',
#   'Bloomberg',
#   'Brent',
#   'betting',
#   'administration',
#   'options',
#   'fall',
#   'according',
#   'report',
#   'WTI',
#   '$',
#   'Khanna',
#   'According',
#   'global',
#   'prices'],
#  ['production',
#   ' ',
#   'oil',
#   'Ida',
#   'offshore',
#   'Gulf',
#   'energy',
#   '   ',
#   'U.S.',
#   'Mexico',
#   '16',
#   'time',
#   'million',
#   'barrels',
#   'year',
#   'years',
#   'global',
#   'supply',
#   'Federal',
#   'Reserve',
#   'inflation'],
#  ['demand',
#   'oil',
#   ' ',
#   'India',
#   'Indian',
#   'bpd',
#   'million',
#   'capacity',
#   'refiners',
#   'fuel',
#   'report',
#   'boost',
#   'refining',
#   'Reuters',
#   'reported',
#   'month',
#   'pandemic',
#   'gasoline',
#   'diesel',
#   'August',
#   'said'],
#  [' ',
#   'deals',
#   '$',
#   'billion',
#   'oil',
#   'consolidation',
#   'upstream',
#   'said',
#   'shale',
#   'rdquo',
#   'U.S.',
#   'half',
#   'North',
#   'America',
#   'patch',
#   'deal',
#   '2021',
#   'spend',
#   'report',
#   'MampA',
#   'continue'],
#  ['Enbridge',
#   ' ',
#   'export',
#   'crude',
#   'percent',
#   'cost',
#   'America',
#   'terminal',
#   'pipeline',
#   'U.S.',
#   'low',
#   'buy',
#   'closing',
#   'said',
#   '100',
#   'Ingleside',
#   'North',
#   'Canadian',
#   'US$',
#   '3',
#   'billion'],
#  [' ',
#   'India',
#   'renewables',
#   'country',
#   'energy',
#   'GW',
#   'countries',
#   'billion',
#   '$',
#   'grid',
#   'sector',
#   'system',
#   'developing',
#   'investors',
#   'largest',
#   'Indiarsquos',
#   'solar',
#   'reach',
#   '2030',
#   'government',
#   'large'],
#  [' ',
#   'independent',
#   'oil',
#   'month',
#   'August',
#   'refiners',
#   'million',
#   'bpd',
#   'higher',
#   'OilX',
#   'increase',
#   'average',
#   'lower',
#   'import',
#   'year',
#   'said',
#   'buying',
#   'Chinese',
#   'imports',
#   'percent',
#   'reported'],
#  ['oil',
#   'Ecuadorrsquos',
#   'petroleum',
#   'industry',
#   'production',
#   'barrels',
#   'crude',
#   ' ',
#   '2020',
#   'output',
#   'Lasso',
#   'day',
#   'investment',
#   'hydrocarbon',
#   'sector',
#   'operations',
#   'companies',
#   'agreements',
#   'Andean',
#   'heavy',
#   'environmental'],
#  [' ',
#   'percent',
#   'oil',
#   'shut',
#   'Sunday',
#   'production',
#   'Louisiana',
#   'Gulf',
#   'offshore',
#   'Ida',
#   'million',
#   'bpd',
#   'U.S.',
#   'refineries',
#   'Port',
#   'said',
#   'week',
#   'Hurricane',
#   'landfall',
#   'gas',
#   'crude'],
#  [' ',
#   'demand',
#   'fuel',
#   'summer',
#   'gasoline',
#   'Europersquos',
#   'oil',
#   'road',
#   'Bloomberg',
#   'Europe',
#   'August',
#   'higher',
#   'fall',
#   'consumption',
#   'Europeans',
#   'late',
#   'nbsp',
#   'traffic',
#   'COVID',
#   '2019',
#   'estimates'],
#  ['Asia',
#   'crude',
#   ' ',
#   'Saudi',
#   'oil',
#   '$',
#   'prices',
#   'price',
#   'Arabia',
#   'OSPs',
#   'October',
#   'Asian',
#   'grades',
#   'cuts',
#   'September',
#   'Middle',
#   'pricing',
#   'selling',
#   'expected',
#   'market',
#   'demand'],
#  [' ',
#   'oil',
#   '$',
#   'year',
#   'Oil',
#   'crude',
#   'refiners',
#   'billion',
#   'China',
#   'Beijing',
#   'reserves',
#   'Rystad',
#   'shale',
#   'demand',
#   'proven',
#   'markets',
#   'U.S.',
#   'teapots',
#   'million',
#   'years',
#   'boe'],
#  [' ',
#   'gasoline',
#   'prices',
#   'U.S.',
#   'OPEC',
#   'oil',
#   'Biden',
#   'Administration',
#   'energy',
#   'production',
#   'continue',
#   'consumers',
#   'policies',
#   'high',
#   'planned',
#   'increases',
#   'said',
#   'group',
#   'White',
#   'House',
#   'support'],
#  ['week',
#   ' ',
#   'count',
#   'rigs',
#   'rig',
#   'oil',
#   'year',
#   'number',
#   'day',
#   'wells',
#   '$',
#   'gas',
#   'United',
#   'States',
#   '5',
#   'time',
#   '2020',
#   'ending',
#   'rose',
#   'fell',
#   'total'],
#  ['Iran',
#   'oil',
#   'production',
#   'sanctions',
#   ' ',
#   'U.S.',
#   'bpd',
#   'crude',
#   'said',
#   'Iranian',
#   'million',
#   'exports',
#   'country',
#   'pre',
#   'plans',
#   'ramp',
#   'months',
#   'minister',
#   'quoted',
#   'despite',
#   'Reuters'],
#  ['oil',
#   ' ',
#   'project',
#   'Rosneft',
#   'Vostok',
#   'billion',
#   'major',
#   'reported',
#   'tons',
#   'Indian',
#   'state',
#   'early',
#   'talks',
#   'stake',
#   'Russian',
#   'massive',
#   'sources',
#   'said',
#   'Oil',
#   'clusters',
#   'resources'],
#  ['oil',
#   'Perursquos',
#   'industry',
#   ' ',
#   'Block',
#   '2020',
#   'considerable',
#   'petroleum',
#   'investment',
#   'communities',
#   'operations',
#   'community',
#   'pandemic',
#   'Andean',
#   'Castillo',
#   'conflict',
#   'July',
#   'countryrsquos',
#   'Peru',
#   'Amazon',
#   'day'],
#  [' ',
#   'refinery',
#   'power',
#   'percent',
#   'Louisiana',
#   'shut',
#   'Hurricane',
#   'restart',
#   'restored',
#   'Gulf',
#   'told',
#   'refineries',
#   'Ida',
#   'weeks',
#   'Coast',
#   'storm',
#   'refiners',
#   'damage',
#   'estimated',
#   'expect',
#   'gas'],
#  ['oil',
#   ' ',
#   'Venezuela',
#   'China',
#   'report',
#   'CNPC',
#   'operations',
#   'local',
#   'companies',
#   'Venezuelan',
#   'crude',
#   'preparing',
#   'Maduro',
#   'government',
#   'legislation',
#   'foreign',
#   'According',
#   'Bloomberg',
#   'sources',
#   'blending',
#   'company'],
#  [' ',
#   'wells',
#   'oil',
#   'number',
#   'Energy',
#   'shale',
#   'producers',
#   'drilling',
#   'capital',
#   'production',
#   'DUC',
#   'year',
#   'percent',
#   'drilled',
#   'levels',
#   'activity',
#   'recover',
#   'completion',
#   'DUCs',
#   'Rystad',
#   'count'],
#  [' ',
#   'OPEC',
#   'oil',
#   'bpd',
#   'prices',
#   'cartel',
#   'production',
#   'meeting',
#   'year',
#   '400,000',
#   'demand',
#   'group',
#   'energy',
#   'supply',
#   'wave',
#   'rise',
#   'surplus',
#   'million',
#   'Oil',
#   'today',
#   'UAE'],
#  [' ',
#   'energy',
#   'oil',
#   'gas',
#   'said',
#   'transition',
#   'continue',
#   'play',
#   'role',
#   'rdquo',
#   'wind',
#   'lower',
#   'ldquoThe',
#   'inflation',
#   'social',
#   'unrest',
#   'chief',
#   'executive',
#   'warned',
#   'admitting',
#   'significant'],
#  ['power',
#   'change',
#   ' ',
#   'new',
#   'transmission',
#   'utilities',
#   'crisis',
#   'electric',
#   'utility',
#   'public',
#   'grid',
#   'restoration',
#   'seen',
#   'hurricane',
#   'think',
#   'climate',
#   'system',
#   'need',
#   'service',
#   'thing',
#   'mdash'],
#  [' ',
#   'UK',
#   'investment',
#   'billion',
#   'energy',
#   'oil',
#   'North',
#   'Sea',
#   'OGUK',
#   'said',
#   'capital',
#   'US$',
#   'fall',
#   'rdquo',
#   'security',
#   '2020',
#   'offshore',
#   'industry',
#   '2021',
#   'Wednesday',
#   'COVID'],
#  ['million',
#   ' ',
#   'barrels',
#   'oil',
#   'bpd',
#   'week',
#   'draw',
#   'production',
#   'estimated',
#   'inventory',
#   'averaging',
#   'prices',
#   'August',
#   '27',
#   'compared',
#   'EIA',
#   'report',
#   'gasoline',
#   'stocks',
#   'period',
#   'earlier'],
#  ['oil',
#   'Louisiana',
#   ' ',
#   'damage',
#   'Ida',
#   'port',
#   'Port',
#   'weeks',
#   'tankers',
#   'ports',
#   'wake',
#   'Hurricane',
#   'assess',
#   'Reuters',
#   'data',
#   'landfall',
#   'earlier',
# ...
#   'North'],
#  ['million',
#   'week',
#   ' ',
#   'earlier',
#   'barrels',
#   'inventory',
#   'bpd',
#   'oil',
#   'crude',
#   'fuel',
#   'draw',
#   'weeks',
#   'inventories',
#   'previous',
#   'weekly',
#   'Distillate',
#   'barrel',
#   'prices',
#   'reported',
#   'EIA',
#   'estimated'],
#  ['OPEC',
#   'million',
#   'bpd',
#   ' ',
#   'production',
#   'cuts',
#   'Saudi',
#   '9.7',
#   'said',
#   'cut',
#   'record',
#   'August',
#   'meeting',
#   'end',
#   'group',
#   'easing',
#   'demand',
#   'Prince',
#   'Abdulaziz',
#   'bin',
#   'Salman'],
#  [' ',
#   'OPEC',
#   'production',
#   'rdquo',
#   'prices',
#   'cuts',
#   'oil',
#   '$',
#   'compliance',
#   'likely',
#   'June',
#   'market',
#   'said',
#   'Oil',
#   'mb',
#   'coronavirus',
#   'Standard',
#   'Chartered',
#   'demand',
#   'supply',
#   'beginning'],
#  ['drilling',
#   ' ',
#   'tools',
#   'wells',
#   'offshore',
#   'drill',
#   'year',
#   'onshore',
#   'demand',
#   'Rystad',
#   'expected',
#   'Energy',
#   '2025',
#   'spending',
#   'activity',
#   'drilled',
#   'number',
#   'likely',
#   '2021',
#   '2020',
#   'total'],
#  ['oil',
#   'demand',
#   ' ',
#   'peak',
#   'global',
#   'world',
#   'end',
#   'market',
#   'reached',
#   'economic',
#   'coronavirus',
#   'crude',
#   'result',
#   'compared',
#   '2019',
#   'countries',
#   'outlook',
#   'growth',
#   'economies',
#   'social',
#   'business'],
#  [' ',
#   'nbsp',
#   'oil',
#   'million',
#   'imports',
#   'bpd',
#   'China',
#   'June',
#   'year',
#   'rate',
#   'crude',
#   'half',
#   'Reuters',
#   'average',
#   'months',
#   'prices',
#   'Oil',
#   'coronavirus',
#   'countryrsquos',
#   'overall',
#   '2019'],
#  ['OPEC',
#   ' ',
#   'million',
#   'production',
#   'bpd',
#   'cuts',
#   'end',
#   'meetings',
#   'oil',
#   'market',
#   'record',
#   'group',
#   'ease',
#   'meeting',
#   'month',
#   '9.7',
#   'Tuesday',
#   'August',
#   'Joint',
#   'Committee',
#   'hold'],
#  ['OPEC',
#   ' ',
#   'market',
#   'cuts',
#   'oil',
#   'production',
#   'supply',
#   'rdquo',
#   'mb',
#   'prices',
#   'said',
#   'demand',
#   'remains',
#   'ndash',
#   'group',
#   'begin',
#   '9.7',
#   'd',
#   'producers',
#   'Dickson',
#   'increase'],
#  ['million',
#   'bbl',
#   'd',
#   ' ',
#   'OPEC',
#   'percent',
#   'demand',
#   'w',
#   'forecast',
#   'CMarkits',
#   'oil',
#   'expected',
#   'cuts',
#   '2020',
#   'y',
#   'inventories',
#   '$',
#   'EIA',
#   'production',
#   'compliance',
#   'rise'],
#  [' ',
#   'production',
#   'OPEC',
#   'oil',
#   'demand',
#   'record',
#   'prices',
#   'market',
#   'alliance',
#   'producers',
#   'Bloomberg',
#   'million',
#   'April',
#   'cut',
#   'lockdowns',
#   'Russia',
#   'led',
#   'Saudi',
#   'Arabia',
#   'coronavirus',
#   'overnight'],
#  [' ',
#   'oil',
#   'nbsp',
#   'Saudi',
#   'exports',
#   'crude',
#   'cuts',
#   'sources',
#   'bpd',
#   'August',
#   'production',
#   'month',
#   'million',
#   'Arabia',
#   'OPEC',
#   'ease',
#   'record',
#   'grades',
#   'set',
#   'July',
#   'toldnbspReutersnbspon'],
#  ['oil',
#   ' ',
#   'blockade',
#   'terminals',
#   'majeure',
#   'exports',
#   'National',
#   'NOC',
#   'forces',
#   'Libyan',
#   'production',
#   'force',
#   'Oil',
#   'Corporation',
#   'export',
#   'United',
#   'Arab',
#   'Emirates',
#   'Es',
#   'Sider',
#   'Khalifa'],
#  [' ',
#   'nbsp',
#   'Houthi',
#   'Saudi',
#   'Iran',
#   'said',
#   'missiles',
#   'military',
#   'Yemen',
#   'Arabia',
#   'oil',
#   'Jizan',
#   'drones',
#   'ballistic',
#   'launched',
#   'terrorist',
#   'backed',
#   'militia',
#   'deliberately',
#   'civilians',
#   'civilian'],
#  [' ',
#   'oil',
#   '$',
#   'Bank',
#   'largest',
#   'billion',
#   'Saudi',
#   'assets',
#   'UAE',
#   'banking',
#   'GDP',
#   'Oman',
#   'price',
#   'heavily',
#   'sector',
#   'deal',
#   'IMF',
#   'Qatar',
#   'merger',
#   'combined',
#   'entity'],
#  [' ',
#   'oil',
#   'market',
#   'demand',
#   'IEA',
#   'mb',
#   'd',
#   'second',
#   'year',
#   'production',
#   'supply',
#   'rdquo',
#   'OPEC',
#   'month',
#   'thought',
#   'prices',
#   'quarter',
#   'half',
#   'compliance',
#   'rally',
#   'shale'],
#  ['oil',
#   ' ',
#   'months',
#   'force',
#   'majeure',
#   'production',
#   'blockade',
#   'terminals',
#   'Libyan',
#   'port',
#   'exports',
#   'Libyarsquos',
#   'National',
#   'Friday',
#   'Libya',
#   'market',
#   'Es',
#   'Sider',
#   'NOC',
#   'said',
#   'damage'],
#  ['oil',
#   ' ',
#   '$',
#   'new',
#   '100',
#   'barrel',
#   'prices',
#   'analysts',
#   'Journal',
#   'return',
#   'gas',
#   'investments',
#   '150',
#   'ones',
#   'demand',
#   'pre',
#   'levels',
#   'Woods',
#   'investment',
#   'told',
#   'hit'],
#  [' ',
#   '$',
#   'crude',
#   'oil',
#   'markets',
#   'cuts',
#   'barrel',
#   'OPEC',
#   'production',
#   'demand',
#   'sour',
#   'U.S.',
#   'Arab',
#   'medium',
#   'price',
#   'futures',
#   'far',
#   'Urals',
#   'delivery',
#   'selling',
#   'end'],
#  ['oil',
#   'production',
#   ' ',
#   'bpd',
#   'curtailed',
#   'U.S.',
#   'second',
#   'June',
#   'Noble',
#   'bring',
#   'end',
#   'quarter',
#   'prices',
#   'expects',
#   'Energy',
#   'July',
#   'demand',
#   'latest',
#   'shut',
#   'company',
#   'said'],
#  ['storage',
#   ' ',
#   'million',
#   'barrels',
#   'crude',
#   'bpd',
#   'Iran',
#   'oil',
#   'production',
#   'Iranrsquos',
#   'according',
#   'capacity',
#   'demand',
#   'floating',
#   'OilX',
#   'onshore',
#   'June',
#   'total',
#   'near',
#   'OPEC',
#   'drop'],
#  [' ',
#   'energy',
#   'China',
#   'U.S.',
#   'products',
#   'US$',
#   'billion',
#   'oil',
#   'trade',
#   'buy',
#   'purchases',
#   'deal',
#   'American',
#   'target',
#   'demand',
#   'phase',
#   'gas',
#   'year',
#   'Chinese',
#   'global',
#   '26'],
#  ['oil',
#   'Colombiarsquos',
#   ' ',
#   'economic',
#   'Colombia',
#   'considerable',
#   'government',
#   'reserves',
#   'price',
#   'economy',
#   'nation',
#   'production',
#   '2020',
#   'weaker',
#   'latest',
#   'American',
#   'development',
#   'growth',
#   'dependence',
#   'sharply',
#   'prices'],
#  ['production',
#   ' ',
#   'curtailed',
#   'said',
#   'oil',
#   'Energy',
#   'prices',
#   'Canadian',
#   'crude',
#   'Cenovus',
#   'bpd',
#   'rdquo',
#   'Pourbaix',
#   'end',
#   'energy',
#   'conference',
#   'Husky',
#   'plunged',
#   'Canada',
#   'bring',
#   'chief'],
#  ['million',
#   'week',
#   ' ',
#   'barrels',
#   'bpd',
#   'inventories',
#   'oil',
#   'earlier',
#   'July',
#   '3',
#   'crude',
#   'prior',
#   'year',
#   'production',
#   '$',
#   'barrel',
#   'Crude',
#   'United',
#   'States',
#   'gasoline',
#   'inventory'],
#  ['oil',
#   'energy',
#   'gas',
#   ' ',
#   'production',
#   'potential',
#   'geothermal',
#   'renewable',
#   'emissions',
#   'Canada',
#   'Canadarsquos',
#   'industry',
#   'sands',
#   'reduce',
#   'COSIA',
#   'C',
#   'heat',
#   'project',
#   'greenhouse',
#   'fossil',
#   'carbon'],
#  ['North',
#   ' ',
#   'Dakota',
#   'oil',
#   'idea',
#   'producers',
#   'Dakotarsquos',
#   'production',
#   'Texas',
#   'Commission',
#   'rdquo',
#   'state',
#   'Access',
#   'shut',
#   'Bakken',
#   'Bismarck',
#   'let',
#   'pro',
#   'rationing',
#   'Commissioner',
#   'mandatory'],
#  ['oil',
#   'storage',
#   'crude',
#   'China',
#   ' ',
#   'Chinarsquos',
#   'prices',
#   'cheap',
#   'rdquo',
#   'countryrsquos',
#   'global',
#   'low',
#   'buying',
#   'CNN',
#   'bought',
#   'issue',
#   'tankers',
#   'ldquoChina',
#   'capacity',
#   'onshore',
#   'earlier'],
#  [' ',
#   'Bakken',
#   'oil',
#   'Dakota',
#   'Access',
#   'rdquo',
#   'pipeline',
#   'production',
#   'shut',
#   'Energy',
#   'rail',
#   'price',
#   'shale',
#   'market',
#   'barrel',
#   'stay',
#   'environmental',
#   'told',
#   'need',
#   'crude',
#   '$'],
#  ['oil',
#   ' ',
#   'Latin',
#   'America',
#   'U.S.',
#   'Venezuelarsquos',
#   'Moscow',
#   'Venezuela',
#   'sanctions',
#   'regime',
#   'Moscowrsquos',
#   'long',
#   'considerable',
#   'regional',
#   'region',
#   'Venezuelan',
#   'decades',
#   'Russia',
#   'gain',
#   'war',
#   'history'],
#  [' ',
#   'Keystone',
#   'XL',
#   'pipeline',
#   'Supreme',
#   'ruling',
#   'project',
#   'permit',
#   'oil',
#   'construction',
#   'pipelines',
#   'Energy',
#   'court',
#   'use',
#   'rivers',
#   'U.S.',
#   'Monday',
#   'Courtrsquos',
#   'day',
#   'gas',
#   'nbsp'],
#  [' ',
#   'data',
#   'oil',
#   'demand',
#   'real',
#   'traders',
#   'time',
#   'continue',
#   'analysts',
#   'search',
#   'gasoline',
#   'mobility',
#   'pandemic',
#   'people',
#   'COVID-19',
#   'market',
#   'ultimate',
#   'sources',
#   'U.S.',
#   'directions',
#   'trends'],
#  ['oil',
#   'June',
#   ' ',
#   'million',
#   'crude',
#   'increase',
#   'bpd',
#   'Chinarsquos',
#   'imports',
#   'record',
#   'OilX',
#   'China',
#   'hit',
#   'high',
#   'according',
#   '11.93',
#   'levels',
#   'year',
#   '   ',
#   'prices',
#   'barrels'],
#  ['million',
#   'bbl',
#   'd',
#   ' ',
#   'oil',
#   'production',
#   'June',
#   '$',
#   'data',
#   'compliance',
#   'average',
#   'w',
#   'U.S.',
#   'demand',
#   'year',
#   'according',
#   'Saudi',
#   'compared',
#   'said',
#   'Arabia',
#   'thousand'],
#  ['Argentinarsquos',
#   ' ',
#   'shale',
#   'year',
#   'ndash',
#   '2020',
#   'Argentina',
#   'Buenos',
#   'Vaca',
#   'Muerta',
#   'oil',
#   'assumed',
#   'Argentinian',
#   'March',
#   'government',
#   'Aires',
#   'economy',
#   'Neuquen',
#   'production',
#   'early',
#   'price'],
#  [' ',
#   'lithium',
#   'ion',
#   'battery',
#   'batteries',
#   'pandemic',
#   'year',
#   'lead',
#   'acid',
#   'market',
#   'Covid-19',
#   'sector',
#   'mdash',
#   'future',
#   'article',
#   'impact',
#   'demand',
#   'company',
#   'growth',
#   'sales',
#   '2020'],
#  [' ',
#   'oil',
#   'gas',
#   'prices',
#   'deals',
#   'U.S.',
#   'million',
#   'production',
#   'MampA',
#   'low',
#   'Q2',
#   'value',
#   'week',
#   'deal',
#   'said',
#   'price',
#   'companies',
#   'quarter',
#   'US$',
#   'crash',
#   'market'],
#  [' ',
#   'Khafji',
#   'production',
#   'Al',
#   'Saudi',
#   'Arabia',
#   'Kuwait',
#   'neutral',
#   'bpd',
#   'oil',
#   'June',
#   'restart',
#   'Wafra',
#   'OPEC',
#   'field',
#   'zone',
#   'late',
#   'plans',
#   'million',
#   '2015',
#   'worsening'],
#  ['demand',
#   ' ',
#   'refineries',
#   'new',
#   'oil',
#   'pandemic',
#   'growth',
#   'Goldman',
#   'bank',
#   'years',
#   'coming',
#   'Covid-19',
#   'recover',
#   'levels',
#   'says',
#   'EVs',
#   'lower',
#   'sees',
#   'analysts',
#   'older',
#   'diesel'],
#  ['demand',
#   'oil',
#   ' ',
#   'growth',
#   'energy',
#   'economic',
#   'recovery',
#   'slow',
#   'Moodyrsquos',
#   'Asia',
#   'year',
#   'BCG',
#   'scenarios',
#   'new',
#   'air',
#   'changes',
#   'said',
#   'report',
#   'transportation',
#   'fuel',
#   'pandemic'],
#  ['rigs',
#   'week',
#   ' ',
#   'oil',
#   'active',
#   'number',
#   'gas',
#   'time',
#   'total',
#   'year',
#   'United',
#   'States',
#   '$',
#   'weeks',
#   'rose',
#   'production',
#   'Baker',
#   'Hughes',
#   '2',
#   'second',
#   'data'],
#  [' ',
#   'million',
#   'bpd',
#   'OPEC',
#   'production',
#   'oil',
#   'cuts',
#   'ease',
#   'Saudi',
#   '9.7',
#   'end',
#   'reached',
#   'April',
#   'supply',
#   'demand',
#   'discussing',
#   'changes',
#   'cut',
#   'agreement',
#   'producers',
#   'August'],
#  ['shale',
#   ' ',
#   'oil',
#   '$',
#   'slow',
#   'industry',
#   'Energy',
#   'term',
#   'recovery',
#   'U.S.',
#   'Texas',
#   'crude',
#   'Permian',
#   'Chesapeake',
#   'certainly',
#   '30',
#   'percent',
#   'companies',
#   'Rig',
#   'Zone',
#   'pandemic'],
#  [' ',
#   'oil',
#   'prices',
#   'companies',
#   '$',
#   'gas',
#   'borrowing',
#   'based',
#   'cut',
#   'credit',
#   'lenders',
#   'Reuters',
#   'year',
#   'saw',
#   'U.S.',
#   '40',
#   'far',
#   'spring',
#   'season',
#   'analysis',
#   'low'],
#  [' ',
#   'oil',
#   'demand',
#   'market',
#   'rdquo',
#   'cases',
#   'new',
#   'price',
#   'U.S.',
#   'crude',
#   'OPEC',
#   'Covid-19',
#   'recovery',
#   'production',
#   'continues',
#   'coronavirus',
#   'rally',
#   'day',
#   'mb',
#   'd',
#   'wrote'],
#  ['debt',
#   'Angolarsquos',
#   ' ',
#   'Angola',
#   'Sonangol',
#   'ndash',
#   'China',
#   'market',
#   'vis',
#   'oil',
#   'revenues',
#   'Angolan',
#   'Luanda',
#   'government',
#   'seeks',
#   'time',
#   'Total',
#   'Block',
#   'current',
#   '2019',
#   'IPO'],
#  ['oil',
#   ' ',
#   'million',
#   'barrels',
#   'demand',
#   'market',
#   'April',
#   'prices',
#   'ndash',
#   'sea',
#   'structure',
#   'crude',
#   'floating',
#   'storage',
#   'June',
#   'contango',
#   'backwardation',
#   'held',
#   'started',
#   'shrink',
#   'According'],
#  ['oil',
#   ' ',
#   'Venezuelarsquos',
#   'crude',
#   'production',
#   'bpd',
#   'June',
#   'U.S.',
#   'percent',
#   'Venezuela',
#   'sanctions',
#   'PDVSA',
#   'documents',
#   'seen',
#   'country',
#   'largest',
#   'reserves',
#   'Orinoco',
#   'belt',
#   'plunged',
#   'industry'],
#  [' ',
#   'million',
#   'week',
#   'nbsp',
#   'bpd',
#   'barrels',
#   'oil',
#   'inventories',
#   'June',
#   'earlier',
#   '26',
#   'inventory',
#   'year',
#   'averaged',
#   'Distillate',
#   'fuel',
#   '$',
#   'United',
#   'States',
#   'shed',
#   'draw'],
#  [' ',
#   'Saudi',
#   'oil',
#   'production',
#   '2050',
#   'Arabia',
#   'gas',
#   'crude',
#   'hydrocarbon',
#   'EIA',
#   'OPEC',
#   'natural',
#   'Arabiarsquos',
#   'worldrsquos',
#   'countries',
#   'producer',
#   'liquids',
#   'condensate',
#   'million',
#   'increase',
#   'Energy'],
#  [' ',
#   'oil',
#   'Namibia',
#   'offshore',
#   'exploration',
#   'production',
#   'Recon',
#   'Total',
#   'Africa',
#   'itrsquos',
#   'commercial',
#   'future',
#   'hydrocarbons',
#   'investment',
#   'communication',
#   'investor',
#   'looking',
#   'market',
#   'RECO',
#   'statements',
#   'risks'],
#  ['oil',
#   ' ',
#   'bpd',
#   'production',
#   'blockade',
#   'government',
#   'groups',
#   'terminals',
#   'January',
#   '$',
#   'losses',
#   'said',
#   'Haftar',
#   'UN',
#   'Sanalla',
#   'leaders',
#   'affiliated',
#   'Libyan',
#   'export',
#   'countryrsquos',
#   'billion'],
#  ['rdquo',
#   'oil',
#   ' ',
#   'cent',
#   'outbreak',
#   'year',
#   'Beijing',
#   'prices',
#   'China',
#   'U.S.',
#   'lockdown',
#   'Chinarsquos',
#   'said',
#   'second',
#   'measures',
#   'target',
#   'Chinese',
#   'demand',
#   'new',
#   'economic',
#   'told'],
#  ['oil',
#   ' ',
#   '$',
#   'Colombiarsquos',
#   'production',
#   '2020',
#   'price',
#   'year',
#   'barrels',
#   'Brent',
#   'daily',
#   'barrel',
#   'Colombian',
#   'spending',
#   'output',
#   'average',
#   'considerable',
#   'latest',
#   'drillers',
#   'industry',
#   'economy'],
#  ['oil',
#   ' ',
#   'contango',
#   'demand',
#   'market',
#   'storage',
#   'futures',
#   'floating',
#   'curve',
#   'backwardation',
#   'months',
#   'prices',
#   'super',
#   'Brent',
#   'OPEC',
#   'year',
#   'April',
#   'month',
#   'higher',
#   'record',
#   'new'],
#  [' ',
#   'OPEC',
#   'production',
#   'bpd',
#   'million',
#   'Petro',
#   'oil',
#   'June',
#   'Logistics',
#   'compliance',
#   'supply',
#   'OPECrsquos',
#   'nbsp',
#   'Saudi',
#   'Iraq',
#   'cuts',
#   'compared',
#   'record',
#   'collective',
#   'quota',
#   'crude'],
#  ['inventories',
#   'crude',
#   'oil',
#   ' ',
#   'million',
#   'June',
#   '19',
#   'barrels',
#   'U.S.',
#   'demand',
#   'capacity',
#   'commercial',
#   'week',
#   'year',
#   'time',
#   'EIA',
#   'percent',
#   'storage',
#   'United',
#   'States',
#   'record'],
#  [' ',
#   'shale',
#   '$',
#   'prices',
#   'production',
#   'U.S.',
#   'industry',
#   'drillers',
#   'oil',
#   'million',
#   'money',
#   'According',
#   'bpd',
#   'cash',
#   '30',
#   'percent',
#   'higher',
#   '35',
#   'need',
#   'banks',
#   'according'],
#  ['rigs',
#   'week',
#   ' ',
#   'number',
#   'oil',
#   'active',
#   'United',
#   'States',
#   'time',
#   'gas',
#   'year',
#   'rig',
#   '$',
#   'weeks',
#   'total',
#   'count',
#   'Baker',
#   'Hughes',
#   'fell',
#   '1',
#   'decline'],
#  [' ',
#   'wells',
#   'oil',
#   'United',
#   'States',
#   '2019',
#   'year',
#   'active',
#   'gas',
#   'producers',
#   'rig',
#   'number',
#   'feet',
#   'average',
#   'drilled',
#   'rigs',
#   'breaking',
#   'according',
#   'EIA',
#   'U.S.',
#   'counts'],
#  [' ',
#   'Gulf',
#   'Coast',
#   'oil',
#   'U.S.',
#   'Argus',
#   'crude',
#   'Texas',
#   'benchmark',
#   'Platts',
#   'Crude',
#   'new',
#   'market',
#   'Launch',
#   'Oil',
#   'Benchmark',
#   'nbsp',
#   'Media',
#   'benchmarks',
#   'pricing',
#   'exported'],
#  ['oil',
#   'economic',
#   ' ',
#   'crude',
#   'demand',
#   '$',
#   'market',
#   'storage',
#   'U.S.',
#   'figures',
#   'looking',
#   'products',
#   'volumes',
#   'markets',
#   'barrel',
#   '2020',
#   'optimism',
#   'production',
#   'price',
#   'supply',
#   'producers'],
#  [' ',
#   'oil',
#   '$',
#   'trading',
#   'firm',
#   'Singapore',
#   'Hin',
#   'Leong',
#   'million',
#   'traders',
#   'billion',
#   'markets',
#   'assets',
#   'including',
#   'Trading',
#   'years',
#   'extent',
#   'liabilities',
#   'commodity',
#   'country',
#   'firms'],
#  ['oil',
#   ' ',
#   'Occidental',
#   'gas',
#   'assets',
#   'US$',
#   'billion',
#   'prices',
#   'impairments',
#   'impairment',
#   'said',
#   'conditions',
#   'tax',
#   '9',
#   'year',
#   'weak',
#   'period',
#   'lower',
#   'result',
#   'rdquo',
#   'Oxy'],
#  [' ',
#   'production',
#   'oil',
#   'wells',
#   'demand',
#   'Russian',
#   'new',
#   'companies',
#   'drilling',
#   'completing',
#   'bpd',
#   'start',
#   'million',
#   'recover',
#   'noted',
#   'necessary',
#   'investment',
#   'pre',
#   'pandemic',
#   'levels',
#   'banks'],
#  ['oil',
#   'Saudi',
#   'April',
#   'exports',
#   ' ',
#   'percent',
#   'billion',
#   'Arabia',
#   'value',
#   'US$',
#   'Arabiarsquos',
#   'prices',
#   'revenues',
#   'March',
#   '2020',
#   'OPEC',
#   'deal',
#   'million',
#   'record',
#   'market',
#   'Kingdomrsquos'],
#  ...]

# %%
corpus_oil_price['most_common_words'] = common_words_list_edited
corpus_oil_price
# Out:
#                                                   title  \
# 0                         $70 Oil Won't Keep OPEC Happy
# 1     Why This Oil Price Slump May Not Be Bad News F...
# 2              The Double Irony Of Biden's Plea To OPEC
# 3                  The Oil Price Rally Is Far From Over
# 4         Biden Threatens OPEC With Undisclosed "Tools"
# ...                                                 ...
# 2183           A Disobliging Update on the Price of Oil
# 2184                What Happens When the Wells Run Dry
# 2185  Petro Unfriendly California Changing it's Stan...
# 2186  New Techniques Oil Companies are Using in Dril...
# 2187  Biofuel of the Future - Turning our Garbage in...
#
#                  date_published  \
# 0     2021-11-29T19:00:00-06:00
# 1     2021-12-02T19:00:00-06:00
# 2     2021-11-10T13:00:00-06:00
# 3     2021-11-09T19:00:00-06:00
# 4     2021-11-08T10:00:00-06:00
# ...                         ...
# 2183  2010-01-09T16:21:21-06:00
# 2184  2010-01-08T16:55:39-06:00
# 2185  2009-12-30T14:18:05-06:00
# 2186  2009-11-25T16:35:34-06:00
# 2187  2009-11-23T14:06:51-06:00
#
#                                                 content  baseline_sentiment  \
# 0     One daymdashthat was all it took oil prices to...                  -1
# 1     Crude oil prices are plunging under the weight...                  -1
# 2     As I wrote in February of this year innbspThe ...                  -1
# 3     How much higher could oil prices go This is th...                   1
# 4     There are other tools in the arsenal that we h...                  -1
# ...                                                 ...                 ...
# 2183  There still seems to be a deplorable uncertain...                  -1
# 2184  One nagging question that the industrial world...                   1
# 2185  The financial crisis changed the way people th...                  -1
# 2186  As the politics and philosophical arguments ab...                   1
# 2187  Two overwhelming environmental calamities, sim...                   1
#
#       vader_sentiment                                  most_common_words
# 0              0.9448  [oil,  , OPEC, $, release, new, bpd, million, ...
# 1              0.9957  [ , production, shale, oil, prices, approach, ...
# 2              0.8805  [oil,  , Biden, prices, Administration, produc...
# 3              0.1027  [oil,  , prices, demand, $, higher, barrel, ye...
# 4             -0.6269  [ , OPEC, oil, pump, tools, President, Biden, ...
# ...               ...                                                ...
# 2183           0.9947  [oil, price, ndash, Saudi, Watling, $, Arabia,...
# 2184          -0.7541  [oil, run, begin, producing, day, thousands, p...
# 2185           0.0982  [oil, state, states, drilling, financial, deve...
# 2186           0.9985  [drilling, oil, wells, new, rdquo, technology,...
# 2187           0.9986  [energy, waste, rdquo, ethanol, trash, garbage...
#
# [2188 rows x 6 columns]

# %%
corpus_alternative_energies['most_common_words'] = common_words_list_edited_2
corpus_crude_oil['most_common_words'] = common_words_list_edited_3

# %%
corpus_oil_price.to_csv('data/corpus_oil_price_3.csv')
corpus_alternative_energies.to_csv('data/corpus_alternative_energies_3.csv')
corpus_crude_oil.to_csv('data/corpus_crude_oil_3.csv')
